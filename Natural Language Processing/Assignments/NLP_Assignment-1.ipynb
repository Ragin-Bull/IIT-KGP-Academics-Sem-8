# %% [markdown]
# # Task -1:
# Importing the Libraries needed for the preprocessing of the texts in the assignment. We'll be requiring spaCy for using NLP based functions for processing and modelling the text. We will be requiring the Regex library (re) for the pre-processing related task such as to remove all characters except for alphanumerics and whitespaces. We'll be requiring Pandas to load the dataset and perform the needed pre-processing

# %%
import spacy
import re
import pandas as pd

# %% [markdown]
# In this step, we are displaying the data obtain from all the CSV files provided to us, we store the data obtained from docs.csv in a Dataframe named df, the data obtained from queries.csv in queries and the data from qdrel.csv as qdrel.

# %%
df = pd.read_csv("./Query_Doc/docs.csv")
queries = pd.read_csv("./Query_Doc/queries.csv")
qdrel = pd.read_csv("./Query_Doc/qdrel.csv")

print("\033[1m" + "Docs Data Frame: \n" + '\033[0m\n', df.head())
print("\033[1m" + "Queries Data Frame: \n" + '\033[0m\n', queries.head())
print("\033[1m" + "Relational Data Frame: \n" + '\033[0m\n', qdrel.head())
# Out:
# Docs Data Frame:
#
#     Unnamed: 0  doc_id                                           doc_text
# 0           0       1  What is the step by step guide to invest in sh...
# 1           1       2  What is the step by step guide to invest in sh...
# 2           2       3  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 3           3       4  What would happen if the Indian government sto...
# 4           4       5  How can I increase the speed of my internet co...
# Queries Data Frame:
#
#     Unnamed: 0  query_id                                         query_text
# 0           0      4584                How can ask questions using photos?
# 1           1      6588  What is Atal Pension Yojana? What are its bene...
# 2           2     10113      Where is starch digested? How is it digested?
# 3           3      7957      What is a conjecture? What are some examples?
# 4           4      5498  What can India do to support the people suffer...
# Relational Data Frame:
#
#     Unnamed: 0  query_id  doc_id
# 0           0       318     317
# 1           1       378     377
# 2           2       379     380
# 3           3       399    2606
# 4           4       399    2607

# %% [markdown]
# Now we realise that there is an unnecessary column named unnamed, we seek to remove that to filter out noise from the data set because it is **NOT** needed in the modelling process

# %%
# Removal of the unnamed column from the dataframe
df = df.drop(df.columns[df.columns.str.contains('Unnamed', case=False)], axis=1)
queries = queries.drop(queries.columns[queries.columns.str.contains('Unnamed', case=False)], axis=1)
qdrel = qdrel.drop(qdrel.columns[qdrel.columns.str.contains('Unnamed', case=False)], axis=1)

print("\033[1m" + "Docs Data Frame: \n" + '\033[0m\n', df.head())
print("\033[1m" + "Queries Data Frame: \n" + '\033[0m\n', queries.head())
print("\033[1m" + "Relational Data Frame: \n" + '\033[0m\n', qdrel.head())
# Out:
# Docs Data Frame:
#
#     doc_id                                           doc_text
# 0       1  What is the step by step guide to invest in sh...
# 1       2  What is the step by step guide to invest in sh...
# 2       3  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 3       4  What would happen if the Indian government sto...
# 4       5  How can I increase the speed of my internet co...
# Queries Data Frame:
#
#     query_id                                         query_text
# 0      4584                How can ask questions using photos?
# 1      6588  What is Atal Pension Yojana? What are its bene...
# 2     10113      Where is starch digested? How is it digested?
# 3      7957      What is a conjecture? What are some examples?
# 4      5498  What can India do to support the people suffer...
# Relational Data Frame:
#
#     query_id  doc_id
# 0       318     317
# 1       378     377
# 2       379     380
# 3       399    2606
# 4       399    2607

# %% [markdown]
# ## a) Preprocessing of the docs and queries - removing the characters other than alphanumerics or whitespaces
#
# Now the first sub task under task-1 expects us to remove all the characters other than alphanumerics and white spaces, we will be using regex for the same. The library used is re, which we had already imported. All we have to do is write a purify_docs function that takes in the data from each of the cell of the docs and queries dataframes as input and then apply the regex operation of filtering out the characters other than lower-case a-z, upper-case A-Z, digits from 0-9 and spaces.

# %%
# Removal of characters other than alphabets (both uppercase and lowercase included), digits and numbers
def purify_docs(data):
    purified_doc = re.sub(r'[^a-zA-Z0-9\s]', ' ', data)
    return purified_doc

df['pure'] = (df['doc_text']).apply(purify_docs)
queries['pure'] = (queries['query_text']).apply(purify_docs)

print("\033[1m" + "Docs Data Frame: \n" + '\033[0m\n', df.head(), "\n")
print("\033[1m" + "Queries Data Frame: \n" + '\033[0m\n', queries.head(), "\n")
# Out:
# Docs Data Frame:
#
#     doc_id                                           doc_text  \
# 0       1  What is the step by step guide to invest in sh...
# 1       2  What is the step by step guide to invest in sh...
# 2       3  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 3       4  What would happen if the Indian government sto...
# 4       5  How can I increase the speed of my internet co...
#
#                                                 pure
# 0  What is the step by step guide to invest in sh...
# 1  What is the step by step guide to invest in sh...
# 2  What is the story of Kohinoor  Koh i Noor  Dia...
# 3  What would happen if the Indian government sto...
# 4  How can I increase the speed of my internet co...
#
# Queries Data Frame:
#
#     query_id                                         query_text  \
# 0      4584                How can ask questions using photos?
# 1      6588  What is Atal Pension Yojana? What are its bene...
# 2     10113      Where is starch digested? How is it digested?
# 3      7957      What is a conjecture? What are some examples?
# 4      5498  What can India do to support the people suffer...
#
#                                                 pure
# 0                How can ask questions using photos
# 1  What is Atal Pension Yojana  What are its bene...
# 2      Where is starch digested  How is it digested
# 3      What is a conjecture  What are some examples
# 4  What can India do to support the people suffer...

# %% [markdown]
# ## b) Now we need to correct the spellings in both queries and documents.
# For each query, which got corrected, we need to display the original and the corrected query on two spearate lines

# %%
# Correct Spellings function ->

# %% [markdown]
# ## c) Now we shall tokenize the words in the documents using spaCy library.
# Also as mentioned in the problem statement we need to remove all words that occur in less than 5 documents or more than 85% of the documents : this forms the vocabulary for the task. Lastly for each document and query, we create the create TF-IDF vectors for obtianing the cosine-similarity scores and further processing.

# %%
# First of all we need to load the NLP spaCy pipeline
nlp = spacy.load("en_core_web_sm")

# Next in order to tokenize the words into a list, we use the mentioned below function for dividing the words into tokens, for each cell of the dataframe a list is returned
def derive_tokens(sentence):
    doc = nlp(sentence)
    tokensList = []
    
    for token in doc:
        word = token.text
        tokensList.append(word)
        
    return tokensList

# Now we apply the above mentioned function to the dataframes
df['tokensList'] = df['pure'].apply(derive_tokens)
queries['tokensList'] = queries['pure'].apply(derive_tokens)

# %%
# Next we shall generate the vocabulary and for that purpose we first need a collection of all tokens used in the docs database
def performFiltrationOfWords(df):
    collectionOfAllWords = []

    for tokens in df['tokensList']:
        for eachToken in tokens:
            collectionOfAllWords.append(eachToken)

    collectionSet = set(collectionOfAllWords)
    mapCollections = {}

    for token in collectionSet:
        mapCollections[token] = collectionOfAllWords.count(token)

    purifiedWords = []
    
    for token in collectionSet:
        if mapCollections[token] >= 5 and mapCollections[token]<= len(df) * 0.85:
            purifiedWords.append(token)
            
    return purifiedWords

filteredWords = performFiltrationOfWords(df)

# We generate a new column tokenList which has the words included in the given vocabulary and then we join those words to form sentences
df['tokensList'] = df['tokensList'].apply(lambda words: [word for word in words if word in filteredWords])
df['sentences'] = df['tokensList'].apply(lambda word: ' '.join(word))
queries['sentences'] = queries['tokensList'].apply(lambda word: ' '.join(word))

# %% [markdown]
# Next we apply the TFIDF function to the Docs and Queries data-frames post preprocessing, in order to create TFIDF vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
tfidfVectorsForDocs = tfidf.fit_transform(df['sentences'])
tfidfVectorsForQueries = tfidf.transform(queries['sentences'])

# %% [markdown]
# ## d) Now for each of the queries, we shall perform the Cosine Pairwise Similarity
# We will be using the sklearn library for the same to calculate the cosine pairwise similarity and along with that we will also be displaying the top 1, top 5 and top 10 most similar documents sorted according to Cosine Similarity scores for eahc query in the Queries dataframe

# %%
from sklearn.metrics.pairwise import cosine_similarity

generateCosineSimilarityMatrix = cosine_similarity(tfidfVectorsForQueries, tfidfVectorsForDocs)

def obtainSimilarDocs(n):
    return generateCosineSimilarityMatrix.argsort(axis=1)[:, -n:][:, ::-1]

def printSimilarDocs(n, documents):
    print(f"\nTop {n} Similar Docs: ")
    for i, indices in enumerate(documents, start=1):
        docText = df.iloc[indices]['doc_text']
        docIndex = df.iloc[indices]['doc_id']
        print(f"Doc ID: {docIndex} : {docText}")
        
# Obtaining the similarity indices and printing them subsequently
topOneSimilarInds = obtainSimilarDocs(1)
topFiveSimilarInds = obtainSimilarDocs(5)
topTenSimilarInds = obtainSimilarDocs(10)

# Running a for loop in order to print all the values:
for i, rows in queries.iterrows():
    query = rows['query_text']
    print(f"\nGiven Query: {query}")
    
    printSimilarDocs(1, topOneSimilarInds[i])
    printSimilarDocs(5, topFiveSimilarInds[i])
    printSimilarDocs(10, topTenSimilarInds[i])
# Out:
# Given Query: How can ask questions using photos?
#
# Top 1 Similar Docs:
# Doc ID: 1377 : What are some of the best photos?
#
# Top 5 Similar Docs:
# Doc ID: 1377 : What are some of the best photos?
# Doc ID: 1782 : What are the best interview questions to ask?
# Doc ID: 9951 : Is there any way to automatically like Instagram photos with hashtags, using software?
# Doc ID: 45 : What are the questions should not ask on Quora?
# Doc ID: 4412 : Why do people have to ask Quora for questions?
#
# Top 10 Similar Docs:
# Doc ID: 1377 : What are some of the best photos?
# Doc ID: 1782 : What are the best interview questions to ask?
# Doc ID: 9951 : Is there any way to automatically like Instagram photos with hashtags, using software?
# Doc ID: 45 : What are the questions should not ask on Quora?
# Doc ID: 4412 : Why do people have to ask Quora for questions?
# Doc ID: 4583 : How do I ask questions with pictures on "Quora"?
# Doc ID: 2603 : What are the best questions to ask a girl while chatting?
# Doc ID: 9179 : How can I make my questions anonymous?
# Doc ID: 2366 : What are good questions for you to ask an interviewer?
# Doc ID: 5546 : Why won't my Instagram photos delete?
#
# Given Query: What is Atal Pension Yojana? What are its benefits?
#
# Top 1 Similar Docs:
# Doc ID: 5065 : What are the benefits of Joint Family?
#
# Top 5 Similar Docs:
# Doc ID: 5065 : What are the benefits of Joint Family?
# Doc ID: 428 : What are the benefits of listing a company in NSE?
# Doc ID: 1916 : What are the benefits of eating avocado?
# Doc ID: 7908 : What are the benefits of Harty capsules made by Lupin Pharmaceuticals?
# Doc ID: 4108 : What benefits do Aadhaar cards grant bearers?
#
# Top 10 Similar Docs:
# Doc ID: 5065 : What are the benefits of Joint Family?
# Doc ID: 428 : What are the benefits of listing a company in NSE?
# Doc ID: 1916 : What are the benefits of eating avocado?
# Doc ID: 7908 : What are the benefits of Harty capsules made by Lupin Pharmaceuticals?
# Doc ID: 4108 : What benefits do Aadhaar cards grant bearers?
# Doc ID: 7129 : What are the benefits of public speaking?
# Doc ID: 1915 : What are health benefits of red lentils?
# Doc ID: 2211 : What are the benefits of learning another language?
# Doc ID: 7627 : What is a sickle cell anemia and what are its symptoms?
# Doc ID: 5257 : What are some short term benefits of a balanced lifestyle?
#
# Given Query: Where is starch digested? How is it digested?
#
# Top 1 Similar Docs:
# Doc ID: 9169 : Where is Nangli Wazidpur?
#
# Top 5 Similar Docs:
# Doc ID: 9169 : Where is Nangli Wazidpur?
# Doc ID: 6249 : Where is Bhutan?
# Doc ID: 9051 : How china is tackling pollution?
# Doc ID: 7612 : How accurate is a 6mm Remington?
# Doc ID: 10114 : How is starch digested?
#
# Top 10 Similar Docs:
# Doc ID: 9169 : Where is Nangli Wazidpur?
# Doc ID: 6249 : Where is Bhutan?
# Doc ID: 9051 : How china is tackling pollution?
# Doc ID: 7612 : How accurate is a 6mm Remington?
# Doc ID: 10114 : How is starch digested?
# Doc ID: 7611 : How accurate is Lawless?
# Doc ID: 9714 : What is log+ (where "+" is a superscript)? Is it the same as ln?
# Doc ID: 2812 : Is ethics bullshit?
# Doc ID: 8676 : Is a calorie a calorie?
# Doc ID: 2023 : Is scientology a fraud?
#
# Given Query: What is a conjecture? What are some examples?
#
# Top 1 Similar Docs:
# Doc ID: 6327 : What are some fungi examples?
#
# Top 5 Similar Docs:
# Doc ID: 6327 : What are some fungi examples?
# Doc ID: 6326 : What are sac fungi? What are some examples?
# Doc ID: 10298 : What are macromolecules? What are some examples?
# Doc ID: 10299 : What are macromolecules, and what are some examples?
# Doc ID: 7956 : What are some examples of a conjecture?
#
# Top 10 Similar Docs:
# Doc ID: 6327 : What are some fungi examples?
# Doc ID: 6326 : What are sac fungi? What are some examples?
# Doc ID: 10298 : What are macromolecules? What are some examples?
# Doc ID: 10299 : What are macromolecules, and what are some examples?
# Doc ID: 7956 : What are some examples of a conjecture?
# Doc ID: 10274 : What are some examples of parasitic bacteria?
# Doc ID: 2214 : What are some examples of disaccharides?
# Doc ID: 10275 : What are some examples for pleomorphic bacteria?
# Doc ID: 3971 : What are some good examples of 4 stanza poems?
# Doc ID: 2213 : What are disaccharides? What are examples of disaccharides?
#
# Given Query: What can India do to support the people suffering from civilian war in Syria?
#
# Top 1 Similar Docs:
# Doc ID: 5497 : What can India do in Syria?
#
# Top 5 Similar Docs:
# Doc ID: 5497 : What can India do in Syria?
# Doc ID: 10149 : How do I Import diamonds from India?
# Doc ID: 8002 : Do you support reservation in private sector in India?
# Doc ID: 5932 : Can a Lenovo K3 Note support VoLTE?
# Doc ID: 6890 : Why do people resort to bullying?
#
# Top 10 Similar Docs:
# Doc ID: 5497 : What can India do in Syria?
# Doc ID: 10149 : How do I Import diamonds from India?
# Doc ID: 8002 : Do you support reservation in private sector in India?
# Doc ID: 5932 : Can a Lenovo K3 Note support VoLTE?
# Doc ID: 6890 : Why do people resort to bullying?
# Doc ID: 8399 : What do people think about India?
# Doc ID: 9517 : Does Instagram support GIFs?
# Doc ID: 621 : Does iPhone 5S support JIO VoLTE?
# Doc ID: 252 : Why does China support Masood Azhar?
# Doc ID: 4906 : What is the best SIP Plan in India?
#
# Given Query: How do introverts enjoy life?
#
# Top 1 Similar Docs:
# Doc ID: 5107 : How do I enjoy the life?
#
# Top 5 Similar Docs:
# Doc ID: 5107 : How do I enjoy the life?
# Doc ID: 7613 : Do introverts enjoy their life?
# Doc ID: 5106 : How can I enjoy my life the most?
# Doc ID: 2178 : Why do some people enjoy giving blowjobs?
# Doc ID: 140 : Are there any people who genuinely enjoy salad with no dressing?
#
# Top 10 Similar Docs:
# Doc ID: 5107 : How do I enjoy the life?
# Doc ID: 7613 : Do introverts enjoy their life?
# Doc ID: 5106 : How can I enjoy my life the most?
# Doc ID: 2178 : Why do some people enjoy giving blowjobs?
# Doc ID: 140 : Are there any people who genuinely enjoy salad with no dressing?
# Doc ID: 6040 : How is life in TIFR?
# Doc ID: 7914 : How do I find heroes in my life?
# Doc ID: 9758 : How is the life of an IES?
# Doc ID: 9200 : How was the life in Satya Yuga?
# Doc ID: 3839 : How do we live a meaningful life?
#
# Given Query: Where does dreams come from?
#
# Top 1 Similar Docs:
# Doc ID: 7302 : Where do dreams come from?
#
# Top 5 Similar Docs:
# Doc ID: 7302 : Where do dreams come from?
# Doc ID: 1086 : What can you do in lucid dreams?
# Doc ID: 7454 : Where does the lone pair come in CH3?
# Doc ID: 8576 : Do your dreams have meanings?
# Doc ID: 8575 : Does dreams have any meaning?
#
# Top 10 Similar Docs:
# Doc ID: 7302 : Where do dreams come from?
# Doc ID: 1086 : What can you do in lucid dreams?
# Doc ID: 7454 : Where does the lone pair come in CH3?
# Doc ID: 8576 : Do your dreams have meanings?
# Doc ID: 8575 : Does dreams have any meaning?
# Doc ID: 466 : Where does the water from the Great Lakes come from, and how does these lakes wildlife compare to Lake Como?
# Doc ID: 465 : Where does the water from the Great Lakes come from, and how does these lakes wildlife compare to Lake Prespa?
# Doc ID: 9199 : Where does the count of 330 million Hindu Gods come from?
# Doc ID: 1909 : What is life without dreams?
# Doc ID: 7430 : What is the power of dreams?
#
# Given Query: Is the lowest sum rule still used in naming organic compounds?
#
# Top 1 Similar Docs:
# Doc ID: 4973 : Is the lowest sum rule still used in naming of organic compounds?
#
# Top 5 Similar Docs:
# Doc ID: 4973 : Is the lowest sum rule still used in naming of organic compounds?
# Doc ID: 2483 : Is a better translation of "exceptio probat regulum" "the exception tests the rule?"
# Doc ID: 8946 : Was British rule in India benevolent?
# Doc ID: 789 : What is Evernote used for?
# Doc ID: 8788 : Is organic food really healthier? Is it more nutritious?
#
# Top 10 Similar Docs:
# Doc ID: 4973 : Is the lowest sum rule still used in naming of organic compounds?
# Doc ID: 2483 : Is a better translation of "exceptio probat regulum" "the exception tests the rule?"
# Doc ID: 8946 : Was British rule in India benevolent?
# Doc ID: 789 : What is Evernote used for?
# Doc ID: 8788 : Is organic food really healthier? Is it more nutritious?
# Doc ID: 2811 : How are stolen passports used?
# Doc ID: 8920 : Why were the Jews rebellious during Roman rule?
# Doc ID: 3216 : Do government engineering colleges follow the 75% attendance rule strictly?
# Doc ID: 2844 : Can touchscreens be used underwater?
# Doc ID: 6026 : What are the different actuators and motors used in biometrics?
#
# Given Query: Kindly tell me whole process of admission at vits Vellore for biotech.i m a bio student in 12..I don't have math there?
#
# Top 1 Similar Docs:
# Doc ID: 2614 : I m bio student how I got admission in vits Vellore in biotechnology and I don't have math in 12?
#
# Top 5 Similar Docs:
# Doc ID: 2614 : I m bio student how I got admission in vits Vellore in biotechnology and I don't have math in 12?
# Doc ID: 4459 : Why don't Mormons clap at church?
# Doc ID: 1523 : What is [math]x[/math] if [math]x+\left(\dfrac{1}{x}\right) =0[/math]?
# Doc ID: 978 : Is noon 12 am or 12 pm?
# Doc ID: 3301 : What is the formula of [math](a+b)^3[/math]?
#
# Top 10 Similar Docs:
# Doc ID: 2614 : I m bio student how I got admission in vits Vellore in biotechnology and I don't have math in 12?
# Doc ID: 4459 : Why don't Mormons clap at church?
# Doc ID: 1523 : What is [math]x[/math] if [math]x+\left(\dfrac{1}{x}\right) =0[/math]?
# Doc ID: 978 : Is noon 12 am or 12 pm?
# Doc ID: 3301 : What is the formula of [math](a+b)^3[/math]?
# Doc ID: 3828 : The roots of the equation [math]x^2+3x-10=0[/math] are [math]\alpha[/math] and [math]\beta[/math], where [math]\alpha<\beta[/math]. What equation are [math]\alpha-1[/math] and [math]\beta+2[/math] the roots of?
# Doc ID: 5079 : I'm bad at math because of the way my high school teachers teach me. Is there any way I can get better at math without the help of teachers?
# Doc ID: 722 : How do I find the zeros of the polynomial function [math]f(x)=\dfrac{1}{2}x^{3}-3x[/math]?
# Doc ID: 2543 : How do I integrate [math]\frac{x^2}{x^2-1}[/math]?
# Doc ID: 6414 : What is the process of crossing over in meiosis?
#
# Given Query: What did Theodore Roosevelt mean when he said, "Black care never sits behind a rider whose pace is fast enough"?
#
# Top 1 Similar Docs:
# Doc ID: 8949 : What did Roosevelt mean by the black care never sits behind a rider whose is fast enough?
#
# Top 5 Similar Docs:
# Doc ID: 8949 : What did Roosevelt mean by the black care never sits behind a rider whose is fast enough?
# Doc ID: 5764 : What did Steve Jobs mean when he compared Microsoft to McDonalds?
# Doc ID: 2651 : What is the story behind the black swan in Swan Lake?
# Doc ID: 2650 : What is the story behind the Black Swan movie?
# Doc ID: 7855 : How did you make money fast?
#
# Top 10 Similar Docs:
# Doc ID: 8949 : What did Roosevelt mean by the black care never sits behind a rider whose is fast enough?
# Doc ID: 5764 : What did Steve Jobs mean when he compared Microsoft to McDonalds?
# Doc ID: 2651 : What is the story behind the black swan in Swan Lake?
# Doc ID: 2650 : What is the story behind the Black Swan movie?
# Doc ID: 7855 : How did you make money fast?
# Doc ID: 2182 : How do you care for guinea pigs?
# Doc ID: 7268 : How did Cristiano Ronaldo learn to run so fast?
# Doc ID: 811 : The guy I'm dating never texts me and I feel like he doesn't care about me but when I see him he shows me he likes me and wants me. Why do I feel this way?
# Doc ID: 9826 : How do I loose weight fast?
# Doc ID: 4788 : Why do I never have nightmares?
#
# Given Query: How does one become more strategic?
#
# Top 1 Similar Docs:
# Doc ID: 8423 : How do I become more ambitious?
#
# Top 5 Similar Docs:
# Doc ID: 8423 : How do I become more ambitious?
# Doc ID: 9657 : How do I become more strategic?
# Doc ID: 10169 : How can one become a good orator?
# Doc ID: 2253 : How does one become a hacker?
# Doc ID: 2759 : How can I become more white?
#
# Top 10 Similar Docs:
# Doc ID: 8423 : How do I become more ambitious?
# Doc ID: 9657 : How do I become more strategic?
# Doc ID: 10169 : How can one become a good orator?
# Doc ID: 2253 : How does one become a hacker?
# Doc ID: 2759 : How can I become more white?
# Doc ID: 7205 : How would one become an ambassador?
# Doc ID: 9381 : How do I become a scriptwriter?
# Doc ID: 9953 : How does one become rich in 2015?
# Doc ID: 9460 : How do you become more intelligent?
# Doc ID: 4875 : How does one ejaculate without achieving orgasm?
#
# Given Query: How can impress a girl who hate me?
#
# Top 1 Similar Docs:
# Doc ID: 2428 : How Can I impress a girl who hate me?
#
# Top 5 Similar Docs:
# Doc ID: 2428 : How Can I impress a girl who hate me?
# Doc ID: 1410 : Why do brothers hate sisters?
# Doc ID: 6497 : Can I impress girls if I wear tight pants?
# Doc ID: 7504 : Can I hate homosexuality but not homosexuals?
# Doc ID: 8515 : My classmate hate me because of my attitude?
#
# Top 10 Similar Docs:
# Doc ID: 2428 : How Can I impress a girl who hate me?
# Doc ID: 1410 : Why do brothers hate sisters?
# Doc ID: 6497 : Can I impress girls if I wear tight pants?
# Doc ID: 7504 : Can I hate homosexuality but not homosexuals?
# Doc ID: 8515 : My classmate hate me because of my attitude?
# Doc ID: 4643 : How do I impress my Would-be Mother-in-law?
# Doc ID: 2197 : Are there Serbs today who don't hate Albanians?
# Doc ID: 1280 : Why do people hate twilight saga?
# Doc ID: 5919 : How can I answer college admissions interview questions to impress the professors?
# Doc ID: 6520 : How can we flirt with a girl?
#
# Given Query: How can I get followers and comments on my blog?
#
# Top 1 Similar Docs:
# Doc ID: 1804 : How can i get more follower on my blog?
#
# Top 5 Similar Docs:
# Doc ID: 1804 : How can i get more follower on my blog?
# Doc ID: 9816 : How could I get more followers on AngelList?
# Doc ID: 9518 : How do I get more followers on Instagram?
# Doc ID: 9817 : How does a startup get more followers on AngelList?
# Doc ID: 3261 : How can I increase traffic on my blog?
#
# Top 10 Similar Docs:
# Doc ID: 1804 : How can i get more follower on my blog?
# Doc ID: 9816 : How could I get more followers on AngelList?
# Doc ID: 9518 : How do I get more followers on Instagram?
# Doc ID: 9817 : How does a startup get more followers on AngelList?
# Doc ID: 3261 : How can I increase traffic on my blog?
# Doc ID: 24 : How can I see all my Youtube comments?
# Doc ID: 5724 : How can I Increase the traffic of my blog?
# Doc ID: 23 : How do I read and find my YouTube comments?
# Doc ID: 1685 : What are your comments on this picture?
# Doc ID: 6217 : Are there any RSS readers that pull comments?
#
# Given Query: How does Quora look to a moderator?
#
# Top 1 Similar Docs:
# Doc ID: 317 : What does the Quora website look like to members of Quora moderation?
#
# Top 5 Similar Docs:
# Doc ID: 317 : What does the Quora website look like to members of Quora moderation?
# Doc ID: 8889 : How does "Free" Translate to Latin?
# Doc ID: 8901 : Does Quora use Deep Learning?
# Doc ID: 7490 : Why do clowns/jokers look so creepy?
# Doc ID: 7748 : What did Victorian-era passports look like?
#
# Top 10 Similar Docs:
# Doc ID: 317 : What does the Quora website look like to members of Quora moderation?
# Doc ID: 8889 : How does "Free" Translate to Latin?
# Doc ID: 8901 : Does Quora use Deep Learning?
# Doc ID: 7490 : Why do clowns/jokers look so creepy?
# Doc ID: 7748 : What did Victorian-era passports look like?
# Doc ID: 4156 : Getting Started on Quora: What is Quora?
# Doc ID: 4611 : How does a capacitor regulate?
# Doc ID: 10268 : How does a skunk spray?
# Doc ID: 3307 : Why does Quora moderation delete questions about Quora moderation?
# Doc ID: 41 : Why do rockets look white?
#
# Given Query: What's your secret to success?
#
# Top 1 Similar Docs:
# Doc ID: 6056 : What is the secret to success?
#
# Top 5 Similar Docs:
# Doc ID: 6056 : What is the secret to success?
# Doc ID: 3494 : Why was Parks and Recreation a success?
# Doc ID: 2506 : Would you share your deepest secret with your spouse?
# Doc ID: 9694 : Does success mean to have money or does money mean to have success?
# Doc ID: 9693 : Does money mean success?
#
# Top 10 Similar Docs:
# Doc ID: 6056 : What is the secret to success?
# Doc ID: 3494 : Why was Parks and Recreation a success?
# Doc ID: 2506 : Would you share your deepest secret with your spouse?
# Doc ID: 9694 : Does success mean to have money or does money mean to have success?
# Doc ID: 9693 : Does money mean success?
# Doc ID: 2507 : What is your secret that you can only share at Quora?
# Doc ID: 5301 : Game of Thrones Season 6 Episode 4: What did the High Sparrow tell Tommen in secret that he repeated to Cersei?
# Doc ID: 6923 : What incident restored your faith in Humanity?
# Doc ID: 5993 : What does Donald Trump's success tell us about the American public?
# Doc ID: 9802 : Since Voldemort never told anyone about his Horcruxes, how did Regulus Black discover his secret?
#
# Given Query: How do I handle fear of change?
#
# Top 1 Similar Docs:
# Doc ID: 7840 : How do I handle the fear of change?
#
# Top 5 Similar Docs:
# Doc ID: 7840 : How do I handle the fear of change?
# Doc ID: 3213 : How many volts can a 30 amp ESC handle?
# Doc ID: 6008 : How do I overcome the fear of uncertainty in life?
# Doc ID: 6007 : How do I overcome my fear of uncertainty in life?
# Doc ID: 7095 : How can I overcome my fear of diseases?
#
# Top 10 Similar Docs:
# Doc ID: 7840 : How do I handle the fear of change?
# Doc ID: 3213 : How many volts can a 30 amp ESC handle?
# Doc ID: 6008 : How do I overcome the fear of uncertainty in life?
# Doc ID: 6007 : How do I overcome my fear of uncertainty in life?
# Doc ID: 7095 : How can I overcome my fear of diseases?
# Doc ID: 6052 : How should I handle my break-up dilemma?
# Doc ID: 1701 : How do I get over the fear of everything?
# Doc ID: 8916 : How we get rid of fear?
# Doc ID: 8915 : How can I overcome the fear of life phobia?
# Doc ID: 9082 : How do I fix my fear of fighting?
#
# Given Query: How important is sex in a relationship?
#
# Top 1 Similar Docs:
# Doc ID: 9732 : Is sex necessary in a relationship?
#
# Top 5 Similar Docs:
# Doc ID: 9732 : Is sex necessary in a relationship?
# Doc ID: 7107 : What is the relationship between E(1/x) and 1/E(x)?
# Doc ID: 7108 : What is the relationship between e and π?
# Doc ID: 5254 : How do I nurture a love relationship?
# Doc ID: 3411 : How can I get satisfied sex?
#
# Top 10 Similar Docs:
# Doc ID: 9732 : Is sex necessary in a relationship?
# Doc ID: 7107 : What is the relationship between E(1/x) and 1/E(x)?
# Doc ID: 7108 : What is the relationship between e and π?
# Doc ID: 5254 : How do I nurture a love relationship?
# Doc ID: 3411 : How can I get satisfied sex?
# Doc ID: 5004 : How important is education?
# Doc ID: 1138 : How does it feel to be in a relationship than being single and how does our life changes when we are in a relationship?
# Doc ID: 3482 : Why is Koundinya Rishi so important?
# Doc ID: 5255 : How do I nurture a loving relationship with myself?
# Doc ID: 4093 : How is culture important in life?
#
# Given Query: How much equity should I get as CTO/co-founder?
#
# Top 1 Similar Docs:
# Doc ID: 4873 : How much equity should I get as CTO?
#
# Top 5 Similar Docs:
# Doc ID: 4873 : How much equity should I get as CTO?
# Doc ID: 6646 : Geology: What does "bauxite is about as weathered as you can get" mean?
# Doc ID: 4375 : How much is a Bob Ross painting worth? How much should I bid on eBay?
# Doc ID: 10233 : How can one get a job as a physicist in NASA?
# Doc ID: 587 : How much money should I raise?
#
# Top 10 Similar Docs:
# Doc ID: 4873 : How much equity should I get as CTO?
# Doc ID: 6646 : Geology: What does "bauxite is about as weathered as you can get" mean?
# Doc ID: 4375 : How much is a Bob Ross painting worth? How much should I bid on eBay?
# Doc ID: 10233 : How can one get a job as a physicist in NASA?
# Doc ID: 587 : How much money should I raise?
# Doc ID: 8958 : When should a dishwasher be repaired and how much does it cost?
# Doc ID: 586 : How much funds should I raise?
# Doc ID: 6797 : How much do IGF1 levels vary throughout the day?
# Doc ID: 1957 : Why is 'fahrenheit 451'  perceived as dystopia?
# Doc ID: 1061 : How much marks should I score in SSC cpo to get Delhi police?
#
# Given Query: Did Tywin sleep with Shae out of pure spite?
#
# Top 1 Similar Docs:
# Doc ID: 2825 : Why does Tywin sleep with Shae in A Storm of Swords?
#
# Top 5 Similar Docs:
# Doc ID: 2825 : Why does Tywin sleep with Shae in A Storm of Swords?
# Doc ID: 8710 : What is sleep sort?
# Doc ID: 771 : What did nicholas piramal do with 17500 cr?
# Doc ID: 7152 : Coffee can interfere with sleep at night?
# Doc ID: 6434 : Is there a way to bypass sleep?
#
# Top 10 Similar Docs:
# Doc ID: 2825 : Why does Tywin sleep with Shae in A Storm of Swords?
# Doc ID: 8710 : What is sleep sort?
# Doc ID: 771 : What did nicholas piramal do with 17500 cr?
# Doc ID: 7152 : Coffee can interfere with sleep at night?
# Doc ID: 6434 : Is there a way to bypass sleep?
# Doc ID: 9124 : How do I exit out of Quora?
# Doc ID: 9013 : What did the Pentagon Papers reveal?
# Doc ID: 1314 : How do get out of Quora?
# Doc ID: 7225 : Can you die from a lack of sleep?
# Doc ID: 1457 : Why did Venuetastic fail?
#
# Given Query: What should someone do to overcome anxiety?
#
# Top 1 Similar Docs:
# Doc ID: 5775 : What can I do to overcome anxiety?
#
# Top 5 Similar Docs:
# Doc ID: 5775 : What can I do to overcome anxiety?
# Doc ID: 6115 : How do I overcome social anxiety in public places?
# Doc ID: 5776 : What do I do to reduce my anxiety?
# Doc ID: 7096 : What should I do to overcome this fear?
# Doc ID: 745 : What should I do to avoid depression and anxiety?
#
# Top 10 Similar Docs:
# Doc ID: 5775 : What can I do to overcome anxiety?
# Doc ID: 6115 : How do I overcome social anxiety in public places?
# Doc ID: 5776 : What do I do to reduce my anxiety?
# Doc ID: 7096 : What should I do to overcome this fear?
# Doc ID: 745 : What should I do to avoid depression and anxiety?
# Doc ID: 2060 : How does someone knows they have social anxiety?
# Doc ID: 7831 : What are the best ways to overcome boredom?
# Doc ID: 8137 : What are good ways to overcome nostalgia?
# Doc ID: 6222 : What should I do to get rid of my anxiety and my low self-esteem?
# Doc ID: 8136 : How can we overcome nostalgia?
#
# Given Query: Why does phase shift take place in the output of the common emitter amplifier when compared to the input signal?
#
# Top 1 Similar Docs:
# Doc ID: 9890 : How does a phase shift occur in common emitter transistor amplifier?
#
# Top 5 Similar Docs:
# Doc ID: 9890 : How does a phase shift occur in common emitter transistor amplifier?
# Doc ID: 7428 : What is phase in waves?
# Doc ID: 7427 : What exactly are in-phase and out-of-phase in terms of waves?
# Doc ID: 4441 : Should I shift the key of C when transposing music?
# Doc ID: 4982 : How does three-phase AC power generated during regenerative braking in trains, get converted back to single-phase AC to be fed back to the catenary wire?
#
# Top 10 Similar Docs:
# Doc ID: 9890 : How does a phase shift occur in common emitter transistor amplifier?
# Doc ID: 7428 : What is phase in waves?
# Doc ID: 7427 : What exactly are in-phase and out-of-phase in terms of waves?
# Doc ID: 4441 : Should I shift the key of C when transposing music?
# Doc ID: 4982 : How does three-phase AC power generated during regenerative braking in trains, get converted back to single-phase AC to be fed back to the catenary wire?
# Doc ID: 2906 : What is the best place to visit in the world? What is the best place to visit in India? What is the best place to visit in Bihar?
# Doc ID: 807 : How does a fetus exhale in the womb?
# Doc ID: 6859 : Why India has few medals in the olympic table when compared to chinese and rest of the world in terms of their population?
# Doc ID: 8775 : What are the keys to the kingdom of contentment?
# Doc ID: 1735 : What are the best films that take place in one room?
#
# Given Query: Why do people say Dhanush (South Indian actor) is ugly? I don't think so.?
#
# Top 1 Similar Docs:
# Doc ID: 7823 : Why do people say Dhanush (South Indian actor) is ugly? I don't think so?
#
# Top 5 Similar Docs:
# Doc ID: 7823 : Why do people say Dhanush (South Indian actor) is ugly? I don't think so?
# Doc ID: 6492 : Why do people say "bless you" whenever someone sneezes?
# Doc ID: 7570 : Why do people say "God bless you"?
# Doc ID: 2990 : What do people think about Indian women?
# Doc ID: 4933 : Why don't we say, "ununderstandable?" After all, we say, "understandable."
#
# Top 10 Similar Docs:
# Doc ID: 7823 : Why do people say Dhanush (South Indian actor) is ugly? I don't think so?
# Doc ID: 6492 : Why do people say "bless you" whenever someone sneezes?
# Doc ID: 7570 : Why do people say "God bless you"?
# Doc ID: 2990 : What do people think about Indian women?
# Doc ID: 4933 : Why don't we say, "ununderstandable?" After all, we say, "understandable."
# Doc ID: 3587 : What do people think of AngelList?
# Doc ID: 2440 : How do you say 1<x<2?
# Doc ID: 5335 : Why do people think computers can't think?
# Doc ID: 8281 : Why do so many people in the U.S. have a chubby stomach?
# Doc ID: 6890 : Why do people resort to bullying?
#
# Given Query: How do I reset my Gmail password when I don't remember my recovery information?
#
# Top 1 Similar Docs:
# Doc ID: 3875 : With a forgotten Gmail password, how do you find an old Gmail password when you don't remember the recovery information?
#
# Top 5 Similar Docs:
# Doc ID: 3875 : With a forgotten Gmail password, how do you find an old Gmail password when you don't remember the recovery information?
# Doc ID: 9443 : How do I reset my Gmail account password?
# Doc ID: 118 : I can't remember my Gmail password or my recovery email. How can I recover my e-mail?
# Doc ID: 6953 : How do I reset my gmail password when they are not highlighting my recovery email option?
# Doc ID: 6952 : How do I recover my lost Gmail password if I don't have the same number and don't remember the recovery email?
#
# Top 10 Similar Docs:
# Doc ID: 3875 : With a forgotten Gmail password, how do you find an old Gmail password when you don't remember the recovery information?
# Doc ID: 9443 : How do I reset my Gmail account password?
# Doc ID: 118 : I can't remember my Gmail password or my recovery email. How can I recover my e-mail?
# Doc ID: 6953 : How do I reset my gmail password when they are not highlighting my recovery email option?
# Doc ID: 6952 : How do I recover my lost Gmail password if I don't have the same number and don't remember the recovery email?
# Doc ID: 10023 : Can I reset my Gmail password without having to change my username?
# Doc ID: 6894 : How do I reset a Gmail password by email?
# Doc ID: 6893 : How do I reset my email password?
# Doc ID: 502 : I do not remember my password to my Gmail account, how can I recover my account?
# Doc ID: 117 : I was suddenly logged off Gmail. I can't remember my Gmail password and just realized the recovery email is no longer alive. What can I do?
#
# Given Query: How can I get rid of cellulite on my stomach?
#
# Top 1 Similar Docs:
# Doc ID: 7989 : How do I get rid of my paranoia?
#
# Top 5 Similar Docs:
# Doc ID: 7989 : How do I get rid of my paranoia?
# Doc ID: 5518 : How can I get rid from my acnes?
# Doc ID: 8030 : How do I get rid of keratosis pilaris?
# Doc ID: 8029 : How do I get rid of keratosis pilaris on my tricep areas?
# Doc ID: 1298 : How can I get rid of man boobs?
#
# Top 10 Similar Docs:
# Doc ID: 7989 : How do I get rid of my paranoia?
# Doc ID: 5518 : How can I get rid from my acnes?
# Doc ID: 8030 : How do I get rid of keratosis pilaris?
# Doc ID: 8029 : How do I get rid of keratosis pilaris on my tricep areas?
# Doc ID: 1298 : How can I get rid of man boobs?
# Doc ID: 6993 : How can I get rid of acne and scars?
# Doc ID: 3282 : How can I get rid of white spiders in my house?
# Doc ID: 7165 : How can I get rid of pimples all over my face?
# Doc ID: 6866 : How do I get rid of fat?
# Doc ID: 9740 : How do I get rid of face pimples?
#
# Given Query: What has been your most embarrassing moment in front of a stranger?
#
# Top 1 Similar Docs:
# Doc ID: 8135 : What was the most embarrassing moment in front of your girlfriend?
#
# Top 5 Similar Docs:
# Doc ID: 8135 : What was the most embarrassing moment in front of your girlfriend?
# Doc ID: 8134 : What is the most embarrassing moment your crush had in front of you?
# Doc ID: 2790 : What is your most embarrassing moment in public?
# Doc ID: 8173 : What is the most embarrassing thing that happened to you in front of your boss?
# Doc ID: 7631 : What is most embrassing moment of your life?
#
# Top 10 Similar Docs:
# Doc ID: 8135 : What was the most embarrassing moment in front of your girlfriend?
# Doc ID: 8134 : What is the most embarrassing moment your crush had in front of you?
# Doc ID: 2790 : What is your most embarrassing moment in public?
# Doc ID: 8173 : What is the most embarrassing thing that happened to you in front of your boss?
# Doc ID: 7631 : What is most embrassing moment of your life?
# Doc ID: 8996 : What are the most embarrassing moments in life?
# Doc ID: 7632 : What are the most embarassing moment in life?
# Doc ID: 2717 : What has been one of the best decisions of your life?
# Doc ID: 6846 : Why AAP’s MLA Dinesh Mohaniya has been arrested?
# Doc ID: 5467 : What is the most embarrassing thing that has ever happened to you in the workplace?
#
# Given Query: How do I rid myself of my paranoia?
#
# Top 1 Similar Docs:
# Doc ID: 7989 : How do I get rid of my paranoia?
#
# Top 5 Similar Docs:
# Doc ID: 7989 : How do I get rid of my paranoia?
# Doc ID: 8030 : How do I get rid of keratosis pilaris?
# Doc ID: 8222 : How should I forgive myself?
# Doc ID: 5518 : How can I get rid from my acnes?
# Doc ID: 8029 : How do I get rid of keratosis pilaris on my tricep areas?
#
# Top 10 Similar Docs:
# Doc ID: 7989 : How do I get rid of my paranoia?
# Doc ID: 8030 : How do I get rid of keratosis pilaris?
# Doc ID: 8222 : How should I forgive myself?
# Doc ID: 5518 : How can I get rid from my acnes?
# Doc ID: 8029 : How do I get rid of keratosis pilaris on my tricep areas?
# Doc ID: 6865 : How do I get rid of the fats covering my muscles all over my body?
# Doc ID: 6866 : How do I get rid of fat?
# Doc ID: 9740 : How do I get rid of face pimples?
# Doc ID: 9739 : How do I get rid of scalp acne?
# Doc ID: 2803 : How do I get rid of severe dandruff?
#
# Given Query: How do I refuse to chose between different things to do in my life?
#
# Top 1 Similar Docs:
# Doc ID: 997 : How is chili different between cultures?
#
# Top 5 Similar Docs:
# Doc ID: 997 : How is chili different between cultures?
# Doc ID: 7153 : How do I to meditate?
# Doc ID: 377 : Is it possible to pursue many different things in life?
# Doc ID: 7914 : How do I find heroes in my life?
# Doc ID: 1743 : What are the best things to do on Halloween?
#
# Top 10 Similar Docs:
# Doc ID: 997 : How is chili different between cultures?
# Doc ID: 7153 : How do I to meditate?
# Doc ID: 377 : Is it possible to pursue many different things in life?
# Doc ID: 7914 : How do I find heroes in my life?
# Doc ID: 1743 : What are the best things to do on Halloween?
# Doc ID: 394 : Why do people collect things?
# Doc ID: 6040 : How is life in TIFR?
# Doc ID: 3149 : How do I ride a bicycle?
# Doc ID: 4612 : How do capacitors regulate?
# Doc ID: 5722 : How do I make my boyfriend pay for my things?
#
# Given Query: Who is better for India, Donald Trump or Hillary Clinton? Why?
#
# Top 1 Similar Docs:
# Doc ID: 8809 : Who would be better for India, Donald Trump or Hillary Clinton?
#
# Top 5 Similar Docs:
# Doc ID: 8809 : Who would be better for India, Donald Trump or Hillary Clinton?
# Doc ID: 6672 : Who will be a better president Donald Trump or Hillary Clinton?
# Doc ID: 6671 : Who is better Trump or Clinton?
# Doc ID: 8624 : Why is Hillary Clinton a better choice than Donald Trump?
# Doc ID: 5550 : How will Hillary Clinton beat Donald Trump?
#
# Top 10 Similar Docs:
# Doc ID: 8809 : Who would be better for India, Donald Trump or Hillary Clinton?
# Doc ID: 6672 : Who will be a better president Donald Trump or Hillary Clinton?
# Doc ID: 6671 : Who is better Trump or Clinton?
# Doc ID: 8624 : Why is Hillary Clinton a better choice than Donald Trump?
# Doc ID: 5550 : How will Hillary Clinton beat Donald Trump?
# Doc ID: 2176 : Why should I not vote for Hillary Clinton or Donald Trump?
# Doc ID: 2175 : Should I vote for Donald Trump or Hillary Clinton?
# Doc ID: 5549 : How does Hillary Clinton view Donald Trump?
# Doc ID: 6306 : Who is the better candidate for being the President of the United States of America: Hillary Clinton or Donald Trump?
# Doc ID: 6307 : In what aspects is Hillary Clinton better than Trump?
#
# Given Query: Will the value of Indian rupee increase after the ban of 500 and 1000 rupee notes?
#
# Top 1 Similar Docs:
# Doc ID: 7311 : How will the ban of 1000 and 500 rupee notes affect the Indian economy?
#
# Top 5 Similar Docs:
# Doc ID: 7311 : How will the ban of 1000 and 500 rupee notes affect the Indian economy?
# Doc ID: 877 : What are your views on ban of 500 and 1000 rupee notes in India?
# Doc ID: 8891 : What will black money owners do after the banning of 500 and 1000 rupee notes?
# Doc ID: 6313 : What are the possible implications of Demonetization of 500 and 1000 rupee notes?
# Doc ID: 2675 : What do you think of the decision by the Indian Government to demonetize 500 and 1000 rupee notes?
#
# Top 10 Similar Docs:
# Doc ID: 7311 : How will the ban of 1000 and 500 rupee notes affect the Indian economy?
# Doc ID: 877 : What are your views on ban of 500 and 1000 rupee notes in India?
# Doc ID: 8891 : What will black money owners do after the banning of 500 and 1000 rupee notes?
# Doc ID: 6313 : What are the possible implications of Demonetization of 500 and 1000 rupee notes?
# Doc ID: 2675 : What do you think of the decision by the Indian Government to demonetize 500 and 1000 rupee notes?
# Doc ID: 6275 : What do you think of the decision by the Indian government to demonetize 500 and 1000 rupee notes?
# Doc ID: 6272 : What will be the effect in Stock market after the Indian Government's decision to demonitize 500 and 1000 rupee notes?
# Doc ID: 2892 : How do you view the Indian government's decision to fight "black money" by scrapping 500 rupee and 1000 rupee notes?
# Doc ID: 7530 : How will the ban on 500 and 1000 rupee note stop black money?
# Doc ID: 6312 : What do you think of the move by the govt to scrap 500 & 1000 rupee notes?
#
# Given Query: Who created the "GOD"?
#
# Top 1 Similar Docs:
# Doc ID: 2756 : If God created the world, who created God?
#
# Top 5 Similar Docs:
# Doc ID: 2756 : If God created the world, who created God?
# Doc ID: 3811 : Where is God when He created the world?
# Doc ID: 700 : When was the Letter J created?
# Doc ID: 3812 : Where is God?
# Doc ID: 8956 : What are the best logos ever created?
#
# Top 10 Similar Docs:
# Doc ID: 2756 : If God created the world, who created God?
# Doc ID: 3811 : Where is God when He created the world?
# Doc ID: 700 : When was the Letter J created?
# Doc ID: 3812 : Where is God?
# Doc ID: 8956 : What are the best logos ever created?
# Doc ID: 2277 : Why do people believe in God? What is the real faith in God? How do you believe God?
# Doc ID: 7625 : What's the meaning of the "Triune God"?
# Doc ID: 489 : If dark energy is created with expansion can infinite of it be created?
# Doc ID: 8206 : If God exists, how can another God exist?
# Doc ID: 5215 : If dark energy is being created with expansion can infinite of it be created?
#
# Given Query: How can I become a billionaire in mindset?
#
# Top 1 Similar Docs:
# Doc ID: 636 : How can I become a billionaire?
#
# Top 5 Similar Docs:
# Doc ID: 636 : How can I become a billionaire?
# Doc ID: 637 : How can I become a billionaire (in finance)?
# Doc ID: 402 : What is the best way to become a billionaire?
# Doc ID: 401 : What is the easiest way to become a billionaire($)?
# Doc ID: 74 : I am a 19 year old guy. How can I become a billionaire in the next 10 years?
#
# Top 10 Similar Docs:
# Doc ID: 636 : How can I become a billionaire?
# Doc ID: 637 : How can I become a billionaire (in finance)?
# Doc ID: 402 : What is the best way to become a billionaire?
# Doc ID: 401 : What is the easiest way to become a billionaire($)?
# Doc ID: 74 : I am a 19 year old guy. How can I become a billionaire in the next 10 years?
# Doc ID: 6477 : How can India become cashless?
# Doc ID: 9381 : How do I become a scriptwriter?
# Doc ID: 2758 : what can i do to become fair?
# Doc ID: 6476 : Can India become cashless?
# Doc ID: 6785 : How can I become a charismatic person?
#
# Given Query: How does the Laravel authentication work?
#
# Top 1 Similar Docs:
# Doc ID: 4439 : How does a kiln work?
#
# Top 5 Similar Docs:
# Doc ID: 4439 : How does a kiln work?
# Doc ID: 6922 : How does the govt of india work?
# Doc ID: 7448 : What is the IoT and how does it work?
# Doc ID: 8633 : How does the respiratory system work?
# Doc ID: 5635 : How do warts/hpv work?
#
# Top 10 Similar Docs:
# Doc ID: 4439 : How does a kiln work?
# Doc ID: 6922 : How does the govt of india work?
# Doc ID: 7448 : What is the IoT and how does it work?
# Doc ID: 8633 : How does the respiratory system work?
# Doc ID: 5635 : How do warts/hpv work?
# Doc ID: 4438 : How do kilns work?
# Doc ID: 6168 : How do nested loops work?
# Doc ID: 7983 : How does Instagram work?
# Doc ID: 8164 : How does the selfie stick work?
# Doc ID: 8362 : What does it entail to work as a Disney princess?
#
# Given Query: What if humans were nocturnal?
#
# Top 1 Similar Docs:
# Doc ID: 7180 : What were Fidel Castro's accomplishments?
#
# Top 5 Similar Docs:
# Doc ID: 7180 : What were Fidel Castro's accomplishments?
# Doc ID: 5800 : Can humans be nocturnal?
# Doc ID: 360 : Do animals (besides humans) kiss?
# Doc ID: 2255 : Who were the Aztec Gods?
# Doc ID: 631 : Who were the creators of trigonometry?
#
# Top 10 Similar Docs:
# Doc ID: 7180 : What were Fidel Castro's accomplishments?
# Doc ID: 5800 : Can humans be nocturnal?
# Doc ID: 360 : Do animals (besides humans) kiss?
# Doc ID: 2255 : Who were the Aztec Gods?
# Doc ID: 631 : Who were the creators of trigonometry?
# Doc ID: 2071 : Other than humans, what are some examples of the smartest mammals?
# Doc ID: 561 : In Ancient Rome, slaves were branded. What happened with the brand mark if they were subsequently liberated?
# Doc ID: 6255 : Future of Work: Will machines replace humans?
# Doc ID: 6949 : What if the Roman Empire Never Fell?
# Doc ID: 10226 : Who were the most notorious usenet trolls?
#
# Given Query: What can be substituted for butter?
#
# Top 1 Similar Docs:
# Doc ID: 4808 : How can I be feminine?
#
# Top 5 Similar Docs:
# Doc ID: 4808 : How can I be feminine?
# Doc ID: 15 : How can I be a good geologist?
# Doc ID: 2124 : How can I be like Jake Williams?
# Doc ID: 9442 : Can being lazy be good for you?
# Doc ID: 444 : What's the PUK for TF64SIMC4?
#
# Top 10 Similar Docs:
# Doc ID: 4808 : How can I be feminine?
# Doc ID: 15 : How can I be a good geologist?
# Doc ID: 2124 : How can I be like Jake Williams?
# Doc ID: 9442 : Can being lazy be good for you?
# Doc ID: 444 : What's the PUK for TF64SIMC4?
# Doc ID: 5083 : Can filler slab be used for high rises?
# Doc ID: 8422 : How can I be more ambitious?
# Doc ID: 5633 : What can be my first question for Quora?
# Doc ID: 2844 : Can touchscreens be used underwater?
# Doc ID: 3438 : Shortcut for c compilation?
#
# Given Query: How much has your salary increased from your first job to today?
#
# Top 1 Similar Docs:
# Doc ID: 8811 : How much has your salary increased from your first job?
#
# Top 5 Similar Docs:
# Doc ID: 8811 : How much has your salary increased from your first job?
# Doc ID: 1485 : What is your job and your salary? Are you satisfied with your current job?
# Doc ID: 6364 : What's it like to work at C1 Financial for your first job?
# Doc ID: 7654 : What's it like to work at Roper Industries for your first job?
# Doc ID: 9306 : What's it like to work at Best Buy for your first job?
#
# Top 10 Similar Docs:
# Doc ID: 8811 : How much has your salary increased from your first job?
# Doc ID: 1485 : What is your job and your salary? Are you satisfied with your current job?
# Doc ID: 6364 : What's it like to work at C1 Financial for your first job?
# Doc ID: 7654 : What's it like to work at Roper Industries for your first job?
# Doc ID: 9306 : What's it like to work at Best Buy for your first job?
# Doc ID: 6923 : What incident restored your faith in Humanity?
# Doc ID: 6700 : How do you stop your Boxer/Pitbull mix from humping your furniture?
# Doc ID: 946 : Operation executive salary in Infosys?
# Doc ID: 6331 : What do you think of your first love?
# Doc ID: 10312 : How traffic increased for websites through backlinks?
#
# Given Query: How is it to work with Satya Nadella?
#
# Top 1 Similar Docs:
# Doc ID: 392 : What is it like to work with an executive recruiter?
#
# Top 5 Similar Docs:
# Doc ID: 392 : What is it like to work with an executive recruiter?
# Doc ID: 7911 : How is it to work as a Management trainee in BlueStar?
# Doc ID: 6482 : What was it like to work with Satya Nadella?
# Doc ID: 7448 : What is the IoT and how does it work?
# Doc ID: 4438 : How do kilns work?
#
# Top 10 Similar Docs:
# Doc ID: 392 : What is it like to work with an executive recruiter?
# Doc ID: 7911 : How is it to work as a Management trainee in BlueStar?
# Doc ID: 6482 : What was it like to work with Satya Nadella?
# Doc ID: 7448 : What is the IoT and how does it work?
# Doc ID: 4438 : How do kilns work?
# Doc ID: 5635 : How do warts/hpv work?
# Doc ID: 6168 : How do nested loops work?
# Doc ID: 9307 : What is it like to work for Best Buy?
# Doc ID: 8362 : What does it entail to work as a Disney princess?
# Doc ID: 4439 : How does a kiln work?
#
# Given Query: What is the difference between transgender man and transgender woman?
#
# Top 1 Similar Docs:
# Doc ID: 3797 : What is the difference between a transgender man and a transgender woman?
#
# Top 5 Similar Docs:
# Doc ID: 3797 : What is the difference between a transgender man and a transgender woman?
# Doc ID: 3702 : How would you, a transgender person, respond to someone who does not believe you are transgender?
# Doc ID: 2270 : What kind of reproductive organs do transgender people have?
# Doc ID: 2271 : How do you view transgender people?
# Doc ID: 2234 : How do we account for transgender people if gender is socially constructed?
#
# Top 10 Similar Docs:
# Doc ID: 3797 : What is the difference between a transgender man and a transgender woman?
# Doc ID: 3702 : How would you, a transgender person, respond to someone who does not believe you are transgender?
# Doc ID: 2270 : What kind of reproductive organs do transgender people have?
# Doc ID: 2271 : How do you view transgender people?
# Doc ID: 2234 : How do we account for transgender people if gender is socially constructed?
# Doc ID: 8414 : Are a Gemini woman and a Libra man compatible?
# Doc ID: 3701 : How can a transgender lesbian who hasn't had genital surgery find a mate?
# Doc ID: 8415 : Would a Gemini man and a Libra woman be compatible?
# Doc ID: 6545 : What is the difference between BPEL, BPMN and BPM?
# Doc ID: 509 : What is the difference between bay, gulf and straits?
#
# Given Query: How and where did feudalism develop?
#
# Top 1 Similar Docs:
# Doc ID: 5039 : Where, why and how did feudalism start?
#
# Top 5 Similar Docs:
# Doc ID: 5039 : Where, why and how did feudalism start?
# Doc ID: 9678 : What is the best way to develop empathy?
# Doc ID: 8472 : How can I develop an Australian accent?
# Doc ID: 8486 : Where did Pizza Hut go from Powai?
# Doc ID: 9169 : Where is Nangli Wazidpur?
#
# Top 10 Similar Docs:
# Doc ID: 5039 : Where, why and how did feudalism start?
# Doc ID: 9678 : What is the best way to develop empathy?
# Doc ID: 8472 : How can I develop an Australian accent?
# Doc ID: 8486 : Where did Pizza Hut go from Powai?
# Doc ID: 9169 : Where is Nangli Wazidpur?
# Doc ID: 6249 : Where is Bhutan?
# Doc ID: 5491 : How should I develop an Android game?
# Doc ID: 4715 : How do I develop more interests in life?
# Doc ID: 1713 : How would I develop an e-commerce website?
# Doc ID: 1258 : How do I develop my presence of mind?
#
# Given Query: How can I observe like Sherlock Holmes?
#
# Top 1 Similar Docs:
# Doc ID: 2124 : How can I be like Jake Williams?
#
# Top 5 Similar Docs:
# Doc ID: 2124 : How can I be like Jake Williams?
# Doc ID: 6254 : How can I think like Sherlock Holmes?
# Doc ID: 414 : What is Jack Dorsey like?
# Doc ID: 7549 : How can I climb Mt. Everest?
# Doc ID: 7154 : How can i meditate?
#
# Top 10 Similar Docs:
# Doc ID: 2124 : How can I be like Jake Williams?
# Doc ID: 6254 : How can I think like Sherlock Holmes?
# Doc ID: 414 : What is Jack Dorsey like?
# Doc ID: 7549 : How can I climb Mt. Everest?
# Doc ID: 7154 : How can i meditate?
# Doc ID: 3867 : How can I unlock iphones?
# Doc ID: 2198 : Why do Serbs like Russians?
# Doc ID: 7842 : How can I speak English like natives?
# Doc ID: 901 : What's it like to be a firefighter?
# Doc ID: 6821 : What's it like to be a pornstar?
#
# Given Query: What causes nuclear reactions in the Sun?
#
# Top 1 Similar Docs:
# Doc ID: 3075 : Where do nuclear reactions occur in the sun? Why do they happen?
#
# Top 5 Similar Docs:
# Doc ID: 3075 : Where do nuclear reactions occur in the sun? Why do they happen?
# Doc ID: 2048 : What causes the burning sensation in a urinary tract infection?
# Doc ID: 1660 : What causes Auto Immune diseases?
# Doc ID: 7389 : What is nuclear fission and nuclear fusion?
# Doc ID: 486 : In "A Raisin in the Sun", why do Walter and Beneatha argue?
#
# Top 10 Similar Docs:
# Doc ID: 3075 : Where do nuclear reactions occur in the sun? Why do they happen?
# Doc ID: 2048 : What causes the burning sensation in a urinary tract infection?
# Doc ID: 1660 : What causes Auto Immune diseases?
# Doc ID: 7389 : What is nuclear fission and nuclear fusion?
# Doc ID: 486 : In "A Raisin in the Sun", why do Walter and Beneatha argue?
# Doc ID: 7390 : What is the difference between nuclear fusion and nuclear fission?
# Doc ID: 8859 : What are the causes of a yellow jelly discharge?
# Doc ID: 8818 : Does HIV causes AIDS?
# Doc ID: 485 : In the play "A Raisin in the Sun", why do Walter ad Beneatha argue?
# Doc ID: 3734 : What were the causes of the Industrial Revolution?
#
# Given Query: What is the best way to memorize notes?
#
# Top 1 Similar Docs:
# Doc ID: 4159 : What is the best way to soak gummy bears in Ciroc vodka?
#
# Top 5 Similar Docs:
# Doc ID: 4159 : What is the best way to soak gummy bears in Ciroc vodka?
# Doc ID: 6837 : What is the best way to make moist bread?
# Doc ID: 5539 : What is the best way to learn astronomy?
# Doc ID: 2441 : What is the best way to say 1?
# Doc ID: 8830 : What are the best way to learn Oracle HRMS modules?
#
# Top 10 Similar Docs:
# Doc ID: 4159 : What is the best way to soak gummy bears in Ciroc vodka?
# Doc ID: 6837 : What is the best way to make moist bread?
# Doc ID: 5539 : What is the best way to learn astronomy?
# Doc ID: 2441 : What is the best way to say 1?
# Doc ID: 8830 : What are the best way to learn Oracle HRMS modules?
# Doc ID: 3038 : What is the best way to prepare for Mu Sigma?
# Doc ID: 9678 : What is the best way to develop empathy?
# Doc ID: 1634 : What is the best way to reduce pollution in india?
# Doc ID: 8400 : What is the best way to learn how to hack (whitehat)?
# Doc ID: 5588 : What is the best toothpaste?
#
# Given Query: Is Syrio Forel a faceless man following Arya around being different people?
#
# Top 1 Similar Docs:
# Doc ID: 4373 : How do I know who are following WordPress blog when it shows different numbers of followers in different pages?
#
# Top 5 Similar Docs:
# Doc ID: 4373 : How do I know who are following WordPress blog when it shows different numbers of followers in different pages?
# Doc ID: 997 : How is chili different between cultures?
# Doc ID: 9534 : How do I make other people want to be around me?
# Doc ID: 6984 : What are some noteworthy things that happened to you in the course of being a promiscuous man?
# Doc ID: 6353 : Which laptop is most suitable with the following specs?
#
# Top 10 Similar Docs:
# Doc ID: 4373 : How do I know who are following WordPress blog when it shows different numbers of followers in different pages?
# Doc ID: 997 : How is chili different between cultures?
# Doc ID: 9534 : How do I make other people want to be around me?
# Doc ID: 6984 : What are some noteworthy things that happened to you in the course of being a promiscuous man?
# Doc ID: 6353 : Which laptop is most suitable with the following specs?
# Doc ID: 2235 : If society reversed gender roles would transgender people be the same people or different people?
# Doc ID: 6352 : Which laptop is the most suitable with the following specs?
# Doc ID: 900 : What is it like being a firefighter?
# Doc ID: 2098 : What is iodimetric titration and how is it different from iodometric titration?
# Doc ID: 9346 : What sunglasses suit a man's face?
#
# ...
# Doc ID: 8362 : What does it entail to work as a Disney princess?
#
# Top 10 Similar Docs:
# Doc ID: 4439 : How does a kiln work?
# Doc ID: 6922 : How does the govt of india work?
# Doc ID: 7448 : What is the IoT and how does it work?
# Doc ID: 7983 : How does Instagram work?
# Doc ID: 8362 : What does it entail to work as a Disney princess?
# Doc ID: 8633 : How does the respiratory system work?
# Doc ID: 6168 : How do nested loops work?
# Doc ID: 5635 : How do warts/hpv work?
# Doc ID: 4438 : How do kilns work?
# Doc ID: 5503 : How does addiction work?
#
# Given Query: What is the greatest mystery in earth?
#
# Top 1 Similar Docs:
# Doc ID: 247 : What is the greatest mystery in the universe?
#
# Top 5 Similar Docs:
# Doc ID: 247 : What is the greatest mystery in the universe?
# Doc ID: 248 : What is the greatest mystery of all time?
# Doc ID: 9079 : Is Earth a prematurely Inhabited Planet?
# Doc ID: 9512 : Which is your greatest achievement?
# Doc ID: 2111 : What were the greatest achievements of the Persian Empire?
#
# Top 10 Similar Docs:
# Doc ID: 247 : What is the greatest mystery in the universe?
# Doc ID: 248 : What is the greatest mystery of all time?
# Doc ID: 9079 : Is Earth a prematurely Inhabited Planet?
# Doc ID: 9512 : Which is your greatest achievement?
# Doc ID: 2111 : What were the greatest achievements of the Persian Empire?
# Doc ID: 3316 : What is the mystery behind the iron piller of Delhi?
# Doc ID: 8094 : What are greatest thriller movies?
# Doc ID: 6426 : Who in the Earth named Earth?
# Doc ID: 9511 : What is your greatest professional achievement?
# Doc ID: 3315 : Miracle: If any, what is the scientific mystery behind the Tilma of the Lady of Guadalupe?
#
# Given Query: What is Fiverr, and how do they make money?
#
# Top 1 Similar Docs:
# Doc ID: 5630 : How do they make smokes?
#
# Top 5 Similar Docs:
# Doc ID: 5630 : How do they make smokes?
# Doc ID: 6929 : How you make money?
# Doc ID: 9879 : How does putlocker make money?
# Doc ID: 8307 : How does Fiverr make money?
# Doc ID: 8619 : How do I make more money?
#
# Top 10 Similar Docs:
# Doc ID: 5630 : How do they make smokes?
# Doc ID: 6929 : How you make money?
# Doc ID: 9879 : How does putlocker make money?
# Doc ID: 8307 : How does Fiverr make money?
# Doc ID: 8619 : How do I make more money?
# Doc ID: 4171 : How do I make money from my Car?
# Doc ID: 5511 : How do I make money online without spending money?
# Doc ID: 569 : How do I to make money online?
# Doc ID: 8037 : How do you make money online?
# Doc ID: 1547 : How do payroll companies make money?
#
# Given Query: What is the best Grand Theft Auto?
#
# Top 1 Similar Docs:
# Doc ID: 7580 : What are some good auto biographies?
#
# Top 5 Similar Docs:
# Doc ID: 7580 : What are some good auto biographies?
# Doc ID: 7581 : What are some good (auto)biographies of prisoners?
# Doc ID: 1659 : Can an auto immune disease cause insomnia?
# Doc ID: 6243 : Which grand theft auto is your favourite?
# Doc ID: 1813 : How do you cancel USAA auto insurance?
#
# Top 10 Similar Docs:
# Doc ID: 7580 : What are some good auto biographies?
# Doc ID: 7581 : What are some good (auto)biographies of prisoners?
# Doc ID: 1659 : Can an auto immune disease cause insomnia?
# Doc ID: 6243 : Which grand theft auto is your favourite?
# Doc ID: 1813 : How do you cancel USAA auto insurance?
# Doc ID: 3403 : What is the best ux resume?
# Doc ID: 5588 : What is the best toothpaste?
# Doc ID: 8267 : What is the best tank in WoT?
# Doc ID: 4722 : What is the best URL shortner extension for Safari?
# Doc ID: 3590 : What are the best Healdsburg wineries?
#
# Given Query: Am I too heavy as a pair skater? 5 ft 108 lb (as of late)!
#
# Top 1 Similar Docs:
# Doc ID: 8481 : I am a pair skater, am I too heavy? 5 ft 108 lb (as of late)!
#
# Top 5 Similar Docs:
# Doc ID: 8481 : I am a pair skater, am I too heavy? 5 ft 108 lb (as of late)!
# Doc ID: 1187 : I want to start my career as a photographer at age of 25. Is it too late?
# Doc ID: 1957 : Why is 'fahrenheit 451'  perceived as dystopia?
# Doc ID: 6692 : Can a new entangled pair be made from a pair of entangled particles without destroying the original entanglement?
# Doc ID: 890 : When is it too late to learn the piano?
#
# Top 10 Similar Docs:
# Doc ID: 8481 : I am a pair skater, am I too heavy? 5 ft 108 lb (as of late)!
# Doc ID: 1187 : I want to start my career as a photographer at age of 25. Is it too late?
# Doc ID: 1957 : Why is 'fahrenheit 451'  perceived as dystopia?
# Doc ID: 6692 : Can a new entangled pair be made from a pair of entangled particles without destroying the original entanglement?
# Doc ID: 890 : When is it too late to learn the piano?
# Doc ID: 6646 : Geology: What does "bauxite is about as weathered as you can get" mean?
# Doc ID: 4377 : Is 21 too late to learn guitar?
# Doc ID: 7454 : Where does the lone pair come in CH3?
# Doc ID: 6691 : Can an entangled pair have well defined angular momentums and undefined spins?
# Doc ID: 9746 : Can we start a sentence with" as well as"?
#
# Given Query: What would Hillary Clinton do now that the election is over?
#
# Top 1 Similar Docs:
# Doc ID: 859 : What will Hillary Clinton do now?
#
# Top 5 Similar Docs:
# Doc ID: 859 : What will Hillary Clinton do now?
# Doc ID: 3547 : Do you think Hillary Clinton’s pneumonia will affect the election?
# Doc ID: 8879 : How certain are you that Hillary Clinton will win the 2016 election?
# Doc ID: 408 : What are the reasons that people dislike Hillary Clinton?
# Doc ID: 6258 : Why should one vote for Hillary Clinton in the 2016 presidential election?
#
# Top 10 Similar Docs:
# Doc ID: 859 : What will Hillary Clinton do now?
# Doc ID: 3547 : Do you think Hillary Clinton’s pneumonia will affect the election?
# Doc ID: 8879 : How certain are you that Hillary Clinton will win the 2016 election?
# Doc ID: 408 : What are the reasons that people dislike Hillary Clinton?
# Doc ID: 6258 : Why should one vote for Hillary Clinton in the 2016 presidential election?
# Doc ID: 8848 : What will be Hillary Clinton's India policy if she wins the election?
# Doc ID: 9621 : What are Hillary Clinton’s qualifications to be President?
# Doc ID: 2784 : Are there any Republicans voting for Hillary Clinton?
# Doc ID: 407 : Why do people hate Hillary Clinton?
# Doc ID: 5550 : How will Hillary Clinton beat Donald Trump?
#
# Given Query: What are the requirements of modulation?
#
# Top 1 Similar Docs:
# Doc ID: 805 : What are the requirements for selection into MIT?
#
# Top 5 Similar Docs:
# Doc ID: 805 : What are the requirements for selection into MIT?
# Doc ID: 9913 : How can I get internship & what's the requirements?
# Doc ID: 2767 : What are requirements I would need to start my own cafe?
# Doc ID: 9914 : What are the basic requirements to get internship in a company?
# Doc ID: 884 : What are the minimum requirements to enter MIT?
#
# Top 10 Similar Docs:
# Doc ID: 805 : What are the requirements for selection into MIT?
# Doc ID: 9913 : How can I get internship & what's the requirements?
# Doc ID: 2767 : What are requirements I would need to start my own cafe?
# Doc ID: 9914 : What are the basic requirements to get internship in a company?
# Doc ID: 884 : What are the minimum requirements to enter MIT?
# Doc ID: 2411 : What are the minimum GPA and  GRE requirements of Florida State University?
# Doc ID: 5423 : What are the specifications of the Acer Aspire E14?
# Doc ID: 3693 : What are the ethnicities of the cast of 'Impractical Jokers'?
# Doc ID: 9208 : What are predators of seals?
# Doc ID: 8775 : What are the keys to the kingdom of contentment?
#
# Given Query: Can I learn while sleeping? If so, how?
#
# Top 1 Similar Docs:
# Doc ID: 1167 : How can I efficiently learn while sleeping?
#
# Top 5 Similar Docs:
# Doc ID: 1167 : How can I efficiently learn while sleeping?
# Doc ID: 5540 : How can I learn astronomy?
# Doc ID: 1030 : Does covering your head while sleeping cause brain damage?
# Doc ID: 4236 : How can I avoid sleeping during studying?
# Doc ID: 120 : How do I learn french genders?
#
# Top 10 Similar Docs:
# Doc ID: 1167 : How can I efficiently learn while sleeping?
# Doc ID: 5540 : How can I learn astronomy?
# Doc ID: 1030 : Does covering your head while sleeping cause brain damage?
# Doc ID: 4236 : How can I avoid sleeping during studying?
# Doc ID: 120 : How do I learn french genders?
# Doc ID: 7918 : How can learn English?
# Doc ID: 7151 : Does coffee stop or interfere with sleeping?
# Doc ID: 5801 : Can I drink green tea before sleeping?
# Doc ID: 2199 : Can you dream while awake?
# Doc ID: 7268 : How did Cristiano Ronaldo learn to run so fast?
#
# Given Query: Why did Ecuador cut Julian Assange's Internet access?
#
# Top 1 Similar Docs:
# Doc ID: 1381 : In C++, what are access modifiers?
#
# Top 5 Similar Docs:
# Doc ID: 1381 : In C++, what are access modifiers?
# Doc ID: 6302 : Can a Lightsaber cut through Adamantium?
# Doc ID: 6303 : Can a lightsaber cut through Superman?
# Doc ID: 1457 : Why did Venuetastic fail?
# Doc ID: 259 : How do I access Torbox in India?
#
# Top 10 Similar Docs:
# Doc ID: 1381 : In C++, what are access modifiers?
# Doc ID: 6302 : Can a Lightsaber cut through Adamantium?
# Doc ID: 6303 : Can a lightsaber cut through Superman?
# Doc ID: 1457 : Why did Venuetastic fail?
# Doc ID: 259 : How do I access Torbox in India?
# Doc ID: 1392 : What are some cute ways to cut up a skirt?
# Doc ID: 1382 : What are access modifiers in Java?
# Doc ID: 10083 : What is the OBC cut off for IIFT 2015?
# Doc ID: 2003 : What would cause an AMP to cut out?
# Doc ID: 4232 : Why internet is only for 28 days?
#
# Given Query: What are the best ways to prepare for software interviews?
#
# Top 1 Similar Docs:
# Doc ID: 974 : How do I prepare for software interviews?
#
# Top 5 Similar Docs:
# Doc ID: 974 : How do I prepare for software interviews?
# Doc ID: 3370 : What are the best ways to get clients for software startup?
# Doc ID: 3038 : What is the best way to prepare for Mu Sigma?
# Doc ID: 3658 : What are the best ways to learn C#?
# Doc ID: 7831 : What are the best ways to overcome boredom?
#
# Top 10 Similar Docs:
# Doc ID: 974 : How do I prepare for software interviews?
# Doc ID: 3370 : What are the best ways to get clients for software startup?
# Doc ID: 3038 : What is the best way to prepare for Mu Sigma?
# Doc ID: 3658 : What are the best ways to learn C#?
# Doc ID: 7831 : What are the best ways to overcome boredom?
# Doc ID: 2699 : What are the best substitutes for butter extracts?
# Doc ID: 772 : What are the best ways to properly finger yourself?
# Doc ID: 8411 : How do I prepare for emc2?
# Doc ID: 5744 : What is the best Antivirus software to be installed for my Android phone?
# Doc ID: 2559 : What are the best ways to lose weight?
#
# Given Query: Did Ben Affleck shine more than Christian Bale as Batman?
#
# Top 1 Similar Docs:
# Doc ID: 2216 : History of Islam: Why did the Umayyad Caliphate invade Christian territory?
#
# Top 5 Similar Docs:
# Doc ID: 2216 : History of Islam: Why did the Umayyad Caliphate invade Christian territory?
# Doc ID: 9194 : Which elements have more stable chlorides than oxides?
# Doc ID: 1799 : What are the best riddles by the Riddler (Batman)?
# Doc ID: 4404 : Why is QQ more popular than WeChat?
# Doc ID: 1103 : What is the order of the Batman: Arkham games?
#
# Top 10 Similar Docs:
# Doc ID: 2216 : History of Islam: Why did the Umayyad Caliphate invade Christian territory?
# Doc ID: 9194 : Which elements have more stable chlorides than oxides?
# Doc ID: 1799 : What are the best riddles by the Riddler (Batman)?
# Doc ID: 4404 : Why is QQ more popular than WeChat?
# Doc ID: 1103 : What is the order of the Batman: Arkham games?
# Doc ID: 1800 : Who was the best villain in the Nolan Batman films?
# Doc ID: 8563 : Is China more diverse than the USA?
# Doc ID: 912 : What are the life lessons that Batman teaches us?
# Doc ID: 6856 : Are there more colors in a rainbow than the seven usually mentioned?
# Doc ID: 8558 : Is the Philippines a Christian country or is it only officially Catholic? Is the Philippines more Western than other Asian countries?
#
# Given Query: Do Trump voters care that he has reneged all his campaign promises?
#
# Top 1 Similar Docs:
# Doc ID: 2683 : Can Donald Trump keep his campaign promises?
#
# Top 5 Similar Docs:
# Doc ID: 2683 : Can Donald Trump keep his campaign promises?
# Doc ID: 1165 : How will Trump supporters react once they realize he can't or won't keep his campaign promises?
# Doc ID: 5369 : After Brexit, many voters expressed remorse to find that some of the promises wouldn't be kept. How might this compare to Trump's campaign promises?
# Doc ID: 469 : Trump supporters, how do you feel about the way he's walking back his promises?
# Doc ID: 2684 : What promises can Donald Trump keep?
#
# Top 10 Similar Docs:
# Doc ID: 2683 : Can Donald Trump keep his campaign promises?
# Doc ID: 1165 : How will Trump supporters react once they realize he can't or won't keep his campaign promises?
# Doc ID: 5369 : After Brexit, many voters expressed remorse to find that some of the promises wouldn't be kept. How might this compare to Trump's campaign promises?
# Doc ID: 469 : Trump supporters, how do you feel about the way he's walking back his promises?
# Doc ID: 2684 : What promises can Donald Trump keep?
# Doc ID: 470 : Do Trump supporters now expect the president to live up to his promises he so forcefully sold them on?
# Doc ID: 3267 : Do Trump supporters believe his claims about his tax returns, or do they just not care?
# Doc ID: 2182 : How do you care for guinea pigs?
# Doc ID: 8995 : If a guy knows his girlfriend is going through something and he acts like he doesn't have much sympathy about it and then his girlfriend gets the feeling that he's cold hearted, what do you do?
# Doc ID: 2446 : Why do Trump supporters believe that Donald Trump can get his platform through congress?
#
# Given Query: Where can I get best qualities outdoor tiles in Sydney?
#
# Top 1 Similar Docs:
# Doc ID: 2995 : Where can I get best assistance in Sydney for any property purchasing?
#
# Top 5 Similar Docs:
# Doc ID: 2995 : Where can I get best assistance in Sydney for any property purchasing?
# Doc ID: 8207 : Where can I find DJs for festival in Sydney?
# Doc ID: 9191 : Where can I get best fire protection services in Sydney?
# Doc ID: 8283 : Where can I get best domestic and commercial window cleaning service in Sydney?
# Doc ID: 4060 : Where can I get environment friendly pest control service in Sydney?
#
# Top 10 Similar Docs:
# Doc ID: 2995 : Where can I get best assistance in Sydney for any property purchasing?
# Doc ID: 8207 : Where can I find DJs for festival in Sydney?
# Doc ID: 9191 : Where can I get best fire protection services in Sydney?
# Doc ID: 8283 : Where can I get best domestic and commercial window cleaning service in Sydney?
# Doc ID: 4060 : Where can I get environment friendly pest control service in Sydney?
# Doc ID: 9192 : Where can I get emergency fire protection service in Sydney?
# Doc ID: 5096 : Where can I find best quality DJ for festival in Sydney?
# Doc ID: 2458 : Where can I get fantastic value in Sydney for floor tiles?
# Doc ID: 2996 : Where can I get knowledgeable assistance for transfer of property in Sydney?
# Doc ID: 7744 : Where can I get affordable DJ for Birthday party in Sydney?
#
# Given Query: How do I become a good computer science engineer?
#
# Top 1 Similar Docs:
# Doc ID: 1078 : How can I become a true computer science engineer?
#
# Top 5 Similar Docs:
# Doc ID: 1078 : How can I become a true computer science engineer?
# Doc ID: 5653 : Is Elon Musk a good engineer?
# Doc ID: 1404 : What are the differences between computer science and computer engineering?
# Doc ID: 9381 : How do I become a scriptwriter?
# Doc ID: 1082 : What is bss engineer?
#
# Top 10 Similar Docs:
# Doc ID: 1078 : How can I become a true computer science engineer?
# Doc ID: 5653 : Is Elon Musk a good engineer?
# Doc ID: 1404 : What are the differences between computer science and computer engineering?
# Doc ID: 9381 : How do I become a scriptwriter?
# Doc ID: 1082 : What is bss engineer?
# Doc ID: 5008 : What are some good universities in Germany for masters in computer science?
# Doc ID: 9895 : Is Ayurveda a science?
# Doc ID: 10169 : How can one become a good orator?
# Doc ID: 7415 : How can I be a good chemical engineer?
# Doc ID: 1403 : What is the difference between IT and computer science engineering?

# %% [markdown]
# ## e) Calculations of Precision@K Scores

# %%
def getPScores(n):
    pAtOneSum = 0.0
    pAtFiveSum = 0.0
    pAtTenSum = 0.0
    if n==1:
        for i, rows in queries.iterrows():
            generateSetOfRelations = set(qdrel[qdrel['query_id'] == rows['query_id']]['doc_id'])
            topOneDocs = topOneSimilarInds[i]
            dataAtOne = set()
            for j, indices in enumerate(topOneDocs, start=1):
                dataAtOne.add(df.iloc[indices]['doc_id'])
    
            pAtOne = len(generateSetOfRelations.intersection(dataAtOne)) / 1
            pAtOneSum += pAtOne
            queryLength = len(queries)
        return pAtOneSum/queryLength
    
    if n==5:
        for i, rows in queries.iterrows():
            generateSetOfRelations = set(qdrel[qdrel['query_id'] == rows['query_id']]['doc_id'])
            topFiveDocs = topFiveSimilarInds[i]
            dataAtFive = set()
            for j, indices in enumerate(topFiveDocs, start=1):
                dataAtFive.add(df.iloc[indices]['doc_id'])
    
            pAtFive = len(generateSetOfRelations.intersection(dataAtFive)) / 5
            pAtFiveSum += pAtFive
            queryLength = len(queries)
        return pAtFiveSum/queryLength
    
    if n==10:
        for i, rows in queries.iterrows():
            generateSetOfRelations = set(qdrel[qdrel['query_id'] == rows['query_id']]['doc_id'])
            topTenDocs = topTenSimilarInds[i]
            dataAtTen = set()
            for j, indices in enumerate(topTenDocs, start=1):
                dataAtTen.add(df.iloc[indices]['doc_id'])
    
            pAtTen = len(generateSetOfRelations.intersection(dataAtTen)) / 10
            pAtTenSum += pAtTen
            queryLength = len(queries)
        return pAtTenSum/queryLength
        
pAOne = getPScores(1)
pAFive = getPScores(5)
pATen = getPScores(10)

print(f"The Weighted Avg Precision@1 Score is as follows: {pAOne:.5f}")
print(f"The Weighted Avg Precision@5 Score is as follows: {pAFive:.5f}")
print(f"The Weighted Avg Precision@10 Score is as follows: {pATen:.5f}")
# Out:
# The Weighted Avg Precision@1 Score is as follows: 0.59000
# The Weighted Avg Precision@5 Score is as follows: 0.19000
# The Weighted Avg Precision@10 Score is as follows: 0.10100

# %% [markdown]
# ## Task - 2a: Only Stemming :
# SpaCy library has no builtin function for spacing, so we shallbe using the NLTK library for Stemming, essentially NLTK has three widely used Stemmers:
#
# - Porter Stemmer
# - Snowball Stemmer
# - Lancaster Stemmer
#
# For the purpose of this model we will be using PorterStemmer, we will just creating an instance and then apply them to the words in the pre-processing phase. We have implemented all functions here, let us checkout the resultant Precision Scores at the end

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer() 

def performStemmingAndTokenize(sentence):
    doc = nlp(sentence)
    tokensList = []
    
    for token in doc:
        word = st.stem(token.text)
        tokensList.append(word.lower())
        
    return tokensList

df['stemmedTokens'] = df['pure'].apply(performStemmingAndTokenize)
queries['stemmedTokens'] = queries['pure'].apply(performStemmingAndTokenize)

def performFiltrationOfStemmedWords(df):
    collectionOfAllWords = []

    for tokens in df['stemmedTokens']:
        for eachToken in tokens:
            collectionOfAllWords.append(eachToken)

    collectionSet = set(collectionOfAllWords)
    mapCollections = {}

    for token in collectionSet:
        mapCollections[token] = collectionOfAllWords.count(token)

    purifiedWords = []
    
    for token in collectionSet:
        if mapCollections[token] >= 5 and mapCollections[token]<= len(df) * 0.85:
            purifiedWords.append(token)
            
    return purifiedWords

filteredWords = performFiltrationOfStemmedWords(df)

df['stemmedTokens'] = df['stemmedTokens'].apply(lambda words: [word for word in words if word in filteredWords])
df['stemmedSentences'] = df['stemmedTokens'].apply(lambda word: ' '.join(word))
queries['stemmedSentences'] = queries['stemmedTokens'].apply(lambda word: ' '.join(word)) 

tfidf = TfidfVectorizer()
tfidfVectorsForDocs = tfidf.fit_transform(df['stemmedSentences'])
tfidfVectorsForQueries = tfidf.transform(queries['stemmedSentences'])

generateCosineSimilarityMatrix = cosine_similarity(tfidfVectorsForQueries, tfidfVectorsForDocs)
        
topOneSimilarInds = obtainSimilarDocs(1)
topFiveSimilarInds = obtainSimilarDocs(5)
topTenSimilarInds = obtainSimilarDocs(10)
        
pAOne = getPScores(1)
pAFive = getPScores(5)
pATen = getPScores(10)

print(f"The Weighted Avg Precision@1 Score is as follows: {pAOne:.5f}")
print(f"The Weighted Avg Precision@5 Score is as follows: {pAFive:.5f}")
print(f"The Weighted Avg Precision@10 Score is as follows: {pATen:.5f}")
# Out:
# The Weighted Avg Precision@1 Score is as follows: 0.69000
# The Weighted Avg Precision@5 Score is as follows: 0.20000
# The Weighted Avg Precision@10 Score is as follows: 0.10900

# %% [markdown]
# ## Task - 2b: Performing Lemmatization on the Data
# Now in this case, before the pre-processing step, we have the builtin function for a Lemmatizer in the standard spaCy NLP Pipeline, therefore we use it to provide only the base words for each of the words present in the data set

# %%
nlp = spacy.load("en_core_web_sm")
 

def performLemmatizationAndTokenize(sentence):
    doc = nlp(sentence)
    tokensList = []
    
    for token in doc:
        tokensList.append(token.lemma_.lower())
        
    return tokensList

df['lemmatizedTokens'] = df['pure'].apply(performLemmatizationAndTokenize)
queries['lemmatizedTokens'] = queries['pure'].apply(performLemmatizationAndTokenize)

def performFiltrationOfLemmatizedWords(df):
    collectionOfAllWords = []

    for tokens in df['lemmatizedTokens']:
        for eachToken in tokens:
            collectionOfAllWords.append(eachToken)

    collectionSet = set(collectionOfAllWords)
    mapCollections = {}

    for token in collectionSet:
        mapCollections[token] = collectionOfAllWords.count(token)

    purifiedWords = []
    
    for token in collectionSet:
        if mapCollections[token] >= 5 and mapCollections[token]<= len(df) * 0.85:
            purifiedWords.append(token)
            
    return purifiedWords

filteredWords = performFiltrationOfLemmatizedWords(df)

df['lemmatizedTokens'] = df['lemmatizedTokens'].apply(lambda words: [word for word in words if word in filteredWords])
df['lemmatizedSentences'] = df['lemmatizedTokens'].apply(lambda word: ' '.join(word))
queries['lemmatizedSentences'] = queries['lemmatizedTokens'].apply(lambda word: ' '.join(word)) 

tfidf = TfidfVectorizer()
tfidfVectorsForDocs = tfidf.fit_transform(df['lemmatizedSentences'])
tfidfVectorsForQueries = tfidf.transform(queries['lemmatizedSentences'])

generateCosineSimilarityMatrix = cosine_similarity(tfidfVectorsForQueries, tfidfVectorsForDocs)
        
topOneSimilarInds = obtainSimilarDocs(1)
topFiveSimilarInds = obtainSimilarDocs(5)
topTenSimilarInds = obtainSimilarDocs(10)
        
pAOne = getPScores(1)
pAFive = getPScores(5)
pATen = getPScores(10)

print(f"The Weighted Avg Precision@1 Score is as follows: {pAOne:.5f}")
print(f"The Weighted Avg Precision@5 Score is as follows: {pAFive:.5f}")
print(f"The Weighted Avg Precision@10 Score is as follows: {pATen:.5f}")
# Out:
# The Weighted Avg Precision@1 Score is as follows: 0.70000
# The Weighted Avg Precision@5 Score is as follows: 0.19400
# The Weighted Avg Precision@10 Score is as follows: 0.10700

# %% [markdown]
# ## Task - 3: Apply Parts-Of-Speech Tagging and Named Entity Recognition and obtaining the results
# In this case, we shall increase the frequency of the important words like the ones which are NOUNS and the ones which are names of entities like an organisation, person's name etc. We shall multiply in a factor of 2 for nouns and 4 for Named Entities

# %%
def performPOSAndNER(sentence):
    doc = nlp(sentence)
    
    newTokensList = []
    for token in doc:
        if token.pos_ == 'NOUN':
            newTokensList.extend([token.text] * 2)
        elif token.ent_type_ != '':
            newTokensList.extend([token.text] * 4)
        else:
            newTokensList.append(token.lemma_)
    
    return ' '.join(newTokensList)

queries['POSTagged'] = queries['pure'].apply(performPOSAndNER)
df['POSTagged'] = df['pure'].apply(performPOSAndNER)

tfidf = TfidfVectorizer()
tfidfVectorsForDocs = tfidf.fit_transform(df['POSTagged'])
tfidfVectorsForQueries = tfidf.transform(queries['POSTagged'])

generateCosineSimilarityMatrix = cosine_similarity(tfidfVectorsForQueries, tfidfVectorsForDocs)
        
topOneSimilarInds = obtainSimilarDocs(1)
topFiveSimilarInds = obtainSimilarDocs(5)
topTenSimilarInds = obtainSimilarDocs(10)
        
pAOne = getPScores(1)
pAFive = getPScores(5)
pATen = getPScores(10)

print(f"The Weighted Avg Precision@1 Score is as follows: {pAOne:.5f}")
print(f"The Weighted Avg Precision@5 Score is as follows: {pAFive:.5f}")
print(f"The Weighted Avg Precision@10 Score is as follows: {pATen:.5f}")
# Out:
# The Weighted Avg Precision@1 Score is as follows: 0.82000
# The Weighted Avg Precision@5 Score is as follows: 0.20800
# The Weighted Avg Precision@10 Score is as follows: 0.10800

# %% [markdown]
# ## Task - 4: Changing the Parameters in order to get better results
#
# **Changes**
# - **Rectifying the Vocabulary:** instead of blindly flitering out the words which have frequency less than 5 and more than 85000, we will instead be removing all those words which are not a noun or aren't names of recognised entities and then successively, we'll apply lemmatization and then generate the words, also we note that we'll be using the POS Tagging as described above for words in their respective lower-case
#
# > **Justification**: If we print the frequency maps or dictionaries containing the useful words, we observe that certain important words which are essential to the context of the sentence are lost because they have a frequency less than 5 in the whole dataset, this is the reason why we shall be using the above mentioned rectification
