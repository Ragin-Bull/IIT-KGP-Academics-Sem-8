# %% [markdown]
# <h1 style="text-align: center;"> Assignment-2 (Task-1) </h1>
# <h4 style="text-align: center;">  Name: Shatansh Patnaik </h4>
# <h4 style="text-align: center;"> Roll No: 20MA20067 </h4>

# %% [markdown]
# ### Importing the essential libraries needed in the project.

# %%
from collections import defaultdict
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import re
import numpy as np
import csv

# %% [markdown]
# ### Parsing function for parsing the Training as well as Test Data

# %%
def parseData(filePath):
    data = []
    listOfSentences = []
    sentIdList = []

    with open(filePath, 'r') as file:
        sentId = ""

        for line in file:
            line = line.strip()
            if line.startswith("# sent_id"):
                newLine = line.split("=")
                newSentence = newLine[-1].strip()
                sentId = newSentence
                sentIdList.append(sentId)

            elif line.startswith("# text"):
                newLine = line.split("=")
                newSentence = newLine[-1].strip()
                listOfSentences.append(newSentence)


            elif line and not line.startswith("#"):
                divisions = line.split()
                if len(divisions) >= 5:
                    data.append([sentId, divisions[0], divisions[1], divisions[3]])


    return data, listOfSentences, sentIdList

# %% [markdown]
# ### Functions for calculation the word given tag and tag given previous tag probabilities

# %%
def calculateTagProbs(data):
    tagsAfterTagsCounts = defaultdict(lambda : defaultdict(int))
    tagCounts = defaultdict(int)
    tagProbs = defaultdict(lambda : defaultdict(float))

    for i in range(len(data)-1):
        currentTag = data[i][3]
        nextTag = data[i+1][3]
        tagsAfterTagsCounts[currentTag][nextTag] += 1
        tagCounts[currentTag] += 1

    for current, nextDict in tagsAfterTagsCounts.items():
        for nextT, count in nextDict.items():
            tagProbs[current][nextT] = count / tagCounts[current]

    return tagProbs

def calculateWordTagProbs(data):
    vocabularySet = set([])
    wordTagCounts = defaultdict(lambda: defaultdict(int))
    wordTagProbs = defaultdict(lambda: defaultdict(float))
    tagCounts = defaultdict(int)
    wordCounts = defaultdict(int)

    for i in range(len(data)):
        tag = data[i][3]
        word = data[i][2]
        wordTagCounts[tag][word] += 1
        tagCounts[tag]+=1
        vocabularySet.add(word)

    tagCnts = len(tagCounts)

    for tag, words in wordTagCounts.items():
        for word, count in words.items():
            wordTagProbs[tag][word] = (count) / (tagCounts[tag])

    return wordTagProbs, tagCnts, vocabularySet, wordTagCounts, tagCounts

# %% [markdown]
# ### The Viterbi Algorithm which takes in a sentence as an input  would return an array of predicted POS Tags and the total probability

# %%
def viterbi(sentence, tagProbs, wordTagProbs, tagCnts):
    v = [{1: "a"}]
    pathFollowed = {}

    # Base Case:
    for tag in wordTagProbs.keys():
        v[0][tag] = (1/tagCnts)*wordTagProbs[tag][sentence[0]]
        pathFollowed[tag] =[tag]

    # Recursive case
    for t in range(1, len(sentence)):
        v.append({})
        newpath = {}

        for tag in wordTagProbs.keys():
            (prob, state) = max((v[t-1][prevTag] * tagProbs[prevTag][tag] * wordTagProbs[tag][sentence[t]], prevTag)
                                for prevTag in wordTagProbs.keys())
            v[t][tag] = prob
            newpath[tag] = pathFollowed[state] + [tag]

        pathFollowed = newpath


    n = len(sentence) - 1
    (prob, state) = max((v[n][tag], tag) for tag in wordTagProbs.keys())

    return [prob, pathFollowed[state]]

# %% [markdown]
# ### Functions for getting the corresponding tags, and their corresponding sentences, performing Smoothing and getting a Smoothing Count

# %%
def getCorrespondingTags(data):
    dictData = {}
    for smallArr in data:
        key = smallArr[0]
        value = smallArr[3]
        if key in dictData:
            dictData[key].append(value)
        else:
            dictData[key] = [value]

    result = []
    for key, values in dictData.items():
        result.append(values)

    return result

def getCorrespondingSentence(data):
    dictData = {}
    for smallArr in data:
        key = smallArr[0]
        value = smallArr[2]
        if key in dictData:
            dictData[key].append(value)
        else:
            dictData[key] = [value]

    result = []
    for key, values in dictData.items():
        result.append(values)

    return result

def getSmoothingCount(data):
    smoothingCount = 0
    for i in range(len(data)):
        if wordTagProbs[data[i][3]][data[i][2]] == 0:
            smoothingCount+=1
    return smoothingCount

def smoothenTransitionProbability(data, tagProbs, wordTagProbs, countTags, countWords, vocabularySet):
    v = len(vocabularySet)
    for i in range(len(data)):
        wordTagProbs[data[i][3]][data[i][2]] = (countWords[data[i][3]][data[i][2]] + 1) / (v + countTags[data[i][3]])

    for tag, words in wordTagProbs.items():
        for word, prob in words.items():
            wordTagProbs[tag][word] = (countWords[tag][word] + 1) / (v + countTags[tag])

    return wordTagProbs

# %% [markdown]
# ### Calculation of Accuracy, Precision, Recall and F1 Score of the Model

# %%
def calculateEvaluationMetrics(sentences, tagProbs, wordTagProbs, getTags, tagCnts):
    results = []
    for i in range(len(sentences)):
        sentence = sentences[i]
        result = viterbi(sentence, tagProbs, wordTagProbs, tagCnts)[1]
        results.append(result)

    xFlat = [item for sublist in getTags for item in sublist]
    yFlat = [item for sublist in results for item in sublist]

    accuracy = accuracy_score(xFlat, yFlat)
    precision = precision_score(xFlat, yFlat, average='weighted', zero_division=1)
    recall = recall_score(xFlat, yFlat, average='weighted', zero_division=1)
    f1 = f1_score(xFlat, yFlat, average='weighted')

    return accuracy, precision, recall, f1, results

# %% [markdown]
# ### Training Data Metrics Evaluation

# %%
rawTrainingData, trainSentences, sentIdList = parseData("./NLP2/train.txt")
trainingData = [sublist for sublist in rawTrainingData if sublist[1].isdigit()]

tagProbs = calculateTagProbs(trainingData)
wordTagProbs, tagCnts, vocabularySet, wordTagCounts, tagCounts = calculateWordTagProbs(trainingData)

getTags = getCorrespondingTags(trainingData)
smoothingCount = getSmoothingCount(trainingData)
trainingSentences = getCorrespondingSentence(trainingData)
# wordTagProbs = smoothenTransitionProbability(trainingData, tagProbs, wordTagProbs, tagCounts, wordTagCounts)

trainingAccuracy, trainingPrecision, trainingRecall, trainingF1, trainingResults = calculateEvaluationMetrics(trainingSentences, tagProbs, wordTagProbs, getTags, tagCnts)

print(f"The Smoothing Count for the training data is {smoothingCount}")
print(f"The training accuracy is {trainingAccuracy*100} %")
print(f"The training precision is {trainingPrecision*100} %")
print(f"The training recall is {trainingRecall*100} %")
print(f"The training F1 Score is {trainingF1*100} %")
# Out:
# The Smoothing Count for the training data is 0
# The training accuracy is 98.1268448784794 %
# The training precision is 98.15698556577934 %
# The training recall is 98.1268448784794 %
# The training F1 Score is 98.13385851813972 %

# %% [markdown]
# ### Testing Data Metrics Evaluation

# %%
rawTestData, testSentences, listOfTestSentIds = parseData("./NLP2/test.txt")
testData = [sublist for sublist in rawTestData if sublist[1].isdigit()]

getTags = getCorrespondingTags(testData)
smoothingCount = getSmoothingCount(testData)
testSentences = getCorrespondingSentence(testData)
wordTagProbs = smoothenTransitionProbability(testData, tagProbs, wordTagProbs, tagCounts, wordTagCounts, vocabularySet)

testAccuracy, testPrecision, testRecall, testF1, testResults = calculateEvaluationMetrics(testSentences, tagProbs, wordTagProbs, getTags, tagCnts)

print(f"The Smoothing Count for the test data is {smoothingCount}")
print(f"The training accuracy is {testAccuracy*100} %")
print(f"The training precision is {testPrecision*100} %")
print(f"The training recall is {testRecall*100} %")
print(f"The training F1 Score is {testF1*100} %")
# Out:
# The Smoothing Count for the test data is 509
# The training accuracy is 86.91460055096418 %
# The training precision is 87.99260138411482 %
# The training recall is 86.91460055096418 %
# The training F1 Score is 86.4908720924295 %

# %%
print(len(trainingResults))
# Out:
# 2000

# %%
print(len(testResults))
# Out:
# 100

# %%
for i in range(len(trainingResults)):
    for j in range(len(trainingResults[i])):
        print(f"{sentIdList[i]}\t{trainingData[j][1]}\t{trainingSentences[i][j]}\t{trainingResults[i][j]}")
# Out:
# GUM_academic_art-1	1	Aesthetic	JJ
# GUM_academic_art-1	2	Appreciation	NN
# GUM_academic_art-1	3	and	CC
# GUM_academic_art-1	4	Spanish	NNP
# GUM_academic_art-1	5	Art	NNP
# GUM_academic_art-1	6	:	:
# GUM_academic_art-2	1	Insights	NNS
# GUM_academic_art-2	2	from	IN
# GUM_academic_art-2	3	Eye	NN
# GUM_academic_art-2	4	-	HYPH
# GUM_academic_art-2	5	Tracking	NN
# GUM_academic_art-3	1	Claire	NNP
# GUM_academic_art-3	2	Bailey	NNP
# GUM_academic_art-3	3	-	HYPH
# GUM_academic_art-3	4	Ross	NNP
# GUM_academic_art-3	5	claire.bailey-ross@port.ac.uk	NNP
# GUM_academic_art-3	6	University	NNP
# GUM_academic_art-3	1	of	IN
# GUM_academic_art-3	2	Portsmouth	NNP
# GUM_academic_art-3	3	,	,
# GUM_academic_art-3	4	United	NNP
# GUM_academic_art-3	5	Kingdom	NNP
# GUM_academic_art-4	1	Andrew	NNP
# GUM_academic_art-4	2	Beresford	NNP
# GUM_academic_art-4	3	a.m.beresford@durham.ac.uk	NNP
# GUM_academic_art-4	4	Durham	NNP
# GUM_academic_art-4	5	University	NNP
# GUM_academic_art-4	6	,	,
# GUM_academic_art-4	1	United	NNP
# GUM_academic_art-4	2	Kingdom	NNP
# GUM_academic_art-5	1	Daniel	NNP
# GUM_academic_art-5	2	Smith	NNP
# GUM_academic_art-5	3	daniel.smith2@durham.ac.uk	NNP
# GUM_academic_art-5	4	Durham	NNP
# GUM_academic_art-5	5	University	NNP
# GUM_academic_art-5	6	,	,
# GUM_academic_art-5	1	United	NNP
# GUM_academic_art-5	2	Kingdom	NNP
# GUM_academic_art-6	1	Claire	NNP
# GUM_academic_art-6	2	Warwick	NNP
# GUM_academic_art-6	3	c.l.h.warwick@durham.ac.uk	NNP
# GUM_academic_art-6	4	Durham	NNP
# GUM_academic_art-6	5	University	NNP
# GUM_academic_art-6	6	,	,
# GUM_academic_art-6	1	United	NNP
# GUM_academic_art-6	2	Kingdom	NNP
# GUM_academic_art-7	1	How	WRB
# GUM_academic_art-7	2	do	VBP
# GUM_academic_art-7	3	people	NNS
# GUM_academic_art-7	4	look	VBP
# GUM_academic_art-7	5	at	IN
# GUM_academic_art-7	6	and	CC
# GUM_academic_art-7	1	experience	NN
# GUM_academic_art-7	2	art	NN
# GUM_academic_art-7	3	?	.
# GUM_academic_art-8	1	Which	WDT
# GUM_academic_art-8	2	elements	NNS
# GUM_academic_art-8	3	of	IN
# GUM_academic_art-8	4	specific	JJ
# GUM_academic_art-8	5	artworks	NNS
# GUM_academic_art-8	6	do	VBP
# GUM_academic_art-8	1	they	PRP
# GUM_academic_art-8	2	focus	VB
# GUM_academic_art-8	3	on	RP
# GUM_academic_art-8	4	?	.
# GUM_academic_art-9	1	Do	VB
# GUM_academic_art-9	2	museum	NN
# GUM_academic_art-9	3	labels	NNS
# GUM_academic_art-9	4	have	VBP
# GUM_academic_art-9	5	an	DT
# GUM_academic_art-9	6	impact	NN
# GUM_academic_art-9	1	on	IN
# GUM_academic_art-9	2	how	WRB
# GUM_academic_art-9	3	people	NNS
# GUM_academic_art-9	4	look	VBP
# GUM_academic_art-9	5	at	IN
# GUM_academic_art-9	1	artworks	NNS
# GUM_academic_art-9	2	?	.
# GUM_academic_art-10	1	The	DT
# GUM_academic_art-10	2	viewing	NN
# GUM_academic_art-10	3	experience	NN
# GUM_academic_art-10	4	of	IN
# GUM_academic_art-10	5	art	NN
# GUM_academic_art-10	6	is	VBZ
# GUM_academic_art-10	1	a	DT
# GUM_academic_art-10	2	complex	JJ
# GUM_academic_art-10	3	one	NN
# GUM_academic_art-10	4	,	,
# GUM_academic_art-10	5	involving	VBG
# GUM_academic_art-10	1	issues	NNS
# GUM_academic_art-10	2	of	IN
# GUM_academic_art-10	3	perception	NN
# GUM_academic_art-10	4	,	,
# GUM_academic_art-10	5	attention	NN
# GUM_academic_art-10	6	,	,
# GUM_academic_art-10	7	memory	NN
# GUM_academic_art-10	8	,	,
# GUM_academic_art-10	9	decision	NN
# GUM_academic_art-10	10	-	HYPH
# GUM_academic_art-10	11	making	VBG
# GUM_academic_art-10	1	,	,
# GUM_academic_art-10	2	affect	VBP
# GUM_academic_art-10	3	,	,
# GUM_academic_art-10	4	and	CC
# GUM_academic_art-10	5	emotion	NN
# GUM_academic_art-10	6	.	.
# GUM_academic_art-11	1	Thus	RB
# GUM_academic_art-11	2	,	,
# GUM_academic_art-11	3	the	DT
# GUM_academic_art-11	4	time	NN
# GUM_academic_art-11	5	it	PRP
# GUM_academic_art-11	6	takes	VBZ
# GUM_academic_art-11	1	and	CC
# GUM_academic_art-11	2	the	DT
# GUM_academic_art-11	3	ways	NNS
# GUM_academic_art-11	4	of	IN
# GUM_academic_art-11	5	visually	RB
# GUM_academic_art-11	1	exploring	VBG
# GUM_academic_art-11	2	an	DT
# GUM_academic_art-11	3	artwork	NN
# GUM_academic_art-11	4	can	MD
# GUM_academic_art-11	5	inform	VB
# GUM_academic_art-11	6	about	IN
# GUM_academic_art-11	7	its	PRP$
# GUM_academic_art-11	8	relevance	NN
# GUM_academic_art-11	9	,	,
# GUM_academic_art-11	10	interestingness	NN
# GUM_academic_art-11	11	,	,
# GUM_academic_art-11	1	and	CC
# GUM_academic_art-11	2	even	RB
# GUM_academic_art-11	3	its	PRP$
# GUM_academic_art-11	4	aesthetic	JJ
# GUM_academic_art-11	5	appeal	NN
# GUM_academic_art-11	6	.	.
# GUM_academic_art-12	1	This	DT
# GUM_academic_art-12	2	paper	NN
# GUM_academic_art-12	3	describes	VBZ
# GUM_academic_art-12	4	a	DT
# GUM_academic_art-12	5	collaborative	JJ
# GUM_academic_art-12	6	pilot	NN
# GUM_academic_art-12	1	project	NN
# GUM_academic_art-12	2	focusing	VBG
# GUM_academic_art-12	3	on	IN
# GUM_academic_art-12	4	a	DT
# GUM_academic_art-12	5	unique	JJ
# GUM_academic_art-12	1	collection	NN
# GUM_academic_art-12	2	of	IN
# GUM_academic_art-12	3	17th	JJ
# GUM_academic_art-12	4	Century	NN
# GUM_academic_art-12	5	Zurbarán	NNP
# GUM_academic_art-12	6	paintings	NNS
# GUM_academic_art-12	7	.	.
# GUM_academic_art-13	1	The	DT
# GUM_academic_art-13	2	Jacob	NNP
# GUM_academic_art-13	3	cycle	NNP
# GUM_academic_art-13	4	at	IN
# GUM_academic_art-13	5	Auckland	NNP
# GUM_academic_art-13	6	Castle	NNP
# GUM_academic_art-13	1	is	VBZ
# GUM_academic_art-13	2	the	DT
# GUM_academic_art-13	3	only	JJ
# GUM_academic_art-13	4	UK	NNP
# GUM_academic_art-13	5	example	NN
# GUM_academic_art-13	1	of	IN
# GUM_academic_art-13	2	a	DT
# GUM_academic_art-13	3	continental	JJ
# GUM_academic_art-13	4	collection	NN
# GUM_academic_art-13	5	preserved	VBN
# GUM_academic_art-13	6	in	IN
# GUM_academic_art-13	7	situ	FW
# GUM_academic_art-13	8	in	IN
# GUM_academic_art-13	9	purpose	NN
# GUM_academic_art-13	10	-	HYPH
# GUM_academic_art-13	11	built	VBN
# GUM_academic_art-13	1	surroundings	NNS
# GUM_academic_art-13	2	.	.
# GUM_academic_art-14	1	While	IN
# GUM_academic_art-14	2	studies	NNS
# GUM_academic_art-14	3	of	IN
# GUM_academic_art-14	4	the	DT
# GUM_academic_art-14	5	psychology	NN
# GUM_academic_art-14	6	of	IN
# GUM_academic_art-14	1	art	NN
# GUM_academic_art-14	2	have	VBP
# GUM_academic_art-14	3	focused	VBN
# GUM_academic_art-14	4	on	IN
# GUM_academic_art-14	5	individual	JJ
# GUM_academic_art-14	1	works	NNS
# GUM_academic_art-14	2	and	CC
# GUM_academic_art-14	3	distinctions	NNS
# GUM_academic_art-14	4	between	IN
# GUM_academic_art-14	5	representative	JJ
# GUM_academic_art-14	6	/	SYM
# GUM_academic_art-14	7	non-representative	JJ
# GUM_academic_art-14	8	topics	NNS
# GUM_academic_art-14	9	,	,
# GUM_academic_art-14	10	no	DT
# GUM_academic_art-14	11	work	NN
# GUM_academic_art-14	1	has	VBZ
# GUM_academic_art-14	2	been	VBN
# GUM_academic_art-14	3	completed	VBN
# GUM_academic_art-14	4	on	IN
# GUM_academic_art-14	5	the	DT
# GUM_academic_art-14	6	aesthetic	JJ
# GUM_academic_art-14	7	appreciation	NN
# GUM_academic_art-14	8	of	IN
# GUM_academic_art-14	1	collections	NNS
# GUM_academic_art-14	2	or	CC
# GUM_academic_art-14	3	of	IN
# GUM_academic_art-14	4	devotional	JJ
# GUM_academic_art-14	5	themes	NNS
# GUM_academic_art-14	6	.	.
# GUM_academic_art-15	1	In	IN
# GUM_academic_art-15	2	this	DT
# GUM_academic_art-15	3	paper	NN
# GUM_academic_art-15	4	,	,
# GUM_academic_art-15	5	we	PRP
# GUM_academic_art-15	6	report	VBP
# GUM_academic_art-15	1	upon	IN
# GUM_academic_art-15	2	the	DT
# GUM_academic_art-15	3	novel	JJ
# GUM_academic_art-15	4	insights	NNS
# GUM_academic_art-15	5	eye	NN
# GUM_academic_art-15	1	-	HYPH
# GUM_academic_art-15	2	tracking	NN
# GUM_academic_art-15	3	techniques	NNS
# GUM_academic_art-15	4	have	VBP
# GUM_academic_art-15	5	provided	VBN
# GUM_academic_art-15	6	into	IN
# GUM_academic_art-15	7	the	DT
# GUM_academic_art-15	8	unconscious	JJ
# GUM_academic_art-15	9	processes	NNS
# GUM_academic_art-15	10	of	IN
# GUM_academic_art-15	11	viewing	VBG
# GUM_academic_art-15	1	the	DT
# GUM_academic_art-15	2	unique	JJ
# GUM_academic_art-15	3	collection	NN
# GUM_academic_art-15	4	of	IN
# GUM_academic_art-15	5	Zurbarán	NNP
# GUM_academic_art-15	6	artworks	NNS
# GUM_academic_art-15	7	.	.
# GUM_academic_art-16	1	The	DT
# GUM_academic_art-16	2	purpose	NN
# GUM_academic_art-16	3	of	IN
# GUM_academic_art-16	4	this	DT
# GUM_academic_art-16	5	pilot	NN
# GUM_academic_art-16	6	study	NN
# GUM_academic_art-16	1	was	VBD
# GUM_academic_art-16	2	to	TO
# GUM_academic_art-16	3	assess	VB
# GUM_academic_art-16	4	the	DT
# GUM_academic_art-16	5	effects	NNS
# GUM_academic_art-16	1	of	IN
# GUM_academic_art-16	2	different	JJ
# GUM_academic_art-16	3	written	JJ
# GUM_academic_art-16	4	interpretation	NN
# GUM_academic_art-16	5	on	IN
# GUM_academic_art-16	6	the	DT
# GUM_academic_art-16	7	visual	JJ
# GUM_academic_art-16	8	exploration	NN
# GUM_academic_art-16	9	of	IN
# GUM_academic_art-16	10	artworks	NNS
# GUM_academic_art-16	11	.	.
# GUM_academic_art-17	1	We	PRP
# GUM_academic_art-17	2	will	MD
# GUM_academic_art-17	3	discuss	VB
# GUM_academic_art-17	4	the	DT
# GUM_academic_art-17	5	potential	JJ
# GUM_academic_art-17	6	implications	NNS
# GUM_academic_art-17	1	of	IN
# GUM_academic_art-17	2	these	DT
# GUM_academic_art-17	3	techniques	NNS
# GUM_academic_art-17	4	and	CC
# GUM_academic_art-17	5	our	PRP$
# GUM_academic_art-17	1	understanding	NN
# GUM_academic_art-17	2	of	IN
# GUM_academic_art-17	3	visual	JJ
# GUM_academic_art-17	4	behaviours	NNS
# GUM_academic_art-17	5	on	IN
# GUM_academic_art-17	6	museum	NN
# GUM_academic_art-17	7	and	CC
# GUM_academic_art-17	8	gallery	NN
# GUM_academic_art-17	9	practice	NN
# GUM_academic_art-17	10	.	.
# GUM_academic_art-18	1	The	DT
# GUM_academic_art-18	2	project	NN
# GUM_academic_art-18	3	brings	VBZ
# GUM_academic_art-18	4	together	RB
# GUM_academic_art-18	5	established	VBN
# GUM_academic_art-18	6	research	NN
# GUM_academic_art-18	1	strengths	NNS
# GUM_academic_art-18	2	in	IN
# GUM_academic_art-18	3	Spanish	JJ
# GUM_academic_art-18	4	art	NN
# GUM_academic_art-18	5	history	NN
# GUM_academic_art-18	1	,	,
# GUM_academic_art-18	2	experimental	JJ
# GUM_academic_art-18	3	psychology	NN
# GUM_academic_art-18	4	,	,
# GUM_academic_art-18	5	digital	JJ
# GUM_academic_art-18	6	humanities	NNS
# GUM_academic_art-18	7	,	,
# GUM_academic_art-18	8	and	CC
# GUM_academic_art-18	9	museum	NN
# GUM_academic_art-18	10	studies	NNS
# GUM_academic_art-18	11	to	TO
# GUM_academic_art-18	1	explore	VB
# GUM_academic_art-18	2	,	,
# GUM_academic_art-18	3	using	VBG
# GUM_academic_art-18	4	eye	NN
# GUM_academic_art-18	5	-	HYPH
# GUM_academic_art-18	6	tracking	NN
# GUM_academic_art-18	7	techniques	NNS
# GUM_academic_art-18	8	,	,
# GUM_academic_art-18	1	aesthetic	JJ
# GUM_academic_art-18	2	reactions	NNS
# GUM_academic_art-18	3	to	IN
# GUM_academic_art-18	4	digital	JJ
# GUM_academic_art-18	5	representations	NNS
# GUM_academic_art-18	6	of	IN
# GUM_academic_art-18	7	the	DT
# GUM_academic_art-18	8	individual	JJ
# GUM_academic_art-18	1	Zurbarán	NNP
# GUM_academic_art-18	2	artworks	NNS
# GUM_academic_art-18	3	as	IN
# GUM_academic_art-18	4	well	RB
# GUM_academic_art-18	5	as	IN
# GUM_academic_art-18	6	the	DT
# GUM_academic_art-18	7	significance	NN
# GUM_academic_art-18	8	of	IN
# GUM_academic_art-18	1	the	DT
# GUM_academic_art-18	2	collection	NN
# GUM_academic_art-18	3	as	IN
# GUM_academic_art-18	4	a	DT
# GUM_academic_art-18	5	whole	NN
# GUM_academic_art-18	6	.	.
# GUM_academic_art-19	1	Our	PRP$
# GUM_academic_art-19	2	experience	NN
# GUM_academic_art-19	3	of	IN
# GUM_academic_art-19	4	art	NN
# GUM_academic_art-19	5	develops	VBZ
# GUM_academic_art-19	6	from	IN
# GUM_academic_art-19	1	the	DT
# GUM_academic_art-19	2	interaction	NN
# GUM_academic_art-19	3	of	IN
# GUM_academic_art-19	4	several	JJ
# GUM_academic_art-19	5	cognitive	JJ
# GUM_academic_art-19	1	and	CC
# GUM_academic_art-19	2	affective	JJ
# GUM_academic_art-19	3	processes	NNS
# GUM_academic_art-19	4	;	:
# GUM_academic_art-19	5	the	DT
# GUM_academic_art-19	6	beginning	NN
# GUM_academic_art-19	7	of	IN
# GUM_academic_art-19	8	which	WDT
# GUM_academic_art-19	9	is	VBZ
# GUM_academic_art-19	10	a	DT
# GUM_academic_art-19	11	visual	JJ
# GUM_academic_art-19	1	scan	NN
# GUM_academic_art-19	2	of	IN
# GUM_academic_art-19	3	the	DT
# GUM_academic_art-19	4	artwork	NN
# GUM_academic_art-19	5	.	.
# GUM_academic_art-20	1	When	WRB
# GUM_academic_art-20	2	regarding	VBG
# GUM_academic_art-20	3	an	DT
# GUM_academic_art-20	4	artwork	NN
# GUM_academic_art-20	5	,	,
# GUM_academic_art-20	6	a	DT
# GUM_academic_art-20	1	viewer	NN
# GUM_academic_art-20	2	gathers	VBZ
# GUM_academic_art-20	3	information	NN
# GUM_academic_art-20	4	through	IN
# GUM_academic_art-20	5	a	DT
# GUM_academic_art-20	1	series	NN
# GUM_academic_art-20	2	fixations	NNS
# GUM_academic_art-20	3	,	,
# GUM_academic_art-20	4	interspersed	VBN
# GUM_academic_art-20	5	by	IN
# GUM_academic_art-20	6	rapid	JJ
# GUM_academic_art-20	7	movements	NNS
# GUM_academic_art-20	8	of	IN
# GUM_academic_art-20	9	the	DT
# GUM_academic_art-20	10	eye	NN
# GUM_academic_art-20	11	called	VBN
# GUM_academic_art-20	1	saccades	NNS
# GUM_academic_art-20	2	.	.
# GUM_academic_art-21	1	The	DT
# GUM_academic_art-21	2	direction	NN
# GUM_academic_art-21	3	of	IN
# GUM_academic_art-21	4	saccades	NNS
# GUM_academic_art-21	5	is	VBZ
# GUM_academic_art-21	6	determined	VBN
# GUM_academic_art-21	1	by	IN
# GUM_academic_art-21	2	an	DT
# GUM_academic_art-21	3	interaction	NN
# GUM_academic_art-21	4	between	IN
# GUM_academic_art-21	5	the	DT
# GUM_academic_art-21	1	goals	NNS
# GUM_academic_art-21	2	of	IN
# GUM_academic_art-21	3	the	DT
# GUM_academic_art-21	4	observer	NN
# GUM_academic_art-21	5	and	CC
# GUM_academic_art-21	6	the	DT
# GUM_academic_art-21	7	physical	JJ
# GUM_academic_art-21	8	properties	NNS
# GUM_academic_art-21	9	of	IN
# GUM_academic_art-21	10	the	DT
# GUM_academic_art-21	11	different	JJ
# GUM_academic_art-21	1	elements	NNS
# GUM_academic_art-21	2	of	IN
# GUM_academic_art-21	3	the	DT
# GUM_academic_art-21	4	scene	NN
# GUM_academic_art-21	5	(	-LRB-
# GUM_academic_art-21	6	e.g.	FW
# GUM_academic_art-21	7	colour	NN
# GUM_academic_art-21	8	,	,
# GUM_academic_art-21	1	texture	NN
# GUM_academic_art-21	2	,	,
# GUM_academic_art-21	3	brightness	NN
# GUM_academic_art-21	4	etc	FW
# GUM_academic_art-21	5	)	-RRB-
# GUM_academic_art-21	6	.	.
# GUM_academic_art-22	1	Importantly	RB
# GUM_academic_art-22	2	,	,
# GUM_academic_art-22	3	studying	VBG
# GUM_academic_art-22	4	eye	NN
# GUM_academic_art-22	5	movements	NNS
# GUM_academic_art-22	6	offers	VBZ
# GUM_academic_art-22	1	an	DT
# GUM_academic_art-22	2	insight	NN
# GUM_academic_art-22	3	that	WDT
# GUM_academic_art-22	4	does	VBZ
# GUM_academic_art-22	5	not	RB
# GUM_academic_art-22	1	depend	VB
# GUM_academic_art-22	2	on	IN
# GUM_academic_art-22	3	the	DT
# GUM_academic_art-22	4	participants	NNS
# GUM_academic_art-22	5	’	POS
# GUM_academic_art-22	6	beliefs	NNS
# GUM_academic_art-22	7	,	,
# GUM_academic_art-22	8	memories	NNS
# GUM_academic_art-22	9	or	CC
# GUM_academic_art-22	10	subjective	JJ
# GUM_academic_art-22	11	impressions	NNS
# GUM_academic_art-22	1	of	IN
# GUM_academic_art-22	2	the	DT
# GUM_academic_art-22	3	artwork	NN
# GUM_academic_art-22	4	.	.
# GUM_academic_art-23	1	Previous	JJ
# GUM_academic_art-23	2	eye	NN
# GUM_academic_art-23	3	tracking	NN
# GUM_academic_art-23	4	research	NN
# GUM_academic_art-23	5	has	VBZ
# GUM_academic_art-23	6	highlighted	VBN
# GUM_academic_art-23	1	the	DT
# GUM_academic_art-23	2	potential	NN
# GUM_academic_art-23	3	to	TO
# GUM_academic_art-23	4	transform	VB
# GUM_academic_art-23	5	the	DT
# GUM_academic_art-23	1	ways	NNS
# GUM_academic_art-23	2	we	PRP
# GUM_academic_art-23	3	understand	VBP
# GUM_academic_art-23	4	visual	JJ
# GUM_academic_art-23	5	processing	NN
# GUM_academic_art-23	6	in	IN
# GUM_academic_art-23	7	the	DT
# GUM_academic_art-23	8	arts	NNS
# GUM_academic_art-23	9	(	-LRB-
# GUM_academic_art-23	10	see	VB
# GUM_academic_art-23	11	for	IN
# GUM_academic_art-23	1	example	NN
# GUM_academic_art-23	2	Brieber	NNP
# GUM_academic_art-23	3	2014	CD
# GUM_academic_art-23	4	;	:
# GUM_academic_art-23	5	Binderman	NNP
# GUM_academic_art-23	6	et	FW
# GUM_academic_art-23	7	al.	FW
# GUM_academic_art-23	8	,	,
# GUM_academic_art-23	1	2005	CD
# GUM_academic_art-23	2	)	-RRB-
# GUM_academic_art-23	3	and	CC
# GUM_academic_art-23	4	at	IN
# GUM_academic_art-23	5	the	DT
# GUM_academic_art-23	6	same	JJ
# GUM_academic_art-23	7	time	NN
# GUM_academic_art-23	8	offers	VBZ
# GUM_academic_art-23	1	a	DT
# GUM_academic_art-23	2	direct	JJ
# GUM_academic_art-23	3	way	NN
# GUM_academic_art-23	4	of	IN
# GUM_academic_art-23	5	studying	VBG
# GUM_academic_art-23	6	several	JJ
# GUM_academic_art-23	7	important	JJ
# GUM_academic_art-23	8	factors	NNS
# GUM_academic_art-23	1	of	IN
# GUM_academic_art-23	2	a	DT
# GUM_academic_art-23	3	museum	NN
# GUM_academic_art-23	4	visit	NN
# GUM_academic_art-23	5	(	-LRB-
# GUM_academic_art-23	6	Filippini	NNP
# GUM_academic_art-23	7	Fantoni	NNP
# GUM_academic_art-23	8	et	FW
# GUM_academic_art-23	9	al.	FW
# GUM_academic_art-23	1	,	,
# GUM_academic_art-23	2	2013	CD
# GUM_academic_art-23	3	;	:
# GUM_academic_art-23	4	Heidenreich	NNP
# GUM_academic_art-23	5	&	CC
# GUM_academic_art-23	6	Turano	NNP
# GUM_academic_art-23	7	2011	CD
# GUM_academic_art-23	8	;	:
# GUM_academic_art-23	9	Milekic	NNP
# GUM_academic_art-23	10	2010	CD
# GUM_academic_art-23	1	)	-RRB-
# GUM_academic_art-23	2	.	.
# GUM_academic_art-24	1	Zurbarán	NNP
# GUM_academic_art-24	2	’s	POS
# GUM_academic_art-24	3	cycle	NN
# GUM_academic_art-24	4	of	IN
# GUM_academic_art-24	5	Jacob	NNP
# GUM_academic_art-24	6	and	CC
# GUM_academic_art-24	1	his	PRP$
# GUM_academic_art-24	2	Sons	NNS
# GUM_academic_art-24	3	has	VBZ
# GUM_academic_art-24	4	been	VBN
# GUM_academic_art-24	5	on	IN
# GUM_academic_art-24	1	display	NN
# GUM_academic_art-24	2	in	IN
# GUM_academic_art-24	3	the	DT
# GUM_academic_art-24	4	Long	NNP
# GUM_academic_art-24	5	Room	NNP
# GUM_academic_art-24	6	at	IN
# GUM_academic_art-24	7	Auckland	NNP
# GUM_academic_art-24	8	Castle	NNP
# GUM_academic_art-24	9	for	IN
# GUM_academic_art-24	10	over	IN
# GUM_academic_art-24	11	250	CD
# GUM_academic_art-24	1	years	NNS
# GUM_academic_art-24	2	.	.
# GUM_academic_art-25	1	It	PRP
# GUM_academic_art-25	2	is	VBZ
# GUM_academic_art-25	3	the	DT
# GUM_academic_art-25	4	only	JJ
# GUM_academic_art-25	5	cycle	NN
# GUM_academic_art-25	6	to	TO
# GUM_academic_art-25	1	be	VB
# GUM_academic_art-25	2	preserved	VBN
# GUM_academic_art-25	3	in	IN
# GUM_academic_art-25	4	purpose	NN
# GUM_academic_art-25	5	-	HYPH
# GUM_academic_art-25	1	built	VBN
# GUM_academic_art-25	2	surroundings	NNS
# GUM_academic_art-25	3	in	IN
# GUM_academic_art-25	4	the	DT
# GUM_academic_art-25	5	UK	NNP
# GUM_academic_art-25	6	,	,
# GUM_academic_art-25	7	and	CC
# GUM_academic_art-25	8	one	NN
# GUM_academic_art-25	9	of	IN
# GUM_academic_art-25	10	very	RB
# GUM_academic_art-25	11	few	JJ
# GUM_academic_art-25	1	of	IN
# GUM_academic_art-25	2	its	PRP$
# GUM_academic_art-25	3	kind	NN
# GUM_academic_art-25	4	in	IN
# GUM_academic_art-25	5	the	DT
# GUM_academic_art-25	6	world	NN
# GUM_academic_art-25	7	.	.
# GUM_academic_art-26	1	It	PRP
# GUM_academic_art-26	2	has	VBZ
# GUM_academic_art-26	3	a	DT
# GUM_academic_art-26	4	long	JJ
# GUM_academic_art-26	5	history	NN
# GUM_academic_art-26	6	in	IN
# GUM_academic_art-26	1	scholarship	NN
# GUM_academic_art-26	2	(	-LRB-
# GUM_academic_art-26	3	Baron	NNP
# GUM_academic_art-26	4	&	CC
# GUM_academic_art-26	5	Beresford	NNP
# GUM_academic_art-26	1	2014	CD
# GUM_academic_art-26	2	)	-RRB-
# GUM_academic_art-26	3	,	,
# GUM_academic_art-26	4	but	CC
# GUM_academic_art-26	5	many	JJ
# GUM_academic_art-26	6	key	JJ
# GUM_academic_art-26	7	aspects	NNS
# GUM_academic_art-26	8	of	IN
# GUM_academic_art-26	9	its	PRP$
# GUM_academic_art-26	10	production	NN
# GUM_academic_art-26	11	and	CC
# GUM_academic_art-26	1	significance	NN
# GUM_academic_art-26	2	have	VBP
# GUM_academic_art-26	3	not	RB
# GUM_academic_art-26	4	yet	RB
# GUM_academic_art-26	5	been	VBN
# GUM_academic_art-26	6	fully	RB
# GUM_academic_art-26	7	understood	VBN
# GUM_academic_art-26	8	.	.
# GUM_academic_art-27	1	In	IN
# GUM_academic_art-27	2	this	DT
# GUM_academic_art-27	3	study	NN
# GUM_academic_art-27	4	we	PRP
# GUM_academic_art-27	5	used	VBD
# GUM_academic_art-27	6	eye	NN
# GUM_academic_art-27	1	-	HYPH
# GUM_academic_art-27	2	tracking	NN
# GUM_academic_art-27	3	in	IN
# GUM_academic_art-27	4	the	DT
# GUM_academic_art-27	5	first	JJ
# GUM_academic_art-27	1	stage	NN
# GUM_academic_art-27	2	of	IN
# GUM_academic_art-27	3	exploring	VBG
# GUM_academic_art-27	4	audience	NN
# GUM_academic_art-27	5	experience	NN
# GUM_academic_art-27	6	of	IN
# GUM_academic_art-27	7	the	DT
# GUM_academic_art-27	8	extensive	JJ
# GUM_academic_art-27	9	Spanish	JJ
# GUM_academic_art-27	10	art	NN
# GUM_academic_art-27	11	collections	NNS
# GUM_academic_art-27	1	of	IN
# GUM_academic_art-27	2	County	NNP
# GUM_academic_art-27	3	Durham	NNP
# GUM_academic_art-27	4	,	,
# GUM_academic_art-27	5	of	IN
# GUM_academic_art-27	6	which	WDT
# GUM_academic_art-27	7	the	DT
# GUM_academic_art-27	8	13	CD
# GUM_academic_art-27	1	Zurbarán	NNP
# GUM_academic_art-27	2	artworks	NNS
# GUM_academic_art-27	3	(	-LRB-
# GUM_academic_art-27	4	there	EX
# GUM_academic_art-27	5	are	VBP
# GUM_academic_art-27	6	actually	RB
# GUM_academic_art-27	7	only	RB
# GUM_academic_art-27	8	12	CD
# GUM_academic_art-27	1	Zurbarán	NNP
# GUM_academic_art-27	2	artworks	NNS
# GUM_academic_art-27	3	,	,
# GUM_academic_art-27	4	the	DT
# GUM_academic_art-27	5	13th	JJ
# GUM_academic_art-27	6	Benjamin	NNP
# GUM_academic_art-27	7	,	,
# GUM_academic_art-27	8	is	VBZ
# GUM_academic_art-27	1	a	DT
# GUM_academic_art-27	2	copy	NN
# GUM_academic_art-27	3	by	IN
# GUM_academic_art-27	4	Arthur	NNP
# GUM_academic_art-27	5	Pond	NNP
# GUM_academic_art-27	6	)	-RRB-
# GUM_academic_art-27	7	are	VBP
# GUM_academic_art-27	8	a	DT
# GUM_academic_art-27	9	key	JJ
# GUM_academic_art-27	1	part	NN
# GUM_academic_art-27	2	of	IN
# GUM_academic_art-27	3	,	,
# GUM_academic_art-27	4	to	TO
# GUM_academic_art-27	5	investigate	VB
# GUM_academic_art-27	6	the	DT
# GUM_academic_art-27	7	ways	NNS
# GUM_academic_art-27	8	in	IN
# GUM_academic_art-27	9	which	WDT
# GUM_academic_art-27	10	audiences	NNS
# GUM_academic_art-27	1	look	VBP
# GUM_academic_art-27	2	at	IN
# GUM_academic_art-27	3	Spanish	JJ
# GUM_academic_art-27	4	art	NN
# GUM_academic_art-27	5	,	,
# GUM_academic_art-27	6	how	WRB
# GUM_academic_art-27	7	aesthetic	JJ
# GUM_academic_art-27	8	experience	NN
# GUM_academic_art-27	9	is	VBZ
# GUM_academic_art-27	10	evaluated	VBN
# GUM_academic_art-27	11	and	CC
# GUM_academic_art-27	12	whether	IN
# GUM_academic_art-27	13	audiences	NNS
# GUM_academic_art-27	1	can	MD
# GUM_academic_art-27	2	be	VB
# GUM_academic_art-27	3	encouraged	VBN
# GUM_academic_art-27	4	to	TO
# GUM_academic_art-27	5	approach	VB
# GUM_academic_art-27	6	art	NN
# GUM_academic_art-27	7	in	IN
# GUM_academic_art-27	8	different	JJ
# GUM_academic_art-27	9	ways	NNS
# GUM_academic_art-27	10	.	.
# GUM_academic_art-28	1	This	DT
# GUM_academic_art-28	2	pilot	NN
# GUM_academic_art-28	3	project	NN
# GUM_academic_art-28	4	primarily	RB
# GUM_academic_art-28	5	investigated	VBD
# GUM_academic_art-28	6	how	WRB
# GUM_academic_art-28	1	participants	NNS
# GUM_academic_art-28	2	visually	RB
# GUM_academic_art-28	3	explore	VB
# GUM_academic_art-28	4	artworks	NNS
# GUM_academic_art-28	5	and	CC
# GUM_academic_art-28	1	provides	VBZ
# GUM_academic_art-28	2	new	JJ
# GUM_academic_art-28	3	insights	NNS
# GUM_academic_art-28	4	into	IN
# GUM_academic_art-28	5	the	DT
# GUM_academic_art-28	6	potential	JJ
# GUM_academic_art-28	7	eye	NN
# GUM_academic_art-28	8	-	HYPH
# GUM_academic_art-28	9	tracking	NN
# GUM_academic_art-28	10	has	VBZ
# GUM_academic_art-28	11	to	TO
# GUM_academic_art-28	1	transform	VB
# GUM_academic_art-28	2	the	DT
# GUM_academic_art-28	3	ways	NNS
# GUM_academic_art-28	4	we	PRP
# GUM_academic_art-28	5	understand	VBP
# GUM_academic_art-28	6	visual	JJ
# GUM_academic_art-28	7	processing	NN
# GUM_academic_art-28	8	in	IN
# GUM_academic_art-28	1	arts	NNS
# GUM_academic_art-28	2	and	CC
# GUM_academic_art-28	3	culture	NN
# GUM_academic_art-28	4	and	CC
# GUM_academic_art-28	5	at	IN
# GUM_academic_art-28	6	the	DT
# GUM_academic_art-28	7	same	JJ
# GUM_academic_art-28	8	time	NN
# GUM_academic_art-28	1	offer	VBP
# GUM_academic_art-28	2	a	DT
# GUM_academic_art-28	3	direct	JJ
# GUM_academic_art-28	4	way	NN
# GUM_academic_art-28	5	of	IN
# GUM_academic_art-28	6	studying	VBG
# GUM_academic_art-28	7	several	JJ
# GUM_academic_art-28	8	important	JJ
# GUM_academic_art-28	1	factors	NNS
# GUM_academic_art-28	2	of	IN
# GUM_academic_art-28	3	a	DT
# GUM_academic_art-28	4	museum	NN
# GUM_academic_art-28	5	visit	NN
# GUM_academic_art-28	6	,	,
# GUM_academic_art-28	7	namely	RB
# GUM_academic_art-28	8	to	TO
# GUM_academic_art-28	9	assess	VB
# GUM_academic_art-28	1	the	DT
# GUM_academic_art-28	2	effects	NNS
# GUM_academic_art-28	3	of	IN
# GUM_academic_art-28	4	label	NN
# GUM_academic_art-28	5	characteristics	NNS
# GUM_academic_art-28	6	on	IN
# GUM_academic_art-28	7	visitor	NN
# GUM_academic_art-28	8	visual	JJ
# GUM_academic_art-28	9	behaviour	NN
# GUM_academic_art-28	10	.	.
# GUM_academic_census-1	1	1	LS
# GUM_academic_census-1	2	Introduction	NN
# GUM_academic_census-2	1	Tenured	JJ
# GUM_academic_census-2	2	and	CC
# GUM_academic_census-2	3	tenure	NN
# GUM_academic_census-2	4	-	HYPH
# GUM_academic_census-2	5	track	NN
# GUM_academic_census-2	6	university	NN
# GUM_academic_census-2	1	faculty	NN
# GUM_academic_census-2	2	play	VB
# GUM_academic_census-2	3	a	DT
# GUM_academic_census-2	4	special	JJ
# GUM_academic_census-2	5	role	NN
# GUM_academic_census-2	1	in	IN
# GUM_academic_census-2	2	determining	VBG
# GUM_academic_census-2	3	the	DT
# GUM_academic_census-2	4	speed	NN
# GUM_academic_census-2	5	and	CC
# GUM_academic_census-2	6	direction	NN
# GUM_academic_census-2	7	of	IN
# GUM_academic_census-2	8	scientific	JJ
# GUM_academic_census-2	9	progress	NN
# GUM_academic_census-2	10	,	,
# GUM_academic_census-2	11	both	CC
# GUM_academic_census-2	1	directly	RB
# GUM_academic_census-2	2	through	IN
# GUM_academic_census-2	3	their	PRP$
# GUM_academic_census-2	4	research	NN
# GUM_academic_census-2	5	and	CC
# GUM_academic_census-2	6	indirectly	RB
# GUM_academic_census-2	7	through	IN
# GUM_academic_census-2	8	their	PRP$
# GUM_academic_census-2	1	training	NN
# GUM_academic_census-2	2	of	IN
# GUM_academic_census-2	3	new	JJ
# GUM_academic_census-2	4	researchers	NNS
# GUM_academic_census-2	5	.	.
# GUM_academic_census-3	1	Past	JJ
# GUM_academic_census-3	2	studies	NNS
# GUM_academic_census-3	3	establish	VBP
# GUM_academic_census-3	4	that	IN
# GUM_academic_census-3	5	each	DT
# GUM_academic_census-3	6	of	IN
# GUM_academic_census-3	1	these	DT
# GUM_academic_census-3	2	efforts	NNS
# GUM_academic_census-3	3	is	VBZ
# GUM_academic_census-3	4	strongly	RB
# GUM_academic_census-3	5	and	CC
# GUM_academic_census-3	1	positively	RB
# GUM_academic_census-3	2	influenced	VBN
# GUM_academic_census-3	3	through	IN
# GUM_academic_census-3	4	various	JJ
# GUM_academic_census-3	5	forms	NNS
# GUM_academic_census-3	6	of	IN
# GUM_academic_census-3	7	faculty	NN
# GUM_academic_census-3	8	diversity	NN
# GUM_academic_census-3	9	,	,
# GUM_academic_census-3	10	including	VBG
# GUM_academic_census-3	11	ethnic	JJ
# GUM_academic_census-3	1	,	,
# GUM_academic_census-3	2	racial	JJ
# GUM_academic_census-3	3	,	,
# GUM_academic_census-3	4	and	CC
# GUM_academic_census-3	5	gender	NN
# GUM_academic_census-3	6	diversity	NN
# GUM_academic_census-3	7	.	.
# GUM_academic_census-4	1	As	IN
# GUM_academic_census-4	2	an	DT
# GUM_academic_census-4	3	example	NN
# GUM_academic_census-4	4	,	,
# GUM_academic_census-4	5	research	NN
# GUM_academic_census-4	6	shows	VBZ
# GUM_academic_census-4	1	that	DT
# GUM_academic_census-4	2	greater	JJR
# GUM_academic_census-4	3	diversity	NN
# GUM_academic_census-4	4	within	IN
# GUM_academic_census-4	5	a	DT
# GUM_academic_census-4	1	community	NN
# GUM_academic_census-4	2	or	CC
# GUM_academic_census-4	3	group	NN
# GUM_academic_census-4	4	can	MD
# GUM_academic_census-4	5	lead	VB
# GUM_academic_census-4	6	to	IN
# GUM_academic_census-4	7	improved	VBN
# GUM_academic_census-4	8	critical	JJ
# GUM_academic_census-4	9	thinking	NN
# GUM_academic_census-4	10	[	-LRB-
# GUM_academic_census-4	11	1	CD
# GUM_academic_census-4	1	]	-RRB-
# GUM_academic_census-4	2	and	CC
# GUM_academic_census-4	3	more	RBR
# GUM_academic_census-4	4	creative	JJ
# GUM_academic_census-4	5	solutions	NNS
# GUM_academic_census-4	6	to	IN
# GUM_academic_census-4	7	complex	JJ
# GUM_academic_census-4	8	tasks	NNS
# GUM_academic_census-4	1	[	-LRB-
# GUM_academic_census-4	2	2	CD
# GUM_academic_census-4	3	,	,
# GUM_academic_census-4	4	3	CD
# GUM_academic_census-4	5	]	-RRB-
# GUM_academic_census-4	6	by	IN
# GUM_academic_census-4	7	pairing	VBG
# GUM_academic_census-4	8	together	RP
# GUM_academic_census-4	1	individuals	NNS
# GUM_academic_census-4	2	with	IN
# GUM_academic_census-4	3	unique	JJ
# GUM_academic_census-4	4	skillsets	NNS
# GUM_academic_census-4	5	and	CC
# GUM_academic_census-4	6	perspectives	NNS
# GUM_academic_census-4	7	that	WDT
# GUM_academic_census-4	8	complement	VBP
# GUM_academic_census-4	1	and	CC
# GUM_academic_census-4	2	often	RB
# GUM_academic_census-4	3	augment	VBP
# GUM_academic_census-4	4	the	DT
# GUM_academic_census-4	5	abilities	NNS
# GUM_academic_census-4	6	of	IN
# GUM_academic_census-4	7	their	PRP$
# GUM_academic_census-4	8	peers	NNS
# GUM_academic_census-4	9	.	.
# GUM_academic_census-5	1	Additionally	RB
# GUM_academic_census-5	2	,	,
# GUM_academic_census-5	3	diversity	NN
# GUM_academic_census-5	4	has	VBZ
# GUM_academic_census-5	5	been	VBN
# GUM_academic_census-5	6	shown	VBN
# GUM_academic_census-5	1	to	TO
# GUM_academic_census-5	2	produce	VB
# GUM_academic_census-5	3	more	RBR
# GUM_academic_census-5	4	supportive	JJ
# GUM_academic_census-5	5	social	JJ
# GUM_academic_census-5	1	climates	NNS
# GUM_academic_census-5	2	and	CC
# GUM_academic_census-5	3	effective	JJ
# GUM_academic_census-5	4	learning	NN
# GUM_academic_census-5	5	environments	NNS
# GUM_academic_census-5	6	[	-LRB-
# GUM_academic_census-5	7	4	CD
# GUM_academic_census-5	8	]	-RRB-
# GUM_academic_census-5	9	,	,
# GUM_academic_census-5	10	which	WDT
# GUM_academic_census-5	11	can	MD
# GUM_academic_census-5	1	facilitate	VB
# GUM_academic_census-5	2	the	DT
# GUM_academic_census-5	3	mentoring	NN
# GUM_academic_census-5	4	of	IN
# GUM_academic_census-5	5	young	JJ
# GUM_academic_census-5	6	scientists	NNS
# GUM_academic_census-5	7	.	.
# GUM_academic_census-6	1	Despite	IN
# GUM_academic_census-6	2	these	DT
# GUM_academic_census-6	3	positive	JJ
# GUM_academic_census-6	4	effects	NNS
# GUM_academic_census-6	5	,	,
# GUM_academic_census-6	6	however	RB
# GUM_academic_census-6	1	,	,
# GUM_academic_census-6	2	quantifying	VBG
# GUM_academic_census-6	3	the	DT
# GUM_academic_census-6	4	impact	NN
# GUM_academic_census-6	5	of	IN
# GUM_academic_census-6	1	diversity	NN
# GUM_academic_census-6	2	in	IN
# GUM_academic_census-6	3	science	NN
# GUM_academic_census-6	4	remains	VBZ
# GUM_academic_census-6	5	exceedingly	RB
# GUM_academic_census-6	6	difficult	JJ
# GUM_academic_census-6	7	,	,
# GUM_academic_census-6	8	due	JJ
# GUM_academic_census-6	9	in	IN
# GUM_academic_census-6	10	large	JJ
# GUM_academic_census-6	11	part	NN
# GUM_academic_census-6	1	to	IN
# GUM_academic_census-6	2	a	DT
# GUM_academic_census-6	3	lack	NN
# GUM_academic_census-6	4	of	IN
# GUM_academic_census-6	5	comprehensive	JJ
# GUM_academic_census-6	6	data	NNS
# GUM_academic_census-6	7	about	IN
# GUM_academic_census-6	8	the	DT
# GUM_academic_census-6	1	scientific	JJ
# GUM_academic_census-6	2	workforce	NN
# GUM_academic_census-6	3	.	.
# GUM_academic_census-7	1	Measuring	VBG
# GUM_academic_census-7	2	the	DT
# GUM_academic_census-7	3	composition	NN
# GUM_academic_census-7	4	and	CC
# GUM_academic_census-7	5	dynamics	NNS
# GUM_academic_census-7	6	of	IN
# GUM_academic_census-7	1	a	DT
# GUM_academic_census-7	2	scientific	JJ
# GUM_academic_census-7	3	workforce	NN
# GUM_academic_census-7	4	,	,
# GUM_academic_census-7	5	particularly	RB
# GUM_academic_census-7	1	in	IN
# GUM_academic_census-7	2	a	DT
# GUM_academic_census-7	3	rapidly	RB
# GUM_academic_census-7	4	expanding	VBG
# GUM_academic_census-7	5	field	NN
# GUM_academic_census-7	6	like	IN
# GUM_academic_census-7	7	computer	NN
# GUM_academic_census-7	8	science	NN
# GUM_academic_census-7	9	,	,
# GUM_academic_census-7	10	is	VBZ
# GUM_academic_census-7	11	a	DT
# GUM_academic_census-7	1	crucial	JJ
# GUM_academic_census-7	2	first	JJ
# GUM_academic_census-7	3	step	NN
# GUM_academic_census-7	4	toward	IN
# GUM_academic_census-7	5	understanding	NN
# GUM_academic_census-7	6	how	WRB
# GUM_academic_census-7	7	scholarly	JJ
# GUM_academic_census-7	8	research	NN
# GUM_academic_census-7	1	is	VBZ
# GUM_academic_census-7	2	conducted	VBN
# GUM_academic_census-7	3	and	CC
# GUM_academic_census-7	4	how	WRB
# GUM_academic_census-7	5	it	PRP
# GUM_academic_census-7	6	might	MD
# GUM_academic_census-7	7	be	VB
# GUM_academic_census-7	8	enhanced	VBN
# GUM_academic_census-7	1	.	.
# GUM_academic_census-8	1	For	IN
# GUM_academic_census-8	2	many	JJ
# GUM_academic_census-8	3	scientific	JJ
# GUM_academic_census-8	4	fields	NNS
# GUM_academic_census-8	5	,	,
# GUM_academic_census-8	6	however	RB
# GUM_academic_census-8	1	,	,
# GUM_academic_census-8	2	there	EX
# GUM_academic_census-8	3	is	VBZ
# GUM_academic_census-8	4	no	DT
# GUM_academic_census-8	5	central	JJ
# GUM_academic_census-8	1	listing	NN
# GUM_academic_census-8	2	of	IN
# GUM_academic_census-8	3	all	DT
# GUM_academic_census-8	4	tenure	NN
# GUM_academic_census-8	5	-	HYPH
# GUM_academic_census-8	6	track	NN
# GUM_academic_census-8	7	faculty	NN
# GUM_academic_census-8	8	,	,
# GUM_academic_census-8	9	making	VBG
# GUM_academic_census-8	10	it	PRP
# GUM_academic_census-8	11	difficult	JJ
# GUM_academic_census-8	1	to	TO
# GUM_academic_census-8	2	define	VB
# GUM_academic_census-8	3	a	DT
# GUM_academic_census-8	4	rigorous	JJ
# GUM_academic_census-8	5	sample	NN
# GUM_academic_census-8	6	frame	NN
# GUM_academic_census-8	7	for	IN
# GUM_academic_census-8	8	analysis	NN
# GUM_academic_census-8	1	.	.
# GUM_academic_census-9	1	Further	RBR
# GUM_academic_census-9	2	,	,
# GUM_academic_census-9	3	rates	NNS
# GUM_academic_census-9	4	of	IN
# GUM_academic_census-9	5	adoption	NN
# GUM_academic_census-9	6	of	IN
# GUM_academic_census-9	1	services	NNS
# GUM_academic_census-9	2	like	IN
# GUM_academic_census-9	3	GoogleScholar	NNP
# GUM_academic_census-9	4	and	CC
# GUM_academic_census-9	5	ResearchGate	NNP
# GUM_academic_census-9	1	vary	VBP
# GUM_academic_census-9	2	within	IN
# GUM_academic_census-9	3	,	,
# GUM_academic_census-9	4	and	CC
# GUM_academic_census-9	5	across	IN
# GUM_academic_census-9	6	disciplines	NNS
# GUM_academic_census-9	7	.	.
# GUM_academic_census-10	1	For	IN
# GUM_academic_census-10	2	instance	NN
# GUM_academic_census-10	3	,	,
# GUM_academic_census-10	4	gender	NN
# GUM_academic_census-10	5	representation	NN
# GUM_academic_census-10	6	in	IN
# GUM_academic_census-10	1	computing	NN
# GUM_academic_census-10	2	is	VBZ
# GUM_academic_census-10	3	an	DT
# GUM_academic_census-10	4	important	JJ
# GUM_academic_census-10	5	issue	NN
# GUM_academic_census-10	1	with	IN
# GUM_academic_census-10	2	broad	JJ
# GUM_academic_census-10	3	implications	NNS
# GUM_academic_census-10	4	[	-LRB-
# GUM_academic_census-10	5	5	CD
# GUM_academic_census-10	6	]	-RRB-
# GUM_academic_census-10	7	,	,
# GUM_academic_census-10	8	but	CC
# GUM_academic_census-10	9	without	IN
# GUM_academic_census-10	10	a	DT
# GUM_academic_census-10	11	full	JJ
# GUM_academic_census-10	1	census	NN
# GUM_academic_census-10	2	of	IN
# GUM_academic_census-10	3	computing	NN
# GUM_academic_census-10	4	faculty	NN
# GUM_academic_census-10	5	,	,
# GUM_academic_census-10	6	the	DT
# GUM_academic_census-10	7	degree	NN
# GUM_academic_census-10	8	of	IN
# GUM_academic_census-10	1	inequality	NN
# GUM_academic_census-10	2	and	CC
# GUM_academic_census-10	3	its	PRP$
# GUM_academic_census-10	4	possible	JJ
# GUM_academic_census-10	5	sources	NNS
# GUM_academic_census-10	6	are	VBP
# GUM_academic_census-10	7	difficult	JJ
# GUM_academic_census-10	8	to	TO
# GUM_academic_census-10	1	establish	VB
# GUM_academic_census-10	2	[	-LRB-
# GUM_academic_census-10	3	6	CD
# GUM_academic_census-10	4	]	-RRB-
# GUM_academic_census-10	5	.	.
# GUM_academic_census-11	1	Some	DT
# GUM_academic_census-11	2	disciplines	NNS
# GUM_academic_census-11	3	,	,
# GUM_academic_census-11	4	like	IN
# GUM_academic_census-11	5	political	JJ
# GUM_academic_census-11	6	science	NN
# GUM_academic_census-11	1	,	,
# GUM_academic_census-11	2	are	VBP
# GUM_academic_census-11	3	organized	VBN
# GUM_academic_census-11	4	around	IN
# GUM_academic_census-11	5	a	DT
# GUM_academic_census-11	1	single	JJ
# GUM_academic_census-11	2	professional	JJ
# GUM_academic_census-11	3	society	NN
# GUM_academic_census-11	4	,	,
# GUM_academic_census-11	5	whose	WP$
# GUM_academic_census-11	6	membership	NN
# GUM_academic_census-11	7	roll	NN
# GUM_academic_census-11	8	approximates	VBZ
# GUM_academic_census-11	9	a	DT
# GUM_academic_census-11	10	full	JJ
# GUM_academic_census-11	11	census	NN
# GUM_academic_census-11	1	[	-LRB-
# GUM_academic_census-11	2	7	CD
# GUM_academic_census-11	3	]	-RRB-
# GUM_academic_census-11	4	.	.
# GUM_academic_census-12	1	Most	JJS
# GUM_academic_census-12	2	fields	NNS
# GUM_academic_census-12	3	,	,
# GUM_academic_census-12	4	on	IN
# GUM_academic_census-12	5	the	DT
# GUM_academic_census-12	6	other	JJ
# GUM_academic_census-12	1	hand	NN
# GUM_academic_census-12	2	,	,
# GUM_academic_census-12	3	including	VBG
# GUM_academic_census-12	4	computer	NN
# GUM_academic_census-12	5	science	NN
# GUM_academic_census-12	1	,	,
# GUM_academic_census-12	2	lack	VBP
# GUM_academic_census-12	3	a	DT
# GUM_academic_census-12	4	single	JJ
# GUM_academic_census-12	5	all	RB
# GUM_academic_census-12	6	-	HYPH
# GUM_academic_census-12	7	encompassing	VBG
# GUM_academic_census-12	8	organization	NN
# GUM_academic_census-12	9	and	CC
# GUM_academic_census-12	10	membership	NN
# GUM_academic_census-12	11	information	NN
# GUM_academic_census-12	1	is	VBZ
# GUM_academic_census-12	2	instead	RB
# GUM_academic_census-12	3	distributed	VBN
# GUM_academic_census-12	4	across	IN
# GUM_academic_census-12	5	many	JJ
# GUM_academic_census-12	6	disjoint	JJ
# GUM_academic_census-12	7	lists	NNS
# GUM_academic_census-12	8	,	,
# GUM_academic_census-12	1	such	JJ
# GUM_academic_census-12	2	as	IN
# GUM_academic_census-12	3	web	NN
# GUM_academic_census-12	4	-	HYPH
# GUM_academic_census-12	5	based	VBN
# GUM_academic_census-12	6	faculty	NN
# GUM_academic_census-12	7	directories	NNS
# GUM_academic_census-12	8	for	IN
# GUM_academic_census-12	1	individual	JJ
# GUM_academic_census-12	2	departments	NNS
# GUM_academic_census-12	3	.	.
# GUM_academic_census-13	1	Because	IN
# GUM_academic_census-13	2	assembling	VBG
# GUM_academic_census-13	3	such	PDT
# GUM_academic_census-13	4	a	DT
# GUM_academic_census-13	5	full	JJ
# GUM_academic_census-13	6	census	NN
# GUM_academic_census-13	1	is	VBZ
# GUM_academic_census-13	2	difficult	JJ
# GUM_academic_census-13	3	,	,
# GUM_academic_census-13	4	past	JJ
# GUM_academic_census-13	5	studies	NNS
# GUM_academic_census-13	1	have	VBP
# GUM_academic_census-13	2	tended	VBN
# GUM_academic_census-13	3	to	TO
# GUM_academic_census-13	4	avoid	VB
# GUM_academic_census-13	5	this	DT
# GUM_academic_census-13	6	task	NN
# GUM_academic_census-13	7	and	CC
# GUM_academic_census-13	8	have	VBP
# GUM_academic_census-13	9	instead	RB
# GUM_academic_census-13	10	used	VBN
# GUM_academic_census-13	11	samples	NNS
# GUM_academic_census-13	1	of	IN
# GUM_academic_census-13	2	researchers	NNS
# GUM_academic_census-13	3	[	-LRB-
# GUM_academic_census-13	4	8	CD
# GUM_academic_census-13	5	–	SYM
# GUM_academic_census-13	6	11	CD
# GUM_academic_census-13	7	]	-RRB-
# GUM_academic_census-13	8	,	,
# GUM_academic_census-13	1	usually	RB
# GUM_academic_census-13	2	specific	JJ
# GUM_academic_census-13	3	to	IN
# GUM_academic_census-13	4	a	DT
# GUM_academic_census-13	5	particular	JJ
# GUM_academic_census-13	6	field	NN
# GUM_academic_census-13	7	[	-LRB-
# GUM_academic_census-13	8	12	CD
# GUM_academic_census-13	1	–	SYM
# GUM_academic_census-13	2	16	CD
# GUM_academic_census-13	3	]	-RRB-
# GUM_academic_census-13	4	,	,
# GUM_academic_census-13	5	and	CC
# GUM_academic_census-13	6	often	RB
# GUM_academic_census-13	7	focused	VBN
# GUM_academic_census-13	8	on	IN
# GUM_academic_census-13	1	the	DT
# GUM_academic_census-13	2	scientific	JJ
# GUM_academic_census-13	3	elite	NN
# GUM_academic_census-13	4	[	-LRB-
# GUM_academic_census-13	5	17	CD
# GUM_academic_census-13	6	,	,
# GUM_academic_census-13	7	18	CD
# GUM_academic_census-13	8	]	-RRB-
# GUM_academic_census-13	9	.	.
# GUM_academic_census-14	1	Although	IN
# GUM_academic_census-14	2	useful	JJ
# GUM_academic_census-14	3	,	,
# GUM_academic_census-14	4	such	JJ
# GUM_academic_census-14	5	samples	NNS
# GUM_academic_census-14	6	are	VBP
# GUM_academic_census-14	1	not	RB
# GUM_academic_census-14	2	representative	JJ
# GUM_academic_census-14	3	of	IN
# GUM_academic_census-14	4	the	DT
# GUM_academic_census-14	5	scientific	JJ
# GUM_academic_census-14	1	workforce	NN
# GUM_academic_census-14	2	as	IN
# GUM_academic_census-14	3	a	DT
# GUM_academic_census-14	4	whole	NN
# GUM_academic_census-14	5	and	CC
# GUM_academic_census-14	6	thus	RB
# GUM_academic_census-14	7	have	VB
# GUM_academic_census-14	8	limited	JJ
# GUM_academic_census-14	9	generalizability	NN
# GUM_academic_census-14	10	.	.
# GUM_academic_census-15	1	One	CD
# GUM_academic_census-15	2	of	IN
# GUM_academic_census-15	3	the	DT
# GUM_academic_census-15	4	largest	JJS
# GUM_academic_census-15	5	census	NN
# GUM_academic_census-15	6	efforts	NNS
# GUM_academic_census-15	1	to	IN
# GUM_academic_census-15	2	date	NN
# GUM_academic_census-15	3	assembled	VBD
# GUM_academic_census-15	4	,	,
# GUM_academic_census-15	5	by	IN
# GUM_academic_census-15	1	hand	NN
# GUM_academic_census-15	2	,	,
# GUM_academic_census-15	3	a	DT
# GUM_academic_census-15	4	nearly	RB
# GUM_academic_census-15	5	complete	JJ
# GUM_academic_census-15	6	record	NN
# GUM_academic_census-15	7	of	IN
# GUM_academic_census-15	8	three	CD
# GUM_academic_census-15	9	academic	JJ
# GUM_academic_census-15	10	fields	NNS
# GUM_academic_census-15	11	:	:
# GUM_academic_census-15	1	computer	NN
# GUM_academic_census-15	2	science	NN
# GUM_academic_census-15	3	,	,
# GUM_academic_census-15	4	history	NN
# GUM_academic_census-15	5	,	,
# GUM_academic_census-15	6	and	CC
# GUM_academic_census-15	7	business	NN
# GUM_academic_census-15	8	[	-LRB-
# GUM_academic_census-15	1	19	CD
# GUM_academic_census-15	2	]	-RRB-
# GUM_academic_census-15	3	.	.
# GUM_academic_census-16	1	This	DT
# GUM_academic_census-16	2	data	NNS
# GUM_academic_census-16	3	set	NN
# GUM_academic_census-16	4	has	VBZ
# GUM_academic_census-16	5	shed	VBN
# GUM_academic_census-16	6	considerable	JJ
# GUM_academic_census-16	1	light	NN
# GUM_academic_census-16	2	on	IN
# GUM_academic_census-16	3	dramatic	JJ
# GUM_academic_census-16	4	inequalities	NNS
# GUM_academic_census-16	5	in	IN
# GUM_academic_census-16	1	faculty	NN
# GUM_academic_census-16	2	training	NN
# GUM_academic_census-16	3	,	,
# GUM_academic_census-16	4	placement	NN
# GUM_academic_census-16	5	,	,
# GUM_academic_census-16	6	and	CC
# GUM_academic_census-16	7	scholarly	JJ
# GUM_academic_census-16	8	productivity	NN
# GUM_academic_census-16	9	[	-LRB-
# GUM_academic_census-16	10	6	CD
# GUM_academic_census-16	11	,	,
# GUM_academic_census-16	1	19	CD
# GUM_academic_census-16	2	,	,
# GUM_academic_census-16	3	20	CD
# GUM_academic_census-16	4	]	-RRB-
# GUM_academic_census-16	5	.	.
# GUM_academic_census-17	1	But	CC
# GUM_academic_census-17	2	,	,
# GUM_academic_census-17	3	this	DT
# GUM_academic_census-17	4	data	NNS
# GUM_academic_census-17	5	set	NN
# GUM_academic_census-17	6	is	VBZ
# GUM_academic_census-17	1	only	RB
# GUM_academic_census-17	2	a	DT
# GUM_academic_census-17	3	single	JJ
# GUM_academic_census-17	4	snapshot	NN
# GUM_academic_census-17	5	of	IN
# GUM_academic_census-17	1	an	DT
# GUM_academic_census-17	2	evolving	VBG
# GUM_academic_census-17	3	and	CC
# GUM_academic_census-17	4	expanding	VBG
# GUM_academic_census-17	5	system	NN
# GUM_academic_census-17	6	and	CC
# GUM_academic_census-17	7	hence	RB
# GUM_academic_census-17	8	offers	VBZ
# GUM_academic_census-17	9	few	JJ
# GUM_academic_census-17	10	insights	NNS
# GUM_academic_census-17	11	into	IN
# GUM_academic_census-17	1	the	DT
# GUM_academic_census-17	2	changing	VBG
# GUM_academic_census-17	3	composition	NN
# GUM_academic_census-17	4	and	CC
# GUM_academic_census-17	5	diversity	NN
# GUM_academic_census-17	6	trends	NNS
# GUM_academic_census-17	7	within	IN
# GUM_academic_census-17	8	these	DT
# GUM_academic_census-17	1	academic	JJ
# GUM_academic_census-17	2	fields	NNS
# GUM_academic_census-17	3	.	.
# GUM_academic_census-18	1	In	IN
# GUM_academic_census-18	2	some	DT
# GUM_academic_census-18	3	fields	NNS
# GUM_academic_census-18	4	,	,
# GUM_academic_census-18	5	yearly	JJ
# GUM_academic_census-18	6	data	NNS
# GUM_academic_census-18	1	on	IN
# GUM_academic_census-18	2	faculty	NN
# GUM_academic_census-18	3	numbers	NNS
# GUM_academic_census-18	4	and	CC
# GUM_academic_census-18	5	composition	NN
# GUM_academic_census-18	1	are	VBP
# GUM_academic_census-18	2	available	JJ
# GUM_academic_census-18	3	in	IN
# GUM_academic_census-18	4	aggregate	NN
# GUM_academic_census-18	5	.	.
# GUM_academic_census-19	1	In	IN
# GUM_academic_census-19	2	computer	NN
# GUM_academic_census-19	3	science	NN
# GUM_academic_census-19	4	,	,
# GUM_academic_census-19	5	the	DT
# GUM_academic_census-19	6	Computing	NNP
# GUM_academic_census-19	1	Research	NNP
# GUM_academic_census-19	2	Association	NNP
# GUM_academic_census-19	3	(	-LRB-
# GUM_academic_census-19	4	CRA	NNP
# GUM_academic_census-19	5	)	-RRB-
# GUM_academic_census-19	1	documents	VBZ
# GUM_academic_census-19	2	trends	NNS
# GUM_academic_census-19	3	in	IN
# GUM_academic_census-19	4	the	DT
# GUM_academic_census-19	5	employment	NN
# GUM_academic_census-19	6	of	IN
# GUM_academic_census-19	7	PhD	NN
# GUM_academic_census-19	8	recipients	NNS
# GUM_academic_census-19	9	through	IN
# GUM_academic_census-19	10	the	DT
# GUM_academic_census-19	11	annual	JJ
# GUM_academic_census-19	1	Taulbee	NNP
# GUM_academic_census-19	2	survey	NN
# GUM_academic_census-19	3	of	IN
# GUM_academic_census-19	4	computing	NN
# GUM_academic_census-19	5	departments	NNS
# GUM_academic_census-19	6	in	IN
# GUM_academic_census-19	7	North	NNP
# GUM_academic_census-19	8	America	NNP
# GUM_academic_census-19	1	(	-LRB-
# GUM_academic_census-19	2	cra.org/resources/taulbee-survey	NNP
# GUM_academic_census-19	3	)	-RRB-
# GUM_academic_census-19	4	.	.
# GUM_academic_census-20	1	Such	JJ
# GUM_academic_census-20	2	surveys	NNS
# GUM_academic_census-20	3	can	MD
# GUM_academic_census-20	4	provide	VB
# GUM_academic_census-20	5	valuable	JJ
# GUM_academic_census-20	6	insight	NN
# GUM_academic_census-20	1	into	IN
# GUM_academic_census-20	2	trends	NNS
# GUM_academic_census-20	3	and	CC
# GUM_academic_census-20	4	summary	NN
# GUM_academic_census-20	5	statistics	NNS
# GUM_academic_census-20	1	on	IN
# GUM_academic_census-20	2	the	DT
# GUM_academic_census-20	3	scientific	JJ
# GUM_academic_census-20	4	workforce	NN
# GUM_academic_census-20	5	but	CC
# GUM_academic_census-20	6	suffer	VB
# GUM_academic_census-20	7	from	IN
# GUM_academic_census-20	8	two	CD
# GUM_academic_census-20	9	key	JJ
# GUM_academic_census-20	10	weaknesses	NNS
# GUM_academic_census-20	11	.	.
# GUM_academic_census-21	1	First	RB
# GUM_academic_census-21	2	,	,
# GUM_academic_census-21	3	surveys	NNS
# GUM_academic_census-21	4	are	VBP
# GUM_academic_census-21	5	subject	NN
# GUM_academic_census-21	6	to	IN
# GUM_academic_census-21	1	variable	JJ
# GUM_academic_census-21	2	response	NN
# GUM_academic_census-21	3	rates	NNS
# GUM_academic_census-21	4	and	CC
# GUM_academic_census-21	5	the	DT
# GUM_academic_census-21	1	misinterpretation	NN
# GUM_academic_census-21	2	of	IN
# GUM_academic_census-21	3	questions	NNS
# GUM_academic_census-21	4	or	CC
# GUM_academic_census-21	5	sample	NN
# GUM_academic_census-21	6	frames	NNS
# GUM_academic_census-21	7	,	,
# GUM_academic_census-21	8	which	WDT
# GUM_academic_census-21	9	can	MD
# GUM_academic_census-21	10	inject	VB
# GUM_academic_census-21	11	bias	NN
# GUM_academic_census-21	1	into	IN
# GUM_academic_census-21	2	fine	JJ
# GUM_academic_census-21	3	-	HYPH
# GUM_academic_census-21	4	grained	JJ
# GUM_academic_census-21	5	analyses	NNS
# GUM_academic_census-21	6	[	-LRB-
# GUM_academic_census-21	7	21	CD
# GUM_academic_census-21	8	,	,
# GUM_academic_census-21	1	22	CD
# GUM_academic_census-21	2	]	-RRB-
# GUM_academic_census-21	3	.	.
# GUM_academic_census-22	1	Second	RB
# GUM_academic_census-22	2	,	,
# GUM_academic_census-22	3	aggregate	JJ
# GUM_academic_census-22	4	information	NN
# GUM_academic_census-22	5	provides	VBZ
# GUM_academic_census-22	6	only	RB
# GUM_academic_census-22	1	a	DT
# GUM_academic_census-22	2	high	JJ
# GUM_academic_census-22	3	-	HYPH
# GUM_academic_census-22	4	level	JJ
# GUM_academic_census-22	5	view	NN
# GUM_academic_census-22	1	of	IN
# GUM_academic_census-22	2	a	DT
# GUM_academic_census-22	3	field	NN
# GUM_academic_census-22	4	,	,
# GUM_academic_census-22	5	which	WDT
# GUM_academic_census-22	6	can	MD
# GUM_academic_census-22	7	make	VB
# GUM_academic_census-22	8	it	PRP
# GUM_academic_census-22	9	difficult	JJ
# GUM_academic_census-22	10	to	TO
# GUM_academic_census-22	11	investigate	VB
# GUM_academic_census-22	1	causality	NN
# GUM_academic_census-22	2	[	-LRB-
# GUM_academic_census-22	3	23	CD
# GUM_academic_census-22	4	]	-RRB-
# GUM_academic_census-22	5	.	.
# GUM_academic_census-23	1	For	IN
# GUM_academic_census-23	2	example	NN
# GUM_academic_census-23	3	,	,
# GUM_academic_census-23	4	differences	NNS
# GUM_academic_census-23	5	in	IN
# GUM_academic_census-23	6	recruitment	NN
# GUM_academic_census-23	1	and	CC
# GUM_academic_census-23	2	retention	NN
# GUM_academic_census-23	3	strategies	NNS
# GUM_academic_census-23	4	across	IN
# GUM_academic_census-23	5	departments	NNS
# GUM_academic_census-23	1	will	MD
# GUM_academic_census-23	2	be	VB
# GUM_academic_census-23	3	washed	VBN
# GUM_academic_census-23	4	out	RP
# GUM_academic_census-23	5	by	IN
# GUM_academic_census-23	6	averaging	NN
# GUM_academic_census-23	7	,	,
# GUM_academic_census-23	8	thereby	RB
# GUM_academic_census-23	9	masking	VBG
# GUM_academic_census-23	10	any	DT
# GUM_academic_census-23	11	insights	NNS
# GUM_academic_census-23	1	into	IN
# GUM_academic_census-23	2	the	DT
# GUM_academic_census-23	3	efficacy	NN
# GUM_academic_census-23	4	of	IN
# GUM_academic_census-23	5	individual	JJ
# GUM_academic_census-23	6	strategies	NNS
# GUM_academic_census-23	7	and	CC
# GUM_academic_census-23	8	policies	NNS
# GUM_academic_census-23	1	.	.
# GUM_academic_census-24	1	Here	RB
# GUM_academic_census-24	2	,	,
# GUM_academic_census-24	3	we	PRP
# GUM_academic_census-24	4	present	VBP
# GUM_academic_census-24	5	a	DT
# GUM_academic_census-24	6	novel	JJ
# GUM_academic_census-24	1	system	NN
# GUM_academic_census-24	2	,	,
# GUM_academic_census-24	3	based	VBN
# GUM_academic_census-24	4	on	IN
# GUM_academic_census-24	5	a	DT
# GUM_academic_census-24	1	topical	JJ
# GUM_academic_census-24	2	web	NN
# ...
# GUM_conversation_family-162	2	,	,
# GUM_conversation_family-162	3	what	WP
# GUM_conversation_family-162	4	was	VBD
# GUM_conversation_family-162	5	her	PRP$
# GUM_conversation_family-162	6	story	NN
# GUM_conversation_family-162	1	about	IN
# GUM_conversation_family-162	2	Barb	NNP
# GUM_conversation_family-162	3	?	.
# GUM_conversation_family-163	1	That	DT
# GUM_conversation_family-163	2	everyone	NN
# GUM_conversation_family-163	3	–	:
# GUM_conversation_family-163	4	That	DT
# GUM_conversation_family-163	5	was	VBD
# GUM_conversation_family-163	6	–	:
# GUM_conversation_family-164	1	She	PRP
# GUM_conversation_family-164	2	was	VBD
# GUM_conversation_family-164	3	in	IN
# GUM_conversation_family-164	4	the	DT
# GUM_conversation_family-164	5	hospital	NN
# GUM_conversation_family-164	6	three	CD
# GUM_conversation_family-164	1	times	NNS
# GUM_conversation_family-164	2	.	.
# GUM_conversation_family-165	1	Carolyn	NNP
# GUM_conversation_family-165	2	was	VBD
# GUM_conversation_family-165	3	so	RB
# GUM_conversation_family-165	4	affected	VBN
# GUM_conversation_family-165	5	by	IN
# GUM_conversation_family-165	6	,	,
# GUM_conversation_family-165	1	or	CC
# GUM_conversation_family-165	2	unaffected	JJ
# GUM_conversation_family-165	3	or	CC
# GUM_conversation_family-165	4	whatever	WP
# GUM_conversation_family-165	5	.	.
# GUM_conversation_family-166	1	With	IN
# GUM_conversation_family-166	2	asthmatic	JJ
# GUM_conversation_family-166	3	bronchitis	NN
# GUM_conversation_family-166	4	.	.
# GUM_conversation_family-167	1	With	IN
# GUM_conversation_family-167	2	bron-	UH
# GUM_conversation_family-167	3	—	:
# GUM_conversation_family-168	1	And	CC
# GUM_conversation_family-168	2	so	RB
# GUM_conversation_family-168	3	,	,
# GUM_conversation_family-168	4	how	WRB
# GUM_conversation_family-168	5	did	VBD
# GUM_conversation_family-168	6	Carolyn	NNP
# GUM_conversation_family-168	1	react	VB
# GUM_conversation_family-168	2	?	.
# GUM_conversation_family-169	1	Well	UH
# GUM_conversation_family-169	2	–	:
# GUM_conversation_family-170	1	I	PRP
# GUM_conversation_family-170	2	–	:
# GUM_conversation_family-170	3	for	IN
# GUM_conversation_family-170	4	some	DT
# GUM_conversation_family-170	5	reason	NN
# GUM_conversation_family-170	6	–	:
# GUM_conversation_family-171	1	She	PRP
# GUM_conversation_family-171	2	said	VBD
# GUM_conversation_family-171	3	thanks	NNS
# GUM_conversation_family-171	4	a	DT
# GUM_conversation_family-171	5	lot	NN
# GUM_conversation_family-171	6	,	,
# GUM_conversation_family-171	1	you	PRP
# GUM_conversation_family-171	2	know	VBP
# GUM_conversation_family-171	3	,	,
# GUM_conversation_family-171	4	because	IN
# GUM_conversation_family-171	5	she	PRP
# GUM_conversation_family-171	1	was	VBD
# GUM_conversation_family-171	2	so	RB
# GUM_conversation_family-171	3	worried	JJ
# GUM_conversation_family-171	4	about	IN
# GUM_conversation_family-171	5	Jonathan	NNP
# GUM_conversation_family-171	6	.	.
# GUM_conversation_family-172	1	Oh	UH
# GUM_conversation_family-172	2	sh-	UH
# GUM_conversation_family-172	3	like	UH
# GUM_conversation_family-172	4	oh	UH
# GUM_conversation_family-172	5	,	,
# GUM_conversation_family-172	6	he	PRP
# GUM_conversation_family-172	1	's	VBZ
# GUM_conversation_family-172	2	gon	VBG
# GUM_conversation_family-172	3	na	TO
# GUM_conversation_family-172	4	go	VB
# GUM_conversation_family-172	5	back	RB
# GUM_conversation_family-172	1	again	RB
# GUM_conversation_family-172	2	in	IN
# GUM_conversation_family-172	3	other	JJ
# GUM_conversation_family-172	4	words	NNS
# GUM_conversation_family-172	5	.	.
# GUM_conversation_family-173	1	I	PRP
# GUM_conversation_family-173	2	said	VBD
# GUM_conversation_family-173	3	but	CC
# GUM_conversation_family-173	4	–	:
# GUM_conversation_family-174	1	And	CC
# GUM_conversation_family-174	2	then	RB
# GUM_conversation_family-174	3	she	PRP
# GUM_conversation_family-174	4	told	VBD
# GUM_conversation_family-174	5	her	PRP
# GUM_conversation_family-174	6	that	WDT
# GUM_conversation_family-174	1	,	,
# GUM_conversation_family-174	2	she	PRP
# GUM_conversation_family-174	3	did	VBD
# GUM_conversation_family-174	4	n't	RB
# GUM_conversation_family-174	5	outgrow	VB
# GUM_conversation_family-174	1	it	PRP
# GUM_conversation_family-174	2	until	IN
# GUM_conversation_family-174	3	she	PRP
# GUM_conversation_family-174	4	was	VBD
# GUM_conversation_family-174	5	five	CD
# GUM_conversation_family-174	6	or	CC
# GUM_conversation_family-174	7	something	NN
# GUM_conversation_family-174	8	?	.
# GUM_conversation_family-175	1	She	PRP
# GUM_conversation_family-175	2	did	VBD
# GUM_conversation_family-175	3	n't	RB
# GUM_conversation_family-175	4	have	VB
# GUM_conversation_family-175	5	what	WP
# GUM_conversation_family-175	6	?	.
# GUM_conversation_family-176	1	We	PRP
# GUM_conversation_family-176	2	are	VBP
# GUM_conversation_family-176	3	all	RB
# GUM_conversation_family-176	4	going	VBG
# GUM_conversation_family-176	5	"	``
# GUM_conversation_family-176	6	Barb	NNP
# GUM_conversation_family-176	1	did	VBD
# GUM_conversation_family-176	2	n't	RB
# GUM_conversation_family-176	3	outgrow	VB
# GUM_conversation_family-176	4	it	PRP
# GUM_conversation_family-176	5	?	.
# GUM_conversation_family-176	1	"	''
# GUM_conversation_family-176	2	.	.
# GUM_conversation_family-177	1	Oh	UH
# GUM_conversation_family-177	2	"	``
# GUM_conversation_family-177	3	outgrow	VB
# GUM_conversation_family-177	4	it	PRP
# GUM_conversation_family-177	5	"	''
# GUM_conversation_family-177	6	.	.
# GUM_conversation_family-178	1	She	PRP
# GUM_conversation_family-178	2	was	VBD
# GUM_conversation_family-178	3	five	CD
# GUM_conversation_family-178	4	or	CC
# GUM_conversation_family-178	5	something	NN
# GUM_conversation_family-178	6	?	.
# GUM_conversation_family-179	1	Mm	UH
# GUM_conversation_family-179	2	.	.
# GUM_conversation_family-180	1	Oh	UH
# GUM_conversation_family-180	2	.	.
# GUM_conversation_family-181	1	So	UH
# GUM_conversation_family-181	2	Carolyn	NNP
# GUM_conversation_family-181	3	was	VBD
# GUM_conversation_family-181	4	really	RB
# GUM_conversation_family-181	5	happy	JJ
# GUM_conversation_family-181	6	.	.
# GUM_conversation_family-182	1	So	UH
# GUM_conversation_family-182	2	,	,
# GUM_conversation_family-182	3	yeah	UH
# GUM_conversation_family-182	4	because	IN
# GUM_conversation_family-182	5	C-	UH
# GUM_conversation_family-182	6	–	:
# GUM_conversation_family-183	1	Like	UH
# GUM_conversation_family-183	2	"	``
# GUM_conversation_family-183	3	oh	UH
# GUM_conversation_family-183	4	this	DT
# GUM_conversation_family-183	5	is	VBZ
# GUM_conversation_family-183	6	great	JJ
# GUM_conversation_family-183	1	news	NN
# GUM_conversation_family-183	2	"	''
# GUM_conversation_family-183	3	.	.
# GUM_conversation_family-184	1	So	RB
# GUM_conversation_family-184	2	then	RB
# GUM_conversation_family-184	3	I	PRP
# GUM_conversation_family-184	4	said	VBD
# GUM_conversation_family-184	5	,	,
# GUM_conversation_family-184	6	"	``
# GUM_conversation_family-184	1	but	CC
# GUM_conversation_family-184	2	look	VB
# GUM_conversation_family-184	3	at	IN
# GUM_conversation_family-184	4	Barb	NNP
# GUM_conversation_family-184	5	,	,
# GUM_conversation_family-184	1	she	PRP
# GUM_conversation_family-184	2	's	VBZ
# GUM_conversation_family-184	3	healthy	JJ
# GUM_conversation_family-184	4	now	RB
# GUM_conversation_family-184	5	"	''
# GUM_conversation_family-184	6	,	,
# GUM_conversation_family-184	7	and	CC
# GUM_conversation_family-184	8	Carolyn	NNP
# GUM_conversation_family-184	9	looked	VBD
# GUM_conversation_family-184	10	at	IN
# GUM_conversation_family-184	11	her	PRP
# GUM_conversation_family-184	1	,	,
# GUM_conversation_family-184	2	and	CC
# GUM_conversation_family-184	3	sort	NN
# GUM_conversation_family-184	4	of	IN
# GUM_conversation_family-184	5	looked	VBD
# GUM_conversation_family-184	6	away	RB
# GUM_conversation_family-184	7	,	,
# GUM_conversation_family-184	8	and	CC
# GUM_conversation_family-184	1	I	PRP
# GUM_conversation_family-184	2	thought	VBD
# GUM_conversation_family-184	3	,	,
# GUM_conversation_family-184	4	oh	UH
# GUM_conversation_family-184	5	boy	UH
# GUM_conversation_family-184	6	.	.
# GUM_conversation_family-185	1	Rude	JJ
# GUM_conversation_family-185	2	.	.
# GUM_conversation_family-186	1	Way	NN
# GUM_conversation_family-186	2	to	TO
# GUM_conversation_family-186	3	go	VB
# GUM_conversation_family-186	4	Carolyn	NNP
# GUM_conversation_family-186	5	.	.
# GUM_conversation_gossip-1	1	He	PRP
# GUM_conversation_gossip-1	2	's	VBZ
# GUM_conversation_gossip-1	3	teething	VBG
# GUM_conversation_gossip-1	4	.	.
# GUM_conversation_gossip-2	1	You	PRP
# GUM_conversation_gossip-2	2	should	MD
# GUM_conversation_gossip-2	3	have	VB
# GUM_conversation_gossip-2	4	heard	VBN
# GUM_conversation_gossip-2	5	him	PRP
# GUM_conversation_gossip-2	6	,	,
# GUM_conversation_gossip-2	1	the	DT
# GUM_conversation_gossip-2	2	night	NN
# GUM_conversation_gossip-2	3	we	PRP
# GUM_conversation_gossip-2	4	took	VBD
# GUM_conversation_gossip-2	5	him	PRP
# GUM_conversation_gossip-2	1	to	IN
# GUM_conversation_gossip-2	2	the	DT
# GUM_conversation_gossip-2	3	emergency	NN
# GUM_conversation_gossip-2	4	room	NN
# GUM_conversation_gossip-2	5	.	.
# GUM_conversation_gossip-3	1	He	PRP
# GUM_conversation_gossip-3	2	sounded	VBD
# GUM_conversation_gossip-3	3	worse	JJR
# GUM_conversation_gossip-3	4	.	.
# GUM_conversation_gossip-4	1	I	PRP
# GUM_conversation_gossip-4	2	pr-	UH
# GUM_conversation_gossip-4	3	if	IN
# GUM_conversation_gossip-4	4	I	PRP
# GUM_conversation_gossip-4	5	know	VBP
# GUM_conversation_gossip-4	6	,	,
# GUM_conversation_gossip-4	1	I	PRP
# GUM_conversation_gossip-4	2	would	MD
# GUM_conversation_gossip-4	3	probably	RB
# GUM_conversation_gossip-4	4	've	VB
# GUM_conversation_gossip-4	5	been	VBN
# GUM_conversation_gossip-4	1	totally	RB
# GUM_conversation_gossip-4	2	freaked	VBN
# GUM_conversation_gossip-4	3	out	RP
# GUM_conversation_gossip-4	4	.	.
# GUM_conversation_gossip-5	1	That	DT
# GUM_conversation_gossip-5	2	's	VBZ
# GUM_conversation_gossip-5	3	scary	JJ
# GUM_conversation_gossip-5	4	.	.
# GUM_conversation_gossip-6	1	Maybe	RB
# GUM_conversation_gossip-6	2	it	PRP
# GUM_conversation_gossip-6	3	's	VBZ
# GUM_conversation_gossip-6	4	good	JJ
# GUM_conversation_gossip-6	5	he	PRP
# GUM_conversation_gossip-6	6	did	VBD
# GUM_conversation_gossip-6	1	n't	RB
# GUM_conversation_gossip-6	2	stay	VB
# GUM_conversation_gossip-6	3	with	IN
# GUM_conversation_gossip-6	4	me	PRP
# GUM_conversation_gossip-6	5	.	.
# GUM_conversation_gossip-7	1	I	PRP
# GUM_conversation_gossip-7	2	'd	MD
# GUM_conversation_gossip-7	3	have	VB
# GUM_conversation_gossip-7	4	been	VBN
# GUM_conversation_gossip-7	5	like	IN
# GUM_conversation_gossip-7	6	Michael	NNP
# GUM_conversation_gossip-7	1	.	.
# GUM_conversation_gossip-8	1	Scary	JJ
# GUM_conversation_gossip-8	2	.	.
# GUM_conversation_gossip-9	1	Yeah	UH
# GUM_conversation_gossip-9	2	,	,
# GUM_conversation_gossip-9	3	he	PRP
# GUM_conversation_gossip-9	4	–	:
# GUM_conversation_gossip-9	5	he	PRP
# GUM_conversation_gossip-9	6	was	VBD
# GUM_conversation_gossip-9	1	um	UH
# GUM_conversation_gossip-9	2	–	:
# GUM_conversation_gossip-10	1	I	PRP
# GUM_conversation_gossip-10	2	'd	MD
# GUM_conversation_gossip-10	3	be	VB
# GUM_conversation_gossip-10	4	like	JJ
# GUM_conversation_gossip-10	5	Mom	NN
# GUM_conversation_gossip-10	6	,	,
# GUM_conversation_gossip-10	1	uh	UH
# GUM_conversation_gossip-10	2	,	,
# GUM_conversation_gossip-10	3	what	WP
# GUM_conversation_gossip-10	4	should	MD
# GUM_conversation_gossip-10	5	we	PRP
# GUM_conversation_gossip-10	1	do	VBP
# GUM_conversation_gossip-10	2	with	IN
# GUM_conversation_gossip-10	3	this	DT
# GUM_conversation_gossip-10	4	child	NN
# GUM_conversation_gossip-10	5	.	.
# GUM_conversation_gossip-11	1	Well	UH
# GUM_conversation_gossip-11	2	his	PRP$
# GUM_conversation_gossip-11	3	temperature	NN
# GUM_conversation_gossip-11	4	was	VBD
# GUM_conversation_gossip-11	5	a	DT
# GUM_conversation_gossip-11	6	hundred	CD
# GUM_conversation_gossip-11	1	and	CC
# GUM_conversation_gossip-11	2	four	CD
# GUM_conversation_gossip-11	3	point	NN
# GUM_conversation_gossip-11	4	five	CD
# GUM_conversation_gossip-11	5	.	.
# GUM_conversation_gossip-12	1	That	DT
# GUM_conversation_gossip-12	2	is	VBZ
# GUM_conversation_gossip-12	3	so	RB
# GUM_conversation_gossip-12	4	high	JJ
# GUM_conversation_gossip-12	5	.	.
# GUM_conversation_gossip-13	1	He	PRP
# GUM_conversation_gossip-13	2	's	VBZ
# GUM_conversation_gossip-13	3	lucky	JJ
# GUM_conversation_gossip-13	4	that	IN
# GUM_conversation_gossip-13	5	he	PRP
# GUM_conversation_gossip-13	6	did	VBD
# GUM_conversation_gossip-13	1	n't	RB
# GUM_conversation_gossip-13	2	–	:
# GUM_conversation_gossip-14	1	How	WRB
# GUM_conversation_gossip-14	2	long	RB
# GUM_conversation_gossip-14	3	was	VBD
# GUM_conversation_gossip-14	4	he	PRP
# GUM_conversation_gossip-14	5	there	RB
# GUM_conversation_gossip-14	6	?	.
# GUM_conversation_gossip-15	1	That	DT
# GUM_conversation_gossip-15	2	high	JJ
# GUM_conversation_gossip-15	3	?	.
# GUM_conversation_gossip-16	1	How	WRB
# GUM_conversation_gossip-16	2	long	RB
# GUM_conversation_gossip-16	3	,	,
# GUM_conversation_gossip-16	4	do	VBP
# GUM_conversation_gossip-16	5	you	PRP
# GUM_conversation_gossip-16	6	know	VBP
# GUM_conversation_gossip-16	1	?	.
# GUM_conversation_gossip-17	1	Uh	UH
# GUM_conversation_gossip-17	2	his	PRP$
# GUM_conversation_gossip-17	3	fever	NN
# GUM_conversation_gossip-17	4	?	.
# GUM_conversation_gossip-18	1	Yeah	UH
# GUM_conversation_gossip-18	2	.	.
# GUM_conversation_gossip-19	1	I	PRP
# GUM_conversation_gossip-19	2	do	VBP
# GUM_conversation_gossip-19	3	n't	RB
# GUM_conversation_gossip-19	4	know	VB
# GUM_conversation_gossip-19	5	.	.
# GUM_conversation_gossip-20	1	That	DT
# GUM_conversation_gossip-20	2	's	VBZ
# GUM_conversation_gossip-20	3	dangerou-	JJ
# GUM_conversation_gossip-20	4	–	:
# GUM_conversation_gossip-20	5	I	PRP
# GUM_conversation_gossip-20	6	mean	VBP
# GUM_conversation_gossip-20	1	s-	UH
# GUM_conversation_gossip-20	2	–	:
# GUM_conversation_gossip-21	1	Cause	IN
# GUM_conversation_gossip-21	2	he	PRP
# GUM_conversation_gossip-21	3	could	MD
# GUM_conversation_gossip-21	4	have	VB
# GUM_conversation_gossip-21	5	,	,
# GUM_conversation_gossip-21	6	brain	NN
# GUM_conversation_gossip-21	1	damage	NN
# GUM_conversation_gossip-21	2	.	.
# GUM_conversation_gossip-22	1	The	DT
# GUM_conversation_gossip-22	2	doctor	NN
# GUM_conversation_gossip-22	3	said	VBD
# GUM_conversation_gossip-22	4	–	:
# GUM_conversation_gossip-22	5	the	DT
# GUM_conversation_gossip-22	6	doctor	NN
# GUM_conversation_gossip-22	1	said	VBD
# GUM_conversation_gossip-22	2	that	IN
# GUM_conversation_gossip-22	3	th-	UH
# GUM_conversation_gossip-22	4	um	UH
# GUM_conversation_gossip-22	5	,	,
# GUM_conversation_gossip-22	1	his	PRP$
# GUM_conversation_gossip-22	2	pediatrician	NN
# GUM_conversation_gossip-22	3	,	,
# GUM_conversation_gossip-22	4	cause	IN
# GUM_conversation_gossip-22	5	I	PRP
# GUM_conversation_gossip-22	6	asked	VBD
# GUM_conversation_gossip-22	7	him	PRP
# GUM_conversation_gossip-22	8	about	RB
# GUM_conversation_gossip-22	9	it	PRP
# GUM_conversation_gossip-22	10	,	,
# GUM_conversation_gossip-22	11	and	CC
# GUM_conversation_gossip-22	1	he	PRP
# GUM_conversation_gossip-22	2	said	VBD
# GUM_conversation_gossip-22	3	that	IN
# GUM_conversation_gossip-22	4	they	PRP
# GUM_conversation_gossip-22	5	do	VBP
# GUM_conversation_gossip-22	6	n't	RB
# GUM_conversation_gossip-22	7	hospitalize	VB
# GUM_conversation_gossip-22	8	until	IN
# GUM_conversation_gossip-22	1	they	PRP
# GUM_conversation_gossip-22	2	go	VBP
# GUM_conversation_gossip-22	3	up	RP
# GUM_conversation_gossip-22	4	to	TO
# GUM_conversation_gossip-22	5	like	VB
# GUM_conversation_gossip-22	6	a	DT
# GUM_conversation_gossip-22	7	hundred	CD
# GUM_conversation_gossip-22	8	and	CC
# GUM_conversation_gossip-22	1	seven	CD
# GUM_conversation_gossip-22	2	.	.
# GUM_conversation_gossip-23	1	And	CC
# GUM_conversation_gossip-23	2	that	WDT
# GUM_conversation_gossip-23	3	's	VBZ
# GUM_conversation_gossip-23	4	where	WRB
# GUM_conversation_gossip-23	5	it	PRP
# GUM_conversation_gossip-23	6	's	VBZ
# GUM_conversation_gossip-23	1	fatal	JJ
# GUM_conversation_gossip-23	2	.	.
# GUM_conversation_gossip-24	1	And	CC
# GUM_conversation_gossip-24	2	I	PRP
# GUM_conversation_gossip-24	3	was	VBD
# GUM_conversation_gossip-24	4	like	UH
# GUM_conversation_gossip-24	5	,	,
# GUM_conversation_gossip-24	6	well	UH
# GUM_conversation_gossip-24	1	,	,
# GUM_conversation_gossip-24	2	you	PRP
# GUM_conversation_gossip-24	3	know	VBP
# GUM_conversation_gossip-24	4	–	:
# GUM_conversation_gossip-25	1	What	WP
# GUM_conversation_gossip-25	2	about	IN
# GUM_conversation_gossip-25	3	brain	NN
# GUM_conversation_gossip-25	4	damage	NN
# GUM_conversation_gossip-25	5	?	.
# GUM_conversation_gossip-26	1	That	DT
# GUM_conversation_gossip-26	2	does	VBZ
# GUM_conversation_gossip-26	3	n't	RB
# GUM_conversation_gossip-26	4	matter	VB
# GUM_conversation_gossip-26	5	or	CC
# GUM_conversation_gossip-26	6	?	.
# GUM_conversation_gossip-27	1	Mmm	UH
# GUM_conversation_gossip-27	2	.	.

# %%
for i in range(len(testResults)):
    for j in range(len(testResults[i])):
        print(f"{listOfTestSentIds[i]}\t{testData[j][1]}\t{testSentences[i][j]}\t{testResults[i][j]}")
# Out:
# GUM_academic_discrimination-1	1	The	DT
# GUM_academic_discrimination-1	2	prevalence	NN
# GUM_academic_discrimination-1	3	of	IN
# GUM_academic_discrimination-1	4	discrimination	NN
# GUM_academic_discrimination-1	5	across	IN
# GUM_academic_discrimination-1	6	racial	JJ
# GUM_academic_discrimination-1	7	groups	NNS
# GUM_academic_discrimination-1	8	in	IN
# GUM_academic_discrimination-1	9	contemporary	JJ
# GUM_academic_discrimination-1	10	America	NNS
# GUM_academic_discrimination-1	11	:	:
# GUM_academic_discrimination-2	1	Results	NNS
# GUM_academic_discrimination-2	2	from	IN
# GUM_academic_discrimination-2	3	a	DT
# GUM_academic_discrimination-2	4	nationally	RB
# GUM_academic_discrimination-2	5	representative	JJ
# GUM_academic_discrimination-2	6	sample	NN
# GUM_academic_discrimination-2	7	of	IN
# GUM_academic_discrimination-2	8	adults	NNS
# GUM_academic_discrimination-3	1	Introduction	NN
# GUM_academic_discrimination-3	2	.	.
# GUM_academic_discrimination-4	1	Personal	JJ
# GUM_academic_discrimination-4	2	experiences	NNS
# GUM_academic_discrimination-4	3	of	IN
# GUM_academic_discrimination-4	4	discrimination	NN
# GUM_academic_discrimination-4	5	and	CC
# GUM_academic_discrimination-4	6	bias	PRP
# GUM_academic_discrimination-4	7	have	VBP
# GUM_academic_discrimination-4	8	been	VBN
# GUM_academic_discrimination-4	9	the	DT
# GUM_academic_discrimination-4	10	focus	NN
# GUM_academic_discrimination-4	11	of	IN
# GUM_academic_discrimination-4	1	much	DT
# GUM_academic_discrimination-4	2	social	JJ
# GUM_academic_discrimination-4	3	science	NN
# GUM_academic_discrimination-4	4	research	NN
# GUM_academic_discrimination-4	5	.	.
# GUM_academic_discrimination-4	6	[	-LRB-
# GUM_academic_discrimination-4	7	1	CD
# GUM_academic_discrimination-4	8	-	HYPH
# GUM_academic_discrimination-4	1	3	CD
# GUM_academic_discrimination-4	2	]	-RRB-
# GUM_academic_discrimination-5	1	Sociologists	NNS
# GUM_academic_discrimination-5	2	have	VBP
# GUM_academic_discrimination-5	3	explored	IN
# GUM_academic_discrimination-5	4	the	DT
# GUM_academic_discrimination-5	5	adverse	JJ
# GUM_academic_discrimination-5	6	consequences	NNS
# GUM_academic_discrimination-5	7	of	IN
# GUM_academic_discrimination-5	8	discrimination	NN
# GUM_academic_discrimination-5	9	[	-LRB-
# GUM_academic_discrimination-5	10	3	CD
# GUM_academic_discrimination-5	11	–	SYM
# GUM_academic_discrimination-5	1	5	CD
# GUM_academic_discrimination-5	2	]	-RRB-
# GUM_academic_discrimination-5	3	;	:
# GUM_academic_discrimination-6	1	psychologists	NNS
# GUM_academic_discrimination-6	2	have	VBP
# GUM_academic_discrimination-6	3	examined	VBN
# GUM_academic_discrimination-6	4	the	DT
# GUM_academic_discrimination-6	5	mental	JJ
# GUM_academic_discrimination-6	6	processes	NNS
# GUM_academic_discrimination-6	7	that	WDT
# GUM_academic_discrimination-6	8	underpin	VBP
# GUM_academic_discrimination-6	9	conscious	JJ
# GUM_academic_discrimination-6	10	and	CC
# GUM_academic_discrimination-6	11	unconscious	JJ
# GUM_academic_discrimination-6	1	biases	NNS
# GUM_academic_discrimination-6	2	[	-LRB-
# GUM_academic_discrimination-6	3	6	CD
# GUM_academic_discrimination-6	4	]	-RRB-
# GUM_academic_discrimination-6	5	;	:
# GUM_academic_discrimination-7	1	neuroscientists	NNS
# GUM_academic_discrimination-7	2	have	VBP
# GUM_academic_discrimination-7	3	examined	VBN
# GUM_academic_discrimination-7	4	the	DT
# GUM_academic_discrimination-7	5	neurobiological	JJ
# GUM_academic_discrimination-7	6	underpinnings	NNS
# GUM_academic_discrimination-7	7	of	IN
# GUM_academic_discrimination-7	8	discrimination	NN
# GUM_academic_discrimination-7	9	[	-LRB-
# GUM_academic_discrimination-7	10	7	CD
# GUM_academic_discrimination-7	11	–	SYM
# GUM_academic_discrimination-7	1	9	CD
# GUM_academic_discrimination-7	2	]	-RRB-
# GUM_academic_discrimination-7	3	;	:
# GUM_academic_discrimination-8	1	and	CC
# GUM_academic_discrimination-8	2	evolutionary	JJ
# GUM_academic_discrimination-8	3	theorists	NNS
# GUM_academic_discrimination-8	4	have	VBP
# GUM_academic_discrimination-8	5	explored	IN
# GUM_academic_discrimination-8	6	the	DT
# GUM_academic_discrimination-8	7	various	JJ
# GUM_academic_discrimination-8	8	ways	NNS
# GUM_academic_discrimination-8	9	that	IN
# GUM_academic_discrimination-8	10	in	IN
# GUM_academic_discrimination-8	11	-	DT
# GUM_academic_discrimination-8	1	group	NN
# GUM_academic_discrimination-8	2	/	SYM
# GUM_academic_discrimination-8	3	out	CD
# GUM_academic_discrimination-8	4	-	HYPH
# GUM_academic_discrimination-8	5	group	NN
# GUM_academic_discrimination-8	6	biases	VBZ
# GUM_academic_discrimination-8	7	emerged	VBN
# GUM_academic_discrimination-8	8	across	IN
# GUM_academic_discrimination-8	1	the	DT
# GUM_academic_discrimination-8	2	history	NN
# GUM_academic_discrimination-8	1	of	IN
# GUM_academic_discrimination-8	2	our	PRP$
# GUM_academic_discrimination-8	3	species	NN
# GUM_academic_discrimination-8	4	.	.
# GUM_academic_discrimination-8	5	[	-LRB-
# GUM_academic_discrimination-8	6	10	CD
# GUM_academic_discrimination-8	7	]	-RRB-
# GUM_academic_discrimination-9	1	In	IN
# GUM_academic_discrimination-9	2	many	JJ
# GUM_academic_discrimination-9	3	respects	NNS
# GUM_academic_discrimination-9	4	,	,
# GUM_academic_discrimination-9	5	researchers	CC
# GUM_academic_discrimination-9	6	already	RB
# GUM_academic_discrimination-9	7	possess	VB
# GUM_academic_discrimination-9	8	a	DT
# GUM_academic_discrimination-9	9	wealth	NN
# GUM_academic_discrimination-9	10	of	IN
# GUM_academic_discrimination-9	11	knowledge	NN
# GUM_academic_discrimination-9	1	concerning	IN
# GUM_academic_discrimination-9	2	the	DT
# GUM_academic_discrimination-9	3	origins	NN
# GUM_academic_discrimination-9	4	and	CC
# GUM_academic_discrimination-9	5	consequences	NNS
# GUM_academic_discrimination-9	6	of	IN
# GUM_academic_discrimination-9	7	discrimination	NN
# GUM_academic_discrimination-9	8	and	CC
# GUM_academic_discrimination-9	1	bias	NN
# GUM_academic_discrimination-9	2	.	.
# GUM_academic_discrimination-9	1	[	-LRB-
# GUM_academic_discrimination-9	2	11	CD
# GUM_academic_discrimination-9	3	]	-RRB-
# GUM_academic_discrimination-10	1	What	WP
# GUM_academic_discrimination-10	2	also	PRP
# GUM_academic_discrimination-10	3	should	MD
# GUM_academic_discrimination-10	4	not	RB
# GUM_academic_discrimination-10	5	be	VB
# GUM_academic_discrimination-10	6	lost	VBN
# GUM_academic_discrimination-10	7	in	IN
# GUM_academic_discrimination-10	8	discussion	NN
# GUM_academic_discrimination-10	9	of	IN
# GUM_academic_discrimination-10	10	discrimination	NN
# GUM_academic_discrimination-10	11	is	VBZ
# GUM_academic_discrimination-10	1	the	DT
# GUM_academic_discrimination-10	2	growing	JJ
# GUM_academic_discrimination-10	3	push	NN
# GUM_academic_discrimination-10	4	to	TO
# GUM_academic_discrimination-10	5	implement	VB
# GUM_academic_discrimination-10	6	social	JJ
# GUM_academic_discrimination-10	7	policy	NN
# GUM_academic_discrimination-10	8	aimed	NN
# GUM_academic_discrimination-10	1	at	IN
# GUM_academic_discrimination-10	2	reducing	VBG
# GUM_academic_discrimination-10	1	the	DT
# GUM_academic_discrimination-10	2	occurrence	NN
# GUM_academic_discrimination-10	3	of	IN
# GUM_academic_discrimination-10	4	discriminatory	JJ
# GUM_academic_discrimination-10	5	practices	NNS
# GUM_academic_discrimination-10	6	.	.
# GUM_academic_discrimination-11	1	Mandatory	JJ
# GUM_academic_discrimination-11	2	diversity	NN
# GUM_academic_discrimination-11	3	trainings	NNS
# GUM_academic_discrimination-11	4	in	IN
# GUM_academic_discrimination-11	5	professional	JJ
# GUM_academic_discrimination-11	6	settings	NNS
# GUM_academic_discrimination-11	7	,	,
# GUM_academic_discrimination-11	8	for	IN
# GUM_academic_discrimination-11	9	example	NN
# GUM_academic_discrimination-11	10	,	,
# GUM_academic_discrimination-11	11	are	VBP
# GUM_academic_discrimination-11	1	intended	VBN
# GUM_academic_discrimination-11	2	to	TO
# GUM_academic_discrimination-11	3	reduce	VB
# GUM_academic_discrimination-11	4	bias	VBN
# GUM_academic_discrimination-11	5	in	IN
# GUM_academic_discrimination-11	6	the	DT
# GUM_academic_discrimination-11	7	workplace	NN
# GUM_academic_discrimination-11	8	by	IN
# GUM_academic_discrimination-11	1	increasing	VBG
# GUM_academic_discrimination-11	2	the	DT
# GUM_academic_discrimination-11	1	awareness	NN
# GUM_academic_discrimination-11	2	of	IN
# GUM_academic_discrimination-11	3	employees	NNS
# GUM_academic_discrimination-11	4	regarding	IN
# GUM_academic_discrimination-11	5	the	DT
# GUM_academic_discrimination-11	6	challenges	NNS
# GUM_academic_discrimination-11	7	facing	VBG
# GUM_academic_discrimination-11	8	minority	NN
# GUM_academic_discrimination-11	9	group	NN
# GUM_academic_discrimination-11	10	members	NNS
# GUM_academic_discrimination-11	11	.	.
# GUM_academic_discrimination-11	12	[	-LRB-
# GUM_academic_discrimination-11	13	12	CD
# GUM_academic_discrimination-11	14	]	-RRB-
# GUM_academic_discrimination-12	1	Indeed	UH
# GUM_academic_discrimination-12	2	,	,
# GUM_academic_discrimination-12	3	the	DT
# GUM_academic_discrimination-12	4	implementation	NN
# GUM_academic_discrimination-12	5	of	IN
# GUM_academic_discrimination-12	6	certain	DT
# GUM_academic_discrimination-12	7	policies	NN
# GUM_academic_discrimination-12	8	is	VBZ
# GUM_academic_discrimination-12	9	rooted	VBN
# GUM_academic_discrimination-12	10	in	IN
# GUM_academic_discrimination-12	11	the	DT
# GUM_academic_discrimination-12	1	assumption	NN
# GUM_academic_discrimination-12	2	that	IN
# GUM_academic_discrimination-12	3	discrimination	NN
# GUM_academic_discrimination-12	4	and	CC
# GUM_academic_discrimination-12	5	biases	PRP
# GUM_academic_discrimination-12	6	are	VBP
# GUM_academic_discrimination-12	7	,	,
# GUM_academic_discrimination-12	8	at	IN
# GUM_academic_discrimination-12	1	least	NN
# GUM_academic_discrimination-12	2	to	IN
# GUM_academic_discrimination-12	1	some	DT
# GUM_academic_discrimination-12	2	appreciable	JJ
# GUM_academic_discrimination-12	3	amount	NN
# GUM_academic_discrimination-12	4	,	,
# GUM_academic_discrimination-12	5	present	NN
# GUM_academic_discrimination-12	6	in	IN
# GUM_academic_discrimination-12	7	modern	JJ
# GUM_academic_discrimination-12	8	society	NN
# GUM_academic_discrimination-12	9	.	.
# GUM_academic_discrimination-13	1	Even	RBS
# GUM_academic_discrimination-13	2	so	RB
# GUM_academic_discrimination-13	3	,	,
# GUM_academic_discrimination-13	4	estimates	NNS
# GUM_academic_discrimination-13	5	of	IN
# GUM_academic_discrimination-13	6	the	DT
# GUM_academic_discrimination-13	7	prevalence	NN
# GUM_academic_discrimination-13	8	of	IN
# GUM_academic_discrimination-13	9	perceived	DT
# GUM_academic_discrimination-13	10	discrimination	NN
# GUM_academic_discrimination-13	11	remains	VBZ
# GUM_academic_discrimination-13	1	rare	JJ
# GUM_academic_discrimination-13	2	(	-LRB-
# GUM_academic_discrimination-13	3	see	NNP
# GUM_academic_discrimination-13	4	[	-LRB-
# GUM_academic_discrimination-13	5	13	CD
# GUM_academic_discrimination-13	6	–	SYM
# GUM_academic_discrimination-13	7	14	CD
# GUM_academic_discrimination-13	8	]	-RRB-
# GUM_academic_discrimination-13	1	)	-RRB-
# GUM_academic_discrimination-13	2	.	.
# GUM_academic_discrimination-14	1	At	IN
# GUM_academic_discrimination-14	2	least	DT
# GUM_academic_discrimination-14	3	one	NN
# GUM_academic_discrimination-14	4	prior	IN
# GUM_academic_discrimination-14	5	study	NN
# GUM_academic_discrimination-14	6	by	IN
# GUM_academic_discrimination-14	7	Kessler	NNP
# GUM_academic_discrimination-14	8	and	CC
# GUM_academic_discrimination-14	9	colleagues	NNP
# GUM_academic_discrimination-14	10	[	-LRB-
# GUM_academic_discrimination-14	11	15	CD
# GUM_academic_discrimination-14	1	]	-RRB-
# GUM_academic_discrimination-14	2	,	,
# GUM_academic_discrimination-14	3	however	RB
# GUM_academic_discrimination-14	4	,	,
# GUM_academic_discrimination-14	5	using	VBG
# GUM_academic_discrimination-14	6	measures	NN
# GUM_academic_discrimination-14	7	of	IN
# GUM_academic_discrimination-14	8	perceived	DT
# GUM_academic_discrimination-14	1	discrimination	NN
# GUM_academic_discrimination-14	2	in	IN
# GUM_academic_discrimination-14	1	a	DT
# GUM_academic_discrimination-14	2	large	JJ
# GUM_academic_discrimination-14	3	American	JJ
# GUM_academic_discrimination-14	4	sample	NN
# GUM_academic_discrimination-14	5	,	,
# GUM_academic_discrimination-14	6	reported	CC
# GUM_academic_discrimination-14	7	that	IN
# GUM_academic_discrimination-14	8	approximately	DT
# GUM_academic_discrimination-14	9	33	JJ
# GUM_academic_discrimination-14	10	%	NN
# GUM_academic_discrimination-14	11	of	IN
# GUM_academic_discrimination-14	12	respondents	NNS
# GUM_academic_discrimination-14	13	reported	IN
# GUM_academic_discrimination-14	14	some	DT
# GUM_academic_discrimination-14	15	form	NN
# GUM_academic_discrimination-14	16	of	IN
# GUM_academic_discrimination-14	17	discrimination	NN
# GUM_academic_discrimination-14	18	(	-LRB-
# GUM_academic_discrimination-14	19	see	VB
# GUM_academic_discrimination-14	20	also	RB
# GUM_academic_discrimination-14	21	,	,
# GUM_academic_discrimination-14	1	Gibbons	NNP
# GUM_academic_discrimination-14	2	et	NNP
# GUM_academic_discrimination-14	3	al.	NNP
# GUM_academic_discrimination-14	4	[	-LRB-
# GUM_academic_discrimination-14	5	4	CD
# GUM_academic_discrimination-14	6	]	-RRB-
# GUM_academic_discrimination-14	7	)	-RRB-
# GUM_academic_discrimination-14	8	.	.
# GUM_academic_discrimination-15	1	The	DT
# GUM_academic_discrimination-15	2	current	JJ
# GUM_academic_discrimination-15	3	study	NN
# GUM_academic_discrimination-15	4	seeks	VBZ
# GUM_academic_discrimination-15	5	to	TO
# GUM_academic_discrimination-15	6	build	VB
# GUM_academic_discrimination-15	7	on	IN
# GUM_academic_discrimination-15	8	this	DT
# GUM_academic_discrimination-15	9	research	NN
# GUM_academic_discrimination-15	10	by	IN
# GUM_academic_discrimination-15	11	estimating	VBG
# GUM_academic_discrimination-15	1	the	DT
# GUM_academic_discrimination-15	2	prevalence	NN
# GUM_academic_discrimination-15	3	of	IN
# GUM_academic_discrimination-15	4	discrimination	NN
# GUM_academic_discrimination-15	5	experiences	NNS
# GUM_academic_discrimination-15	6	among	IN
# GUM_academic_discrimination-15	7	a	DT
# GUM_academic_discrimination-15	8	large	JJ
# GUM_academic_discrimination-15	1	,	,
# GUM_academic_discrimination-15	2	nationally	RB
# GUM_academic_discrimination-15	1	representative	JJ
# GUM_academic_discrimination-15	2	sample	NN
# GUM_academic_discrimination-15	3	of	IN
# GUM_academic_discrimination-15	4	adults	NNS
# GUM_academic_discrimination-15	5	from	IN
# GUM_academic_discrimination-15	6	the	DT
# GUM_academic_discrimination-15	7	United	NNP
# GUM_academic_discrimination-15	8	States	NNPS
# GUM_academic_discrimination-15	9	.	.
# GUM_academic_discrimination-16	1	Additionally	UH
# GUM_academic_discrimination-16	2	,	,
# GUM_academic_discrimination-16	3	the	DT
# GUM_academic_discrimination-16	4	analysis	NN
# GUM_academic_discrimination-16	5	address	IN
# GUM_academic_discrimination-16	6	the	DT
# GUM_academic_discrimination-16	7	perceived	JJ
# GUM_academic_discrimination-16	8	reasons	NNS
# GUM_academic_discrimination-16	9	for	IN
# GUM_academic_discrimination-16	10	reported	DT
# GUM_academic_discrimination-16	11	discrimination	NN
# GUM_academic_discrimination-16	1	experiences	NNS
# GUM_academic_discrimination-16	2	.	.
# GUM_academic_discrimination-17	1	Reason	NN
# GUM_academic_discrimination-17	2	for	IN
# GUM_academic_discrimination-17	3	discrimination	NN
# GUM_academic_discrimination-17	4	.	.
# GUM_academic_discrimination-18	1	All	DT
# GUM_academic_discrimination-18	2	respondents	NNS
# GUM_academic_discrimination-18	3	who	WP
# GUM_academic_discrimination-18	4	indicated	VBD
# GUM_academic_discrimination-18	5	they	PRP
# GUM_academic_discrimination-18	6	were	VBD
# GUM_academic_discrimination-18	7	discriminated	VBN
# GUM_academic_discrimination-18	8	against	IN
# GUM_academic_discrimination-18	9	—	DT
# GUM_academic_discrimination-18	10	specifically	NN
# GUM_academic_discrimination-18	11	,	,
# GUM_academic_discrimination-18	1	those	DT
# GUM_academic_discrimination-18	2	who	JJ
# GUM_academic_discrimination-18	3	responded	NN
# GUM_academic_discrimination-18	4	with	IN
# GUM_academic_discrimination-18	5	sometimes	NNP
# GUM_academic_discrimination-18	6	or	CC
# GUM_academic_discrimination-18	7	often	RB
# GUM_academic_discrimination-18	8	to	IN
# GUM_academic_discrimination-18	1	the	DT
# GUM_academic_discrimination-18	2	perceived	JJ
# GUM_academic_discrimination-18	1	discrimination	NN
# GUM_academic_discrimination-18	2	measure	VBZ
# GUM_academic_discrimination-18	3	described	VBN
# GUM_academic_discrimination-18	4	above	IN
# GUM_academic_discrimination-18	5	—	PRP
# GUM_academic_discrimination-18	6	were	VBD
# GUM_academic_discrimination-18	7	asked	IN
# GUM_academic_discrimination-18	8	the	DT
# GUM_academic_discrimination-18	9	following	JJ
# GUM_academic_discrimination-18	10	question	NN
# GUM_academic_discrimination-18	11	:	:
# GUM_academic_discrimination-19	1	“	``
# GUM_academic_discrimination-19	2	What	TO
# GUM_academic_discrimination-19	3	do	VB
# GUM_academic_discrimination-19	4	you	PRP
# GUM_academic_discrimination-19	5	think	RB
# GUM_academic_discrimination-19	6	was	VBD
# GUM_academic_discrimination-19	7	the	DT
# GUM_academic_discrimination-19	8	main	JJ
# GUM_academic_discrimination-19	9	reason	NN
# GUM_academic_discrimination-19	10	for	IN
# GUM_academic_discrimination-19	11	these	DT
# GUM_academic_discrimination-19	1	experiences	NN
# GUM_academic_discrimination-19	2	?	.
# GUM_academic_discrimination-19	3	”	''
# GUM_academic_discrimination-20	1	Respondents	NNS
# GUM_academic_discrimination-20	2	were	VBD
# GUM_academic_discrimination-20	3	allowed	VBN
# GUM_academic_discrimination-20	4	to	IN
# GUM_academic_discrimination-20	5	choose	DT
# GUM_academic_discrimination-20	6	one	NN
# GUM_academic_discrimination-20	7	response	NN
# GUM_academic_discrimination-20	8	from	IN
# GUM_academic_discrimination-20	9	11	CD
# GUM_academic_discrimination-20	10	categories	-RRB-
# GUM_academic_discrimination-20	11	.	.
# GUM_academic_discrimination-21	1	For	IN
# GUM_academic_discrimination-21	2	the	DT
# GUM_academic_discrimination-21	3	present	JJ
# GUM_academic_discrimination-21	4	analysis	NN
# GUM_academic_discrimination-21	5	,	,
# GUM_academic_discrimination-21	6	these	DT
# GUM_academic_discrimination-21	7	responses	NNS
# GUM_academic_discrimination-21	8	were	VBD
# GUM_academic_discrimination-21	9	recoded	VBN
# GUM_academic_discrimination-21	10	into	IN
# GUM_academic_discrimination-21	11	nine	DT
# GUM_academic_discrimination-21	1	mutually	RB
# GUM_academic_discrimination-21	2	exclusive	JJ
# GUM_academic_discrimination-21	3	categories	NNS
# GUM_academic_discrimination-21	4	capturing	VBG
# GUM_academic_discrimination-21	5	the	DT
# GUM_academic_discrimination-21	6	following	JJ
# GUM_academic_discrimination-21	7	options	NNS
# GUM_academic_discrimination-21	8	:	:
# GUM_academic_discrimination-22	1	race	NN
# GUM_academic_discrimination-22	2	/	IN
# GUM_academic_discrimination-22	3	ancestry	NN
# GUM_academic_discrimination-22	4	/	IN
# GUM_academic_discrimination-22	5	skin	DT
# GUM_academic_discrimination-22	6	color	NN
# GUM_academic_discrimination-22	7	;	:
# GUM_academic_discrimination-23	1	gender	WP$
# GUM_academic_discrimination-23	2	;	:
# GUM_academic_discrimination-24	1	age	WP$
# GUM_academic_discrimination-24	2	;	:
# GUM_academic_discrimination-25	1	religion	NN
# GUM_academic_discrimination-25	2	;	:
# GUM_academic_discrimination-26	1	height	,
# GUM_academic_discrimination-26	2	or	CC
# GUM_academic_discrimination-26	3	weight	NN
# GUM_academic_discrimination-26	4	;	:
# GUM_academic_discrimination-27	1	sexual	JJ
# GUM_academic_discrimination-27	2	orientation	NN
# GUM_academic_discrimination-27	3	;	:
# GUM_academic_discrimination-28	1	education	NN
# GUM_academic_discrimination-28	2	or	CC
# GUM_academic_discrimination-28	3	income	NN
# GUM_academic_discrimination-28	4	;	:
# GUM_academic_discrimination-29	1	physical	JJ
# GUM_academic_discrimination-29	2	disability	NN
# GUM_academic_discrimination-29	3	;	:
# GUM_academic_discrimination-30	1	and	CC
# GUM_academic_discrimination-30	2	other	JJ
# GUM_academic_discrimination-30	3	.	.
# GUM_academic_discrimination-31	1	The	DT
# GUM_academic_discrimination-31	2	following	JJ
# GUM_academic_discrimination-31	3	categories	NNS
# GUM_academic_discrimination-31	4	from	IN
# GUM_academic_discrimination-31	5	the	DT
# GUM_academic_discrimination-31	6	original	JJ
# GUM_academic_discrimination-31	7	questionnaire	NN
# GUM_academic_discrimination-31	8	were	VBD
# GUM_academic_discrimination-31	9	collapsed	VBN
# GUM_academic_discrimination-31	10	into	IN
# GUM_academic_discrimination-31	11	one	NN
# GUM_academic_discrimination-31	1	category	NN
# GUM_academic_discrimination-31	2	for	IN
# GUM_academic_discrimination-31	3	the	DT
# GUM_academic_discrimination-31	4	analysis	NN
# GUM_academic_discrimination-31	5	:	:
# GUM_academic_discrimination-31	6	race	NN
# GUM_academic_discrimination-31	7	;	:
# GUM_academic_discrimination-31	8	ancestry	NN
# GUM_academic_discrimination-31	1	or	CC
# GUM_academic_discrimination-31	2	national	JJ
# GUM_academic_discrimination-31	1	origin	NN
# GUM_academic_discrimination-31	2	;	:
# GUM_academic_discrimination-31	3	and	CC
# GUM_academic_discrimination-31	4	shade	NN
# GUM_academic_discrimination-31	5	of	IN
# GUM_academic_discrimination-31	6	skin	DT
# GUM_academic_discrimination-31	7	color	NN
# GUM_academic_discrimination-31	8	.	.
# GUM_academic_discrimination-32	1	Additionally	UH
# GUM_academic_discrimination-32	2	,	,
# GUM_academic_discrimination-32	3	because	IN
# GUM_academic_discrimination-32	4	this	DT
# GUM_academic_discrimination-32	5	question	NN
# GUM_academic_discrimination-32	6	was	VBD
# GUM_academic_discrimination-32	7	only	RB
# GUM_academic_discrimination-32	8	asked	VBN
# GUM_academic_discrimination-32	9	of	IN
# GUM_academic_discrimination-32	10	respondents	NNS
# GUM_academic_discrimination-32	11	who	WP
# GUM_academic_discrimination-32	1	reported	VBD
# GUM_academic_discrimination-32	2	prior	DT
# GUM_academic_discrimination-32	3	discrimination	NN
# GUM_academic_discrimination-32	4	experiences	NNS
# GUM_academic_discrimination-32	5	,	,
# GUM_academic_discrimination-32	6	the	DT
# GUM_academic_discrimination-32	7	built	NN
# GUM_academic_discrimination-32	8	-	HYPH
# GUM_academic_discrimination-32	1	in	IN
# GUM_academic_discrimination-32	2	skip	DT
# GUM_academic_discrimination-32	1	pattern	NN
# GUM_academic_discrimination-32	2	resulted	NN
# GUM_academic_discrimination-32	3	in	IN
# GUM_academic_discrimination-32	4	a	DT
# GUM_academic_discrimination-32	5	large	JJ
# GUM_academic_discrimination-32	6	number	NN
# GUM_academic_discrimination-32	7	of	IN
# GUM_academic_discrimination-32	8	cases	DT
# GUM_academic_discrimination-32	9	scored	NN
# GUM_academic_discrimination-32	10	as	IN
# GUM_academic_discrimination-32	11	missing	NNP
# GUM_academic_discrimination-32	12	(	-LRB-
# GUM_academic_discrimination-32	13	legitimate	CD
# GUM_academic_discrimination-32	14	skip	CD
# GUM_academic_discrimination-32	15	)	-RRB-
# GUM_academic_discrimination-32	16	.	.
# GUM_academic_discrimination-33	1	Respondent	NN
# GUM_academic_discrimination-33	2	race	NN
# GUM_academic_discrimination-33	3	.	.
# GUM_academic_discrimination-34	1	Because	IN
# GUM_academic_discrimination-34	2	a	DT
# GUM_academic_discrimination-34	3	race	NN
# GUM_academic_discrimination-34	4	variable	NN
# GUM_academic_discrimination-34	5	is	VBZ
# GUM_academic_discrimination-34	6	not	RB
# GUM_academic_discrimination-34	7	available	VBN
# GUM_academic_discrimination-34	8	from	IN
# GUM_academic_discrimination-34	9	the	DT
# GUM_academic_discrimination-34	10	Wave	NNP
# GUM_academic_discrimination-34	11	4	CD
# GUM_academic_discrimination-34	1	interviews	-RRB-
# GUM_academic_discrimination-34	2	,	,
# GUM_academic_discrimination-34	3	we	PRP
# GUM_academic_discrimination-34	4	use	VBP
# GUM_academic_discrimination-34	5	the	DT
# GUM_academic_discrimination-34	6	racial	JJ
# GUM_academic_discrimination-34	7	category	NN
# GUM_academic_discrimination-34	8	reported	NN
# GUM_academic_discrimination-34	1	by	IN
# GUM_academic_discrimination-34	2	the	DT
# GUM_academic_discrimination-34	1	respondent	NN
# GUM_academic_discrimination-34	2	during	IN
# GUM_academic_discrimination-34	3	the	DT
# GUM_academic_discrimination-34	4	Wave	NNP
# GUM_academic_discrimination-34	5	1	CD
# GUM_academic_discrimination-34	6	interview	-RRB-
# GUM_academic_discrimination-34	7	.	.
# GUM_academic_discrimination-35	1	Wave	$
# GUM_academic_discrimination-35	2	1	CD
# GUM_academic_discrimination-35	3	race	NN
# GUM_academic_discrimination-35	4	—	:
# GUM_academic_discrimination-35	5	rather	RB
# GUM_academic_discrimination-35	6	than	RB
# GUM_academic_discrimination-35	7	,	,
# GUM_academic_discrimination-35	8	say	NNP
# GUM_academic_discrimination-35	9	,	,
# GUM_academic_discrimination-35	10	Wave	NNP
# GUM_academic_discrimination-35	11	3	CD
# GUM_academic_discrimination-35	1	race	NN
# GUM_academic_discrimination-35	2	—	:
# GUM_academic_discrimination-35	3	was	VBD
# GUM_academic_discrimination-35	4	used	VBN
# GUM_academic_discrimination-35	5	to	TO
# GUM_academic_discrimination-35	6	preserve	VB
# GUM_academic_discrimination-35	7	case	NN
# GUM_academic_discrimination-35	8	counts	NNS
# GUM_academic_discrimination-35	1	.	.
# GUM_academic_discrimination-36	1	The	DT
# GUM_academic_discrimination-36	2	logic	NN
# GUM_academic_discrimination-36	3	is	VBZ
# GUM_academic_discrimination-36	4	that	DT
# GUM_academic_discrimination-36	5	(	-LRB-
# GUM_academic_discrimination-36	6	nearly	CD
# GUM_academic_discrimination-36	7	)	-RRB-
# GUM_academic_discrimination-36	8	all	.
# GUM_academic_discrimination-36	9	Wave	-LRB-
# GUM_academic_discrimination-36	10	4	CD
# GUM_academic_discrimination-36	11	respondents	NNS
# GUM_academic_discrimination-36	1	appeared	VBD
# GUM_academic_discrimination-36	2	in	IN
# GUM_academic_discrimination-36	3	the	DT
# GUM_academic_discrimination-36	4	Wave	NNP
# GUM_academic_discrimination-36	5	1	CD
# GUM_academic_discrimination-36	6	sample	-RRB-
# GUM_academic_discrimination-36	7	,	,
# GUM_academic_discrimination-36	8	but	CC
# GUM_academic_discrimination-36	1	not	RB
# GUM_academic_discrimination-36	2	all	DT
# GUM_academic_discrimination-36	1	would	MD
# GUM_academic_discrimination-36	2	have	VB
# GUM_academic_discrimination-36	3	been	VBN
# GUM_academic_discrimination-36	4	interviewed	VBN
# GUM_academic_discrimination-36	5	at	IN
# GUM_academic_discrimination-36	6	Wave	NNP
# GUM_academic_discrimination-36	7	3	CD
# GUM_academic_discrimination-36	8	due	-RRB-
# GUM_academic_discrimination-36	9	to	IN
# GUM_academic_discrimination-36	10	differential	JJ
# GUM_academic_discrimination-36	11	patterns	NNS
# GUM_academic_discrimination-36	12	of	IN
# GUM_academic_discrimination-36	13	temporary	DT
# GUM_academic_discrimination-36	14	attrition	NN
# GUM_academic_discrimination-36	15	.	.
# GUM_academic_discrimination-37	1	Respondents	NNS
# GUM_academic_discrimination-37	2	were	VBD
# GUM_academic_discrimination-37	3	asked	VBN
# GUM_academic_discrimination-37	4	to	TO
# GUM_academic_discrimination-37	5	indicate	VB
# GUM_academic_discrimination-37	6	their	PRP$
# GUM_academic_discrimination-37	7	race	NN
# GUM_academic_discrimination-37	8	from	IN
# GUM_academic_discrimination-37	9	among	IN
# GUM_academic_discrimination-37	10	the	DT
# GUM_academic_discrimination-37	11	following	JJ
# GUM_academic_discrimination-37	1	categories	NNS
# GUM_academic_discrimination-37	2	:	:
# GUM_academic_discrimination-37	3	White	UH
# GUM_academic_discrimination-37	4	;	:
# GUM_academic_discrimination-37	5	Black	NNP
# GUM_academic_discrimination-37	6	or	CC
# GUM_academic_discrimination-37	7	African	NNP
# GUM_academic_discrimination-37	8	American	NNP
# GUM_academic_discrimination-37	1	;	NNP
# GUM_academic_discrimination-37	2	Hispanic	NNP
# GUM_academic_discrimination-37	1	;	NNP
# GUM_academic_discrimination-37	2	American	NNP
# GUM_academic_discrimination-37	3	Indian	NNP
# GUM_academic_discrimination-37	4	or	CC
# GUM_academic_discrimination-37	5	Native	NNP
# GUM_academic_discrimination-37	6	American	NNP
# GUM_academic_discrimination-37	7	;	:
# GUM_academic_discrimination-37	8	and	CC
# GUM_academic_discrimination-37	9	Asian	NNP
# GUM_academic_discrimination-37	10	or	CC
# GUM_academic_discrimination-37	11	Pacific	NNP
# GUM_academic_discrimination-37	12	Islander	NNP
# GUM_academic_discrimination-37	13	.	.
# GUM_academic_discrimination-38	1	Respondents	NNS
# GUM_academic_discrimination-38	2	were	VBD
# GUM_academic_discrimination-38	3	provided	IN
# GUM_academic_discrimination-38	4	the	DT
# GUM_academic_discrimination-38	5	opportunity	NN
# GUM_academic_discrimination-38	6	to	TO
# GUM_academic_discrimination-38	7	select	VB
# GUM_academic_discrimination-38	8	more	RBR
# GUM_academic_discrimination-38	9	than	IN
# GUM_academic_discrimination-38	10	one	NN
# GUM_academic_discrimination-38	11	race	NN
# GUM_academic_discrimination-38	1	,	,
# GUM_academic_discrimination-38	2	and	CC
# GUM_academic_discrimination-38	3	those	DT
# GUM_academic_discrimination-38	4	who	WP
# GUM_academic_discrimination-38	5	did	VBD
# GUM_academic_discrimination-38	6	were	PRP
# GUM_academic_discrimination-38	7	asked	VBD
# GUM_academic_discrimination-38	8	a	DT
# GUM_academic_discrimination-38	1	follow	NN
# GUM_academic_discrimination-38	2	-	HYPH
# GUM_academic_discrimination-38	1	up	JJ
# GUM_academic_discrimination-38	2	question	NN
# GUM_academic_discrimination-38	3	regarding	IN
# GUM_academic_discrimination-38	4	which	DT
# GUM_academic_discrimination-38	5	category	NN
# GUM_academic_discrimination-38	6	best	NN
# GUM_academic_discrimination-38	7	described	IN
# GUM_academic_discrimination-38	8	their	PRP$
# GUM_academic_discrimination-38	9	racial	JJ
# GUM_academic_discrimination-38	10	background	NN
# GUM_academic_discrimination-38	11	.	.
# GUM_academic_discrimination-39	1	In	IN
# GUM_academic_discrimination-39	2	the	DT
# GUM_academic_discrimination-39	3	current	JJ
# GUM_academic_discrimination-39	4	study	NN
# GUM_academic_discrimination-39	5	,	,
# GUM_academic_discrimination-39	6	those	DT
# GUM_academic_discrimination-39	7	respondents	NNS
# GUM_academic_discrimination-39	8	who	IN
# GUM_academic_discrimination-39	9	indicated	DT
# GUM_academic_discrimination-39	10	more	NN
# GUM_academic_discrimination-39	11	than	IN
# GUM_academic_discrimination-39	1	one	NN
# GUM_academic_discrimination-39	2	race	NN
# GUM_academic_discrimination-39	3	were	VBD
# GUM_academic_discrimination-39	4	coded	VBN
# GUM_academic_discrimination-39	5	as	IN
# GUM_academic_discrimination-39	6	“	DT
# GUM_academic_discrimination-39	7	mixed	VBN
# GUM_academic_discrimination-39	8	race	NN
# GUM_academic_discrimination-39	1	”	''
# GUM_academic_discrimination-39	2	.	.
# GUM_academic_discrimination-40	1	Demographic	JJ
# GUM_academic_discrimination-40	2	variables	NNS
# GUM_academic_discrimination-40	3	.	.
# GUM_academic_discrimination-41	1	To	TO
# GUM_academic_discrimination-41	2	provide	VB
# GUM_academic_discrimination-41	3	information	NN
# GUM_academic_discrimination-41	4	on	IN
# GUM_academic_discrimination-41	5	the	DT
# GUM_academic_discrimination-41	6	analytical	JJ
# GUM_academic_discrimination-41	7	sample	NN
# GUM_academic_discrimination-41	8	as	IN
# GUM_academic_discrimination-41	9	a	DT
# GUM_academic_discrimination-41	10	whole	NN
# GUM_academic_discrimination-41	11	,	,
# GUM_academic_discrimination-41	1	two	CD
# GUM_academic_discrimination-41	2	additional	-RRB-
# GUM_academic_discrimination-41	3	demographic	JJ
# GUM_academic_discrimination-41	4	variables	NNS
# GUM_academic_discrimination-41	5	are	VBP
# GUM_academic_discrimination-41	6	included	VBN
# GUM_academic_discrimination-41	7	.	.
# GUM_academic_discrimination-42	1	First	RB
# GUM_academic_discrimination-42	2	,	,
# GUM_academic_discrimination-42	3	age	NN
# GUM_academic_discrimination-42	4	is	VBZ
# GUM_academic_discrimination-42	5	a	DT
# GUM_academic_discrimination-42	6	continuous	NN
# GUM_academic_discrimination-42	7	measure	VBZ
# GUM_academic_discrimination-42	8	created	VBN
# GUM_academic_discrimination-42	9	by	IN
# GUM_academic_discrimination-42	10	subtracting	VBG
# GUM_academic_discrimination-42	11	the	DT
# GUM_academic_discrimination-42	1	year	NN
# GUM_academic_discrimination-42	2	of	IN
# GUM_academic_discrimination-42	3	the	DT
# GUM_academic_discrimination-42	4	respondents	NNS
# GUM_academic_discrimination-42	5	'	POS
# GUM_academic_discrimination-42	6	birth	NN
# GUM_academic_discrimination-42	7	(	-LRB-
# GUM_academic_discrimination-42	8	obtained	VBN
# GUM_academic_discrimination-42	1	from	IN
# GUM_academic_discrimination-42	2	Wave	NNP
# GUM_academic_discrimination-42	1	1	CD
# GUM_academic_discrimination-42	2	)	-RRB-
# GUM_academic_discrimination-42	3	from	IN
# GUM_academic_discrimination-42	4	the	DT
# GUM_academic_discrimination-42	5	year	NN
# GUM_academic_discrimination-42	6	of	IN
# GUM_academic_discrimination-42	7	the	DT
# GUM_academic_discrimination-42	8	interview	NN
# GUM_academic_discrimination-42	9	at	IN
# GUM_academic_discrimination-42	10	Wave	NNP
# GUM_academic_discrimination-42	11	4	CD
# GUM_academic_discrimination-42	12	.	.
# GUM_academic_discrimination-43	1	Second	RB
# GUM_academic_discrimination-43	2	,	,
# GUM_academic_discrimination-43	3	sex	NN
# GUM_academic_discrimination-43	4	was	VBD
# GUM_academic_discrimination-43	5	dichotomously	RB
# GUM_academic_discrimination-43	6	coded	VBN
# GUM_academic_discrimination-43	7	based	VBN
# GUM_academic_discrimination-43	8	on	IN
# GUM_academic_discrimination-43	9	the	DT
# GUM_academic_discrimination-43	10	self	NN
# GUM_academic_discrimination-43	11	-	HYPH
# GUM_academic_discrimination-43	1	reported	JJ
# GUM_academic_discrimination-43	2	sex	NN
# GUM_academic_discrimination-43	3	of	IN
# GUM_academic_discrimination-43	4	the	DT
# GUM_academic_discrimination-43	5	respondent	NN
# GUM_academic_discrimination-43	6	at	IN
# GUM_academic_discrimination-43	7	Wave	NNP
# GUM_academic_discrimination-43	8	4	NNP
# GUM_academic_discrimination-43	1	(	-LRB-
# GUM_academic_discrimination-43	2	0	CD
# GUM_academic_discrimination-43	1	=	-RRB-
# GUM_academic_discrimination-43	2	female	,
# GUM_academic_discrimination-43	3	and	CC
# GUM_academic_discrimination-43	4	1	CD
# GUM_academic_discrimination-43	5	=	SYM
# GUM_academic_discrimination-43	6	male	CD
# GUM_academic_discrimination-43	7	)	-RRB-
# GUM_academic_discrimination-43	8	.	.
# GUM_academic_discrimination-44	1	Analytical	JJ
# GUM_academic_discrimination-44	2	plan	NN
# GUM_academic_discrimination-44	3	.	.
# GUM_academic_discrimination-45	1	Our	PRP$
# GUM_academic_discrimination-45	2	exploratory	JJ
# GUM_academic_discrimination-45	3	study	NN
# GUM_academic_discrimination-45	4	included	IN
# GUM_academic_discrimination-45	5	three	DT
# GUM_academic_discrimination-45	6	basic	JJ
# GUM_academic_discrimination-45	7	steps	NNS
# GUM_academic_discrimination-45	8	.	.
# GUM_academic_discrimination-46	1	First	RB
# GUM_academic_discrimination-46	2	,	,
# GUM_academic_discrimination-46	3	summary	DT
# GUM_academic_discrimination-46	4	statistics	NN
# GUM_academic_discrimination-46	5	of	IN
# GUM_academic_discrimination-46	6	the	DT
# GUM_academic_discrimination-46	7	study	NN
# GUM_academic_discrimination-46	8	variables	,
# GUM_academic_discrimination-46	9	and	CC
# GUM_academic_discrimination-46	10	racial	JJ
# GUM_academic_discrimination-46	11	categories	NNS
# GUM_academic_discrimination-46	1	were	VBD
# GUM_academic_discrimination-46	2	produced	VBN
# GUM_academic_discrimination-46	3	.	.
# GUM_academic_discrimination-47	1	Second	RB
# GUM_academic_discrimination-47	2	,	,
# GUM_academic_discrimination-47	3	we	PRP
# GUM_academic_discrimination-47	4	examined	VBD
# GUM_academic_discrimination-47	5	the	DT
# GUM_academic_discrimination-47	6	relative	JJ
# GUM_academic_discrimination-47	7	proportions	NNS
# GUM_academic_discrimination-47	8	of	IN
# GUM_academic_discrimination-47	9	the	DT
# GUM_academic_discrimination-47	10	two	JJ
# GUM_academic_discrimination-47	11	discrimination	NN
# GUM_academic_discrimination-47	1	experience	NN
# GUM_academic_discrimination-47	2	measures	NN
# GUM_academic_discrimination-47	3	across	IN
# GUM_academic_discrimination-47	4	each	DT
# GUM_academic_discrimination-47	5	racial	JJ
# GUM_academic_discrimination-47	6	category	NN
# GUM_academic_discrimination-47	7	.	.
# GUM_academic_discrimination-48	1	Finally	RB
# GUM_academic_discrimination-48	2	,	,
# GUM_academic_discrimination-48	3	we	PRP
# GUM_academic_discrimination-48	4	assessed	VBD
# GUM_academic_discrimination-48	5	the	DT
# GUM_academic_discrimination-48	6	distribution	NN
# GUM_academic_discrimination-48	7	of	IN
# GUM_academic_discrimination-48	8	reported	DT
# GUM_academic_discrimination-48	9	reasons	NNS
# GUM_academic_discrimination-48	10	for	IN
# GUM_academic_discrimination-48	11	discrimination	NN
# GUM_academic_discrimination-48	1	across	IN
# GUM_academic_discrimination-48	2	the	DT
# GUM_academic_discrimination-48	3	racial	JJ
# GUM_academic_discrimination-48	4	categories	NNS
# GUM_academic_discrimination-48	5	.	.
# GUM_academic_discrimination-49	1	In	IN
# GUM_academic_discrimination-49	2	order	NN
# GUM_academic_discrimination-49	3	to	TO
# GUM_academic_discrimination-49	4	examine	VB
# GUM_academic_discrimination-49	5	potential	DT
# GUM_academic_discrimination-49	6	bivariate	JJ
# GUM_academic_discrimination-49	7	associations	NNS
# GUM_academic_discrimination-49	8	,	,
# GUM_academic_discrimination-49	9	the	DT
# GUM_academic_discrimination-49	10	adjusted	VBN
# GUM_academic_discrimination-49	11	F	IN
# GUM_academic_discrimination-49	1	statistic	NN
# GUM_academic_discrimination-49	2	(	-LRB-
# GUM_academic_discrimination-49	3	design	CD
# GUM_academic_discrimination-49	4	-	HYPH
# GUM_academic_discrimination-49	5	based	VBN
# GUM_academic_discrimination-49	6	F	CD
# GUM_academic_discrimination-49	7	)	-RRB-
# GUM_academic_discrimination-49	8	was	VBD
# GUM_academic_discrimination-49	1	employed	VBN
# GUM_academic_discrimination-49	2	as	IN
# GUM_academic_discrimination-49	1	it	PRP
# GUM_academic_discrimination-49	2	corrects	VBZ
# GUM_academic_discrimination-49	3	for	IN
# GUM_academic_discrimination-49	4	a	DT
# GUM_academic_discrimination-49	5	complex	JJ
# GUM_academic_discrimination-49	6	sample	NN
# GUM_academic_discrimination-49	7	design	IN
# GUM_academic_discrimination-49	8	such	JJ
# GUM_academic_discrimination-49	9	as	IN
# GUM_academic_discrimination-49	10	that	DT
# GUM_academic_discrimination-49	11	used	VBN
# GUM_academic_discrimination-49	12	in	IN
# GUM_academic_discrimination-49	13	the	DT
# GUM_academic_discrimination-49	14	Add	JJ
# GUM_academic_discrimination-49	15	Health	NN
# GUM_academic_discrimination-49	16	.	.
# GUM_academic_discrimination-49	17	[	-LRB-
# GUM_academic_discrimination-49	18	21	CD
# GUM_academic_discrimination-49	19	]	-RRB-
# GUM_academic_discrimination-50	1	More	RBR
# GUM_academic_discrimination-50	2	specifically	RB
# GUM_academic_discrimination-50	3	,	,
# GUM_academic_discrimination-50	4	when	PRP
# GUM_academic_discrimination-50	5	analyzing	VBD
# GUM_academic_discrimination-50	6	weighted	VBN
# GUM_academic_discrimination-50	7	sample	NN
# GUM_academic_discrimination-50	8	data	NNS
# GUM_academic_discrimination-50	9	employing	VBG
# GUM_academic_discrimination-50	10	the	DT
# GUM_academic_discrimination-50	11	svy	NNP
# GUM_academic_discrimination-50	1	suite	NN
# GUM_academic_discrimination-50	2	of	IN
# GUM_academic_discrimination-50	3	commands	NNS
# GUM_academic_discrimination-50	4	in	IN
# GUM_academic_discrimination-50	5	Stata	NNP
# GUM_academic_discrimination-50	6	the	DT
# GUM_academic_discrimination-50	7	conventional	NNP
# GUM_academic_discrimination-50	8	Pearson	NNP
# GUM_academic_discrimination-50	1	χ2	SYM
# GUM_academic_discrimination-50	2	statistic	NN
# GUM_academic_discrimination-50	1	test	NN
# GUM_academic_discrimination-50	2	of	IN
# GUM_academic_discrimination-50	3	independence	NN
# GUM_academic_discrimination-50	4	is	VBZ
# GUM_academic_discrimination-50	5	converted	VBN
# GUM_academic_discrimination-50	6	into	IN
# GUM_academic_discrimination-50	7	“	``
# GUM_academic_discrimination-50	8	an	DT
# GUM_academic_discrimination-50	9	F	JJ
# GUM_academic_discrimination-50	10	statistic	NN
# GUM_academic_discrimination-50	11	with	IN
# GUM_academic_discrimination-50	12	noninteger	JJ
# GUM_academic_discrimination-50	13	degrees	NNS
# GUM_academic_discrimination-50	14	of	IN
# GUM_academic_discrimination-50	15	freedom	NN
# GUM_academic_discrimination-50	16	by	IN
# GUM_academic_discrimination-50	17	using	VBG
# GUM_academic_discrimination-50	18	a	DT
# GUM_academic_discrimination-50	19	second	JJ
# GUM_academic_discrimination-50	20	-	HYPH
# GUM_academic_discrimination-50	21	order	NNP
# GUM_academic_discrimination-50	1	Rao	NNP
# GUM_academic_discrimination-50	2	and	CC
# GUM_academic_discrimination-50	3	Scott	NNP
# GUM_academic_discrimination-50	4	(	-LRB-
# GUM_academic_discrimination-50	5	1981	CD
# GUM_academic_discrimination-50	6	[	-LRB-
# GUM_academic_discrimination-50	7	22	CD
# GUM_academic_discrimination-50	8	]	-RRB-
# GUM_academic_discrimination-50	9	,	,
# GUM_academic_discrimination-50	10	1984	NNP
# GUM_academic_discrimination-50	11	[	-LRB-
# GUM_academic_discrimination-50	12	23	CD
# GUM_academic_discrimination-50	13	]	-RRB-
# GUM_academic_discrimination-50	14	)	-RRB-
# GUM_academic_discrimination-50	1	correction	.
# GUM_academic_discrimination-50	2	”	UH
# GUM_academic_discrimination-50	3	.	.
# GUM_academic_discrimination-50	4	[	-LRB-
# GUM_academic_discrimination-50	5	24	CD
# GUM_academic_discrimination-50	6	]	-RRB-
# GUM_academic_discrimination-51	1	The	DT
# GUM_academic_discrimination-51	2	p	NN
# GUM_academic_discrimination-51	3	-	HYPH
# GUM_academic_discrimination-51	4	value	NN
# GUM_academic_discrimination-51	5	associated	VBN
# GUM_academic_discrimination-51	6	with	IN
# GUM_academic_discrimination-51	7	the	DT
# GUM_academic_discrimination-51	8	design	NN
# GUM_academic_discrimination-51	9	-	HYPH
# GUM_academic_discrimination-51	10	based	VBN
# GUM_academic_discrimination-51	11	F	NN
# GUM_academic_discrimination-51	1	is	VBZ
# GUM_academic_discrimination-51	2	thus	RB
# GUM_academic_discrimination-51	3	more	RBR
# GUM_academic_discrimination-51	4	accurate	JJ
# GUM_academic_discrimination-51	5	(	NN
# GUM_academic_discrimination-51	6	than	IN
# GUM_academic_discrimination-51	7	the	DT
# GUM_academic_discrimination-51	8	associated	NN
# GUM_academic_discrimination-51	1	with	IN
# GUM_academic_discrimination-51	2	the	CD
# GUM_academic_discrimination-51	1	χ2	SYM
# GUM_academic_discrimination-51	2	statistic	NN
# GUM_academic_discrimination-51	3	)	-RRB-
# GUM_academic_discrimination-51	4	given	IN
# GUM_academic_discrimination-51	5	the	DT
# GUM_academic_discrimination-51	6	adjustments	NNS
# GUM_academic_discrimination-51	7	and	CC
# GUM_academic_discrimination-51	8	calculations	NNS
# GUM_academic_discrimination-51	9	take	,
# GUM_academic_discrimination-51	10	into	IN
# GUM_academic_discrimination-51	11	account	VBG
# GUM_academic_discrimination-51	12	the	DT
# GUM_academic_discrimination-51	13	weighted	VBN
# GUM_academic_discrimination-51	14	nature	NN
# GUM_academic_discrimination-51	15	of	IN
# GUM_academic_discrimination-51	16	the	DT
# GUM_academic_discrimination-51	17	data	NNS
# GUM_academic_discrimination-51	18	.	.
# GUM_academic_discrimination-52	1	This	DT
# GUM_academic_discrimination-52	2	final	JJ
# GUM_academic_discrimination-52	3	step	NN
# GUM_academic_discrimination-52	4	also	RB
# GUM_academic_discrimination-52	5	included	IN
# GUM_academic_discrimination-52	6	an	DT
# GUM_academic_discrimination-52	7	examination	NN
# GUM_academic_discrimination-52	8	of	IN
# GUM_academic_discrimination-52	9	the	DT
# GUM_academic_discrimination-52	10	relative	JJ
# GUM_academic_discrimination-52	11	distribution	NN
# GUM_academic_discrimination-52	1	of	IN
# GUM_academic_discrimination-52	2	racial	JJ
# GUM_academic_discrimination-52	3	categories	NNS
# GUM_academic_discrimination-52	4	across	IN
# GUM_academic_discrimination-52	5	the	DT
# GUM_academic_discrimination-52	6	various	JJ
# GUM_academic_discrimination-52	7	reported	JJ
# GUM_academic_discrimination-52	8	reasons	NNS
# GUM_academic_discrimination-52	1	for	IN
# GUM_academic_discrimination-52	2	discrimination	NN
# GUM_academic_discrimination-52	1	.	.
# GUM_academic_discrimination-53	1	As	IN
# GUM_academic_discrimination-53	2	noted	DT
# GUM_academic_discrimination-53	3	earlier	NN
# GUM_academic_discrimination-53	4	,	,
# GUM_academic_discrimination-53	5	all	DT
# GUM_academic_discrimination-53	6	analyses	NNS
# GUM_academic_discrimination-53	7	were	VBD
# GUM_academic_discrimination-53	8	weighted	VBN
# GUM_academic_discrimination-53	9	according	VBN
# GUM_academic_discrimination-53	10	to	IN
# GUM_academic_discrimination-53	11	the	DT
# GUM_academic_discrimination-53	1	survey	NN
# GUM_academic_discrimination-53	2	weight	VBZ
# GUM_academic_discrimination-53	3	provided	VBN
# GUM_academic_discrimination-53	4	by	IN
# GUM_academic_discrimination-53	5	the	DT
# GUM_academic_discrimination-53	6	Add	NN
# GUM_academic_discrimination-53	7	Health	IN
# GUM_academic_discrimination-53	8	research	NN
# GUM_academic_discrimination-53	1	staff	,
# GUM_academic_discrimination-53	2	and	CC
# GUM_academic_discrimination-53	1	standard	JJ
# GUM_academic_discrimination-53	2	errors	NNS
# GUM_academic_discrimination-53	3	were	VBD
# GUM_academic_discrimination-53	4	corrected	VBN
# GUM_academic_discrimination-53	5	for	IN
# GUM_academic_discrimination-53	6	the	DT
# GUM_academic_discrimination-53	7	clustering	NN
# GUM_academic_discrimination-53	8	and	CC
# GUM_academic_discrimination-53	9	stratification	NN
# GUM_academic_discrimination-53	10	that	IN
# GUM_academic_discrimination-53	11	defined	VBG
# GUM_academic_discrimination-53	12	the	DT
# GUM_academic_discrimination-53	13	sampling	NN
# GUM_academic_discrimination-53	14	strategy	NN
# GUM_academic_discrimination-53	15	.	.
# GUM_academic_discrimination-54	1	Thus	RB
# GUM_academic_discrimination-54	2	,	,
# GUM_academic_discrimination-54	3	all	DT
# GUM_academic_discrimination-54	4	estimates	NNS
# GUM_academic_discrimination-54	5	reported	.
# GUM_academic_discrimination-54	6	here	PRP
# GUM_academic_discrimination-54	7	can	MD
# GUM_academic_discrimination-54	8	be	VB
# GUM_academic_discrimination-54	9	considered	VBN
# GUM_academic_discrimination-54	10	nationally	RB
# GUM_academic_discrimination-54	11	representative	VBN
# GUM_academic_discrimination-54	1	of	IN
# GUM_academic_discrimination-54	2	the	DT
# GUM_academic_discrimination-54	3	United	NNP
# GUM_academic_discrimination-54	4	States	NNPS
# GUM_academic_discrimination-54	5	.	.
# GUM_academic_eegimaa-1	1	2.	``
# GUM_academic_eegimaa-1	2	GUJJOLAAY	NNP
# GUM_academic_eegimaa-1	3	EEGIMAA	NNP
# GUM_academic_eegimaa-1	4	,	,
# GUM_academic_eegimaa-1	5	ITS	PRP$
# GUM_academic_eegimaa-1	6	SPEAKERS	NNS
# GUM_academic_eegimaa-1	7	AND	IN
# GUM_academic_eegimaa-1	8	THEIR	PRP$
# GUM_academic_eegimaa-1	9	NEIGHBOURS	NNS
# GUM_academic_eegimaa-2	1	This	DT
# GUM_academic_eegimaa-2	2	section	NN
# GUM_academic_eegimaa-2	3	briefly	RB
# GUM_academic_eegimaa-2	4	presents	IN
# GUM_academic_eegimaa-2	5	the	DT
# GUM_academic_eegimaa-2	6	Gújjolaay	NNP
# GUM_academic_eegimaa-2	7	Eegimaa	NNP
# GUM_academic_eegimaa-2	8	(	-LRB-
# GUM_academic_eegimaa-2	9	Eegimaa	NNP
# GUM_academic_eegimaa-2	10	for	IN
# GUM_academic_eegimaa-2	11	short	DT
# GUM_academic_eegimaa-2	1	;	:
# GUM_academic_eegimaa-2	2	Ethnologue	NNP
# GUM_academic_eegimaa-2	3	code	NN
# GUM_academic_eegimaa-2	4	:	:
# GUM_academic_eegimaa-2	5	ISO	NNP
# GUM_academic_eegimaa-2	6	639-3	CD
# GUM_academic_eegimaa-2	7	:	:
# GUM_academic_eegimaa-2	8	bqj	NNP
# GUM_academic_eegimaa-2	1	)	-RRB-
# GUM_academic_eegimaa-2	2	,	,
# GUM_academic_eegimaa-2	1	its	PRP$
# GUM_academic_eegimaa-2	2	speakers	NNS
# GUM_academic_eegimaa-2	3	and	CC
# GUM_academic_eegimaa-2	4	its	PRP$
# GUM_academic_eegimaa-2	5	varieties	NNS
# GUM_academic_eegimaa-2	6	.	.
# GUM_academic_eegimaa-3	1	We	PRP
# GUM_academic_eegimaa-3	2	also	RB
# GUM_academic_eegimaa-3	3	discuss	JJ
# GUM_academic_eegimaa-3	4	aspects	NNS
# GUM_academic_eegimaa-3	5	of	IN
# GUM_academic_eegimaa-3	6	the	DT
# GUM_academic_eegimaa-3	7	contact	JJ
# GUM_academic_eegimaa-3	8	situation	NN
# GUM_academic_eegimaa-3	9	of	IN
# GUM_academic_eegimaa-3	10	the	DT
# GUM_academic_eegimaa-3	11	Eegimaa	NNP
# GUM_academic_eegimaa-3	1	language	NN
# GUM_academic_eegimaa-3	2	.	.
# GUM_academic_eegimaa-4	1	This	DT
# GUM_academic_eegimaa-4	2	is	VBZ
# GUM_academic_eegimaa-4	3	important	JJ
# GUM_academic_eegimaa-4	4	,	,
# GUM_academic_eegimaa-4	5	because	IN
# GUM_academic_eegimaa-4	6	as	IN
# GUM_academic_eegimaa-4	7	we	PRP
# GUM_academic_eegimaa-4	8	will	MD
# GUM_academic_eegimaa-4	9	show	VB
# GUM_academic_eegimaa-4	10	in	RP
# GUM_academic_eegimaa-4	11	§	SYM
# GUM_academic_eegimaa-4	1	6	CD
# GUM_academic_eegimaa-4	2	below	-RRB-
# GUM_academic_eegimaa-4	3	,	,
# GUM_academic_eegimaa-4	4	some	DT
# GUM_academic_eegimaa-4	5	of	IN
# GUM_academic_eegimaa-4	6	the	DT
# GUM_academic_eegimaa-4	7	Eegimaa	NNP
# GUM_academic_eegimaa-4	8	death	POS
# GUM_academic_eegimaa-4	1	prevention	NN
# GUM_academic_eegimaa-4	2	names	,
# GUM_academic_eegimaa-4	1	and	CC
# GUM_academic_eegimaa-4	2	child	NN
# GUM_academic_eegimaa-4	3	-	HYPH
# GUM_academic_eegimaa-4	4	bearing	NN
# GUM_academic_eegimaa-4	5	names	NNS
# GUM_academic_eegimaa-4	6	are	VBP
# GUM_academic_eegimaa-4	7	given	VBN
# GUM_academic_eegimaa-4	8	to	IN
# GUM_academic_eegimaa-4	9	Eegimaa	NNP
# GUM_academic_eegimaa-4	10	people	NNS
# GUM_academic_eegimaa-4	11	from	IN
# GUM_academic_eegimaa-4	12	other	JJ
# GUM_academic_eegimaa-4	13	communities	NNS
# GUM_academic_eegimaa-4	14	.	.
# GUM_academic_eegimaa-5	1	Eegimaa	NNP
# GUM_academic_eegimaa-5	2	is	VBZ
# GUM_academic_eegimaa-5	3	a	DT
# GUM_academic_eegimaa-5	4	Jóola	JJ
# GUM_academic_eegimaa-5	5	language	NN
# GUM_academic_eegimaa-5	6	spoken	VBN
# GUM_academic_eegimaa-5	7	in	IN
# GUM_academic_eegimaa-5	8	the	DT
# GUM_academic_eegimaa-5	9	Basse	NNP
# GUM_academic_eegimaa-5	10	Casamance	NNP
# GUM_academic_eegimaa-5	11	area	NNP
# GUM_academic_eegimaa-5	1	of	IN
# GUM_academic_eegimaa-5	2	Southern	NNP
# GUM_academic_eegimaa-5	3	Senegal	NNP
# GUM_academic_eegimaa-5	4	by	IN
# GUM_academic_eegimaa-5	5	a	DT
# GUM_academic_eegimaa-5	6	population	NN
# GUM_academic_eegimaa-5	7	estimated	VBD
# GUM_academic_eegimaa-5	8	to	TO
# GUM_academic_eegimaa-5	1	be	VB
# GUM_academic_eegimaa-5	2	between	IN
# GUM_academic_eegimaa-5	1	7,000	CD
# GUM_academic_eegimaa-5	2	(	-LRB-
# GUM_academic_eegimaa-5	3	Bassène	NNP
# GUM_academic_eegimaa-5	4	,	,
# ...
# GUM_academic_eegimaa-27	7	are	VBP
# GUM_academic_eegimaa-27	8	written	VBN
# GUM_academic_eegimaa-27	9	using	IN
# GUM_academic_eegimaa-27	10	the	DT
# GUM_academic_eegimaa-27	11	Eegimaa	NNP
# GUM_academic_eegimaa-27	1	orthography	NN
# GUM_academic_eegimaa-27	2	and	CC
# GUM_academic_eegimaa-27	3	following	VBG
# GUM_academic_eegimaa-27	4	the	DT
# GUM_academic_eegimaa-27	5	pronunciation	NN
# GUM_academic_eegimaa-27	6	of	IN
# GUM_academic_eegimaa-27	7	village	DT
# GUM_academic_eegimaa-27	8	names	NN
# GUM_academic_eegimaa-27	1	by	IN
# GUM_academic_eegimaa-27	2	native	JJ
# GUM_academic_eegimaa-27	1	speakers	NNS
# GUM_academic_eegimaa-27	2	.	.
# GUM_academic_eegimaa-28	1	Jóola	JJ
# GUM_academic_eegimaa-28	2	language	NN
# GUM_academic_eegimaa-28	3	varieties	NNS
# GUM_academic_eegimaa-28	4	which	WDT
# GUM_academic_eegimaa-28	5	are	VBP
# GUM_academic_eegimaa-28	6	closely	RB
# GUM_academic_eegimaa-28	7	related	VBN
# GUM_academic_eegimaa-28	8	to	IN
# GUM_academic_eegimaa-28	9	Eegimaa	NNP
# GUM_academic_eegimaa-28	10	include	NNP
# GUM_academic_eegimaa-28	11	Kujireray	NNP
# GUM_academic_eegimaa-28	1	/	NNP
# GUM_academic_eegimaa-28	2	Kuluunaay	NNP
# GUM_academic_eegimaa-28	3	(	-LRB-
# GUM_academic_eegimaa-28	4	from	IN
# GUM_academic_eegimaa-28	5	the	DT
# GUM_academic_eegimaa-28	6	village	NN
# GUM_academic_eegimaa-28	7	of	IN
# GUM_academic_eegimaa-28	8	Brin	NNP
# GUM_academic_eegimaa-28	1	with	IN
# GUM_academic_eegimaa-28	2	76	CD
# GUM_academic_eegimaa-28	1	%	-RRB-
# GUM_academic_eegimaa-28	2	lexical	JJ
# GUM_academic_eegimaa-28	3	similarity	NN
# GUM_academic_eegimaa-28	4	)	-RRB-
# GUM_academic_eegimaa-28	5	and	CC
# GUM_academic_eegimaa-28	6	Gufiñamay	NNP
# GUM_academic_eegimaa-28	7	(	-LRB-
# GUM_academic_eegimaa-28	8	from	IN
# GUM_academic_eegimaa-28	9	the	DT
# GUM_academic_eegimaa-28	10	village	NN
# GUM_academic_eegimaa-28	11	of	IN
# GUM_academic_eegimaa-28	12	Afiniam	NNP
# GUM_academic_eegimaa-28	13	with	IN
# GUM_academic_eegimaa-28	14	74	CD
# GUM_academic_eegimaa-28	15	%	-RRB-
# GUM_academic_eegimaa-28	16	lexical	JJ
# GUM_academic_eegimaa-28	17	similarity	NN
# GUM_academic_eegimaa-28	18	(	-LRB-
# GUM_academic_eegimaa-28	19	based	VBN
# GUM_academic_eegimaa-28	20	on	IN
# GUM_academic_eegimaa-28	21	Lewis	NNP
# GUM_academic_eegimaa-28	1	et	NNP
# GUM_academic_eegimaa-28	2	al.	NNP
# GUM_academic_eegimaa-28	3	,	,
# GUM_academic_eegimaa-28	4	2014	CD
# GUM_academic_eegimaa-28	5	eds.	NNS
# GUM_academic_eegimaa-28	6	)	-RRB-
# GUM_academic_eegimaa-28	7	)	-RRB-
# GUM_academic_eegimaa-28	8	.	.
# GUM_academic_eegimaa-29	1	Gútaamay	NNP
# GUM_academic_eegimaa-29	2	(	-LRB-
# GUM_academic_eegimaa-29	3	from	IN
# GUM_academic_eegimaa-29	4	the	DT
# GUM_academic_eegimaa-29	5	village	NN
# GUM_academic_eegimaa-29	6	of	IN
# GUM_academic_eegimaa-29	7	Butam	NNP
# GUM_academic_eegimaa-29	8	)	-RRB-
# GUM_academic_eegimaa-29	9	,	,
# GUM_academic_eegimaa-29	10	Gulapaoray	NNP
# GUM_academic_eegimaa-29	11	(	-LRB-
# GUM_academic_eegimaa-29	1	from	IN
# GUM_academic_eegimaa-29	2	the	DT
# GUM_academic_eegimaa-29	3	village	NN
# GUM_academic_eegimaa-29	4	Djilapaor	NNP
# GUM_academic_eegimaa-29	5	)	-RRB-
# GUM_academic_eegimaa-29	6	and	CC
# GUM_academic_eegimaa-29	7	Gusiilay	NNP
# GUM_academic_eegimaa-29	8	(	-LRB-
# GUM_academic_eegimaa-29	1	ISO	NNP
# GUM_academic_eegimaa-29	2	639-3	CD
# GUM_academic_eegimaa-29	1	:	:
# GUM_academic_eegimaa-29	2	bsl	NNP
# GUM_academic_eegimaa-29	3	)	-RRB-
# GUM_academic_eegimaa-29	4	from	IN
# GUM_academic_eegimaa-29	5	the	DT
# GUM_academic_eegimaa-29	6	village	NN
# GUM_academic_eegimaa-29	7	of	IN
# GUM_academic_eegimaa-29	8	Thionk	NNP
# GUM_academic_eegimaa-29	9	Essil	NNP
# GUM_academic_eegimaa-29	10	are	VBP
# GUM_academic_eegimaa-29	11	also	RB
# GUM_academic_eegimaa-29	12	other	JJ
# GUM_academic_eegimaa-29	13	languages	NNS
# GUM_academic_eegimaa-29	14	related	,
# GUM_academic_eegimaa-29	15	to	IN
# GUM_academic_eegimaa-29	16	Eegimaa	NNP
# GUM_academic_eegimaa-29	17	.	.
# GUM_academic_eegimaa-30	1	They	PRP
# GUM_academic_eegimaa-30	2	are	VBP
# GUM_academic_eegimaa-30	3	located	DT
# GUM_academic_eegimaa-30	4	north	NN
# GUM_academic_eegimaa-30	5	of	IN
# GUM_academic_eegimaa-30	6	the	DT
# GUM_academic_eegimaa-30	7	Casamance	NNP
# GUM_academic_eegimaa-30	8	River	NNP
# GUM_academic_eegimaa-30	9	in	IN
# GUM_academic_eegimaa-30	10	the	DT
# GUM_academic_eegimaa-30	11	Jóola	NNP
# GUM_academic_eegimaa-30	1	Búluf	NNP
# GUM_academic_eegimaa-30	2	area	NNP
# GUM_academic_eegimaa-30	3	.	.
# GUM_academic_eegimaa-31	1	There	EX
# GUM_academic_eegimaa-31	2	are	VBP
# GUM_academic_eegimaa-31	3	also	RB
# GUM_academic_eegimaa-31	4	small	JJ
# GUM_academic_eegimaa-31	5	migrant	JJ
# GUM_academic_eegimaa-31	6	Eegimaa	NNP
# GUM_academic_eegimaa-31	7	communities	NNP
# GUM_academic_eegimaa-31	8	in	IN
# GUM_academic_eegimaa-31	9	villages	NNS
# GUM_academic_eegimaa-31	10	like	IN
# GUM_academic_eegimaa-31	11	Djifanghor	NNP
# GUM_academic_eegimaa-31	1	(	-LRB-
# GUM_academic_eegimaa-31	2	east	NN
# GUM_academic_eegimaa-31	3	of	IN
# GUM_academic_eegimaa-31	4	Ziguinchor	NNP
# GUM_academic_eegimaa-31	5	)	-RRB-
# GUM_academic_eegimaa-31	6	and	CC
# GUM_academic_eegimaa-31	7	in	IN
# GUM_academic_eegimaa-31	8	Bourofaye	NNP
# GUM_academic_eegimaa-31	1	(	-LRB-
# GUM_academic_eegimaa-31	2	south	CD
# GUM_academic_eegimaa-31	1	of	IN
# GUM_academic_eegimaa-31	2	Ziguinchor	NNP
# GUM_academic_eegimaa-31	3	)	-RRB-
# GUM_academic_eegimaa-31	4	,	,
# GUM_academic_eegimaa-31	5	where	WRB
# GUM_academic_eegimaa-31	6	they	PRP
# GUM_academic_eegimaa-31	7	cohabit	VBP
# GUM_academic_eegimaa-31	8	with	IN
# GUM_academic_eegimaa-31	9	speakers	NNS
# GUM_academic_eegimaa-31	10	of	IN
# GUM_academic_eegimaa-31	11	Baïnounk	NNP
# GUM_academic_eegimaa-31	12	languages	NNP
# GUM_academic_eegimaa-31	13	.	.
# GUM_academic_eegimaa-32	1	Nowadays	``
# GUM_academic_eegimaa-32	2	most	NNP
# GUM_academic_eegimaa-32	3	Eegimaa	NNP
# GUM_academic_eegimaa-32	4	speakers	NNS
# GUM_academic_eegimaa-32	5	from	IN
# GUM_academic_eegimaa-32	6	Mof-Ávvi	NNP
# GUM_academic_eegimaa-32	7	live	NNP
# GUM_academic_eegimaa-32	8	outside	IN
# GUM_academic_eegimaa-32	9	their	PRP$
# GUM_academic_eegimaa-32	10	homeland	NN
# GUM_academic_eegimaa-32	11	,	,
# GUM_academic_eegimaa-32	1	generally	RB
# GUM_academic_eegimaa-32	2	in	IN
# GUM_academic_eegimaa-32	3	urban	JJ
# GUM_academic_eegimaa-32	4	areas	NNS
# GUM_academic_eegimaa-32	5	like	IN
# GUM_academic_eegimaa-32	6	Ziguinchor	NNP
# GUM_academic_eegimaa-32	7	and	CC
# GUM_academic_eegimaa-32	8	Dakar	NNP
# GUM_academic_eegimaa-32	1	.	.
# GUM_academic_eegimaa-33	1	Speakers	NNS
# GUM_academic_eegimaa-33	2	of	IN
# GUM_academic_eegimaa-33	3	Eegimaa	NNP
# GUM_academic_eegimaa-33	4	use	IN
# GUM_academic_eegimaa-33	5	the	DT
# GUM_academic_eegimaa-33	6	term	NNP
# GUM_academic_eegimaa-33	7	Gújjolaay	NNP
# GUM_academic_eegimaa-33	8	(	-LRB-
# GUM_academic_eegimaa-33	9	meaning	NNP
# GUM_academic_eegimaa-33	10	Jóola	NNP
# GUM_academic_eegimaa-33	11	)	-RRB-
# GUM_academic_eegimaa-33	1	to	TO
# GUM_academic_eegimaa-33	2	refer	VB
# GUM_academic_eegimaa-33	3	to	IN
# GUM_academic_eegimaa-33	4	their	PRP$
# GUM_academic_eegimaa-33	5	language	NN
# GUM_academic_eegimaa-33	6	when	WRB
# GUM_academic_eegimaa-33	7	they	PRP
# GUM_academic_eegimaa-33	8	speak	VBD
# GUM_academic_eegimaa-33	1	to	IN
# GUM_academic_eegimaa-33	2	each	DT
# GUM_academic_eegimaa-33	1	other	JJ
# GUM_academic_eegimaa-33	2	,	,
# GUM_academic_eegimaa-33	3	but	CC
# GUM_academic_eegimaa-33	4	Eegimaa	NNP
# GUM_academic_eegimaa-33	5	to	TO
# GUM_academic_eegimaa-33	6	distinguish	VB
# GUM_academic_eegimaa-33	7	their	PRP$
# GUM_academic_eegimaa-33	8	Jóola	JJ
# GUM_academic_eegimaa-33	9	variety	NN
# GUM_academic_eegimaa-33	10	from	IN
# GUM_academic_eegimaa-33	11	that	DT
# GUM_academic_eegimaa-33	12	of	IN
# GUM_academic_eegimaa-33	13	other	JJ
# GUM_academic_eegimaa-33	14	Jóola	JJ
# GUM_academic_eegimaa-33	15	peoples	NNS
# GUM_academic_eegimaa-33	16	.	.
# GUM_academic_eegimaa-34	1	Eegimaa	NNP
# GUM_academic_eegimaa-34	2	is	VBZ
# GUM_academic_eegimaa-34	3	an	DT
# GUM_academic_eegimaa-34	4	endangered	JJ
# GUM_academic_eegimaa-34	5	language	NN
# GUM_academic_eegimaa-34	6	whose	IN
# GUM_academic_eegimaa-34	7	transmission	NN
# GUM_academic_eegimaa-34	8	to	IN
# GUM_academic_eegimaa-34	9	new	JJ
# GUM_academic_eegimaa-34	10	generations	NNS
# GUM_academic_eegimaa-34	11	has	VBZ
# GUM_academic_eegimaa-34	1	been	VBN
# GUM_academic_eegimaa-34	2	declining	VBG
# GUM_academic_eegimaa-34	3	significantly	NN
# GUM_academic_eegimaa-34	4	in	IN
# GUM_academic_eegimaa-34	5	the	DT
# GUM_academic_eegimaa-34	6	last	JJ
# GUM_academic_eegimaa-34	7	decades	NNS
# GUM_academic_eegimaa-34	8	.	.
# GUM_academic_eegimaa-35	1	It	PRP
# GUM_academic_eegimaa-35	2	is	VBZ
# GUM_academic_eegimaa-35	3	important	JJ
# GUM_academic_eegimaa-35	4	to	TO
# GUM_academic_eegimaa-35	5	understand	VB
# GUM_academic_eegimaa-35	6	the	DT
# GUM_academic_eegimaa-35	7	contact	JJ
# GUM_academic_eegimaa-35	8	situation	NN
# GUM_academic_eegimaa-35	9	of	IN
# GUM_academic_eegimaa-35	10	Eegimaa	NNP
# GUM_academic_eegimaa-35	11	,	,
# GUM_academic_eegimaa-35	1	because	IN
# GUM_academic_eegimaa-35	2	some	DT
# GUM_academic_eegimaa-35	3	of	IN
# GUM_academic_eegimaa-35	4	the	DT
# GUM_academic_eegimaa-35	5	ritual	NN
# GUM_academic_eegimaa-35	6	names	VBZ
# GUM_academic_eegimaa-35	7	analysed	VBN
# GUM_academic_eegimaa-35	8	in	IN
# GUM_academic_eegimaa-35	1	this	DT
# GUM_academic_eegimaa-35	2	paper	NN
# GUM_academic_eegimaa-35	1	come	NN
# GUM_academic_eegimaa-35	2	from	IN
# GUM_academic_eegimaa-35	3	other	JJ
# GUM_academic_eegimaa-35	4	languages	NNS
# GUM_academic_eegimaa-35	5	or	CC
# GUM_academic_eegimaa-35	6	from	IN
# GUM_academic_eegimaa-35	7	neighbouring	VBG
# GUM_academic_eegimaa-35	8	communities	NNS
# GUM_academic_eegimaa-35	9	.	.
# GUM_academic_eegimaa-36	1	These	WRB
# GUM_academic_eegimaa-36	2	names	PRP
# GUM_academic_eegimaa-36	3	are	VBP
# GUM_academic_eegimaa-36	4	given	VBN
# GUM_academic_eegimaa-36	5	either	VBN
# GUM_academic_eegimaa-36	6	in	IN
# GUM_academic_eegimaa-36	7	Eegimaa	NNP
# GUM_academic_eegimaa-36	8	or	CC
# GUM_academic_eegimaa-36	9	in	IN
# GUM_academic_eegimaa-36	10	a	DT
# GUM_academic_eegimaa-36	11	different	JJ
# GUM_academic_eegimaa-36	1	language	NN
# GUM_academic_eegimaa-36	2	.	.
# GUM_bio_dvorak-1	1	Antonín	NNP
# GUM_bio_dvorak-1	2	Dvořák	NNP
# GUM_bio_dvorak-2	1	Antonín	NNP
# GUM_bio_dvorak-2	2	Leopold	NNP
# GUM_bio_dvorak-2	3	Dvořák	NNP
# GUM_bio_dvorak-2	4	(	-LRB-
# GUM_bio_dvorak-2	5	/	NNP
# GUM_bio_dvorak-2	6	d(ə)ˈvɔːrʒɑːk	NNP
# GUM_bio_dvorak-2	7	,	,
# GUM_bio_dvorak-2	8	-ʒæk	NNP
# GUM_bio_dvorak-2	9	/	NNP
# GUM_bio_dvorak-2	10	d(ə)-VOR-zha(h)k	NNP
# GUM_bio_dvorak-2	11	;	NNP
# GUM_bio_dvorak-2	1	Czech	NNP
# GUM_bio_dvorak-2	2	:	NNP
# GUM_bio_dvorak-2	3	[	-LRB-
# GUM_bio_dvorak-2	4	ˈantoɲiːn	NNP
# GUM_bio_dvorak-2	5	ˈlɛopolt	NNP
# GUM_bio_dvorak-2	6	ˈdvor̝aːk	NNP
# GUM_bio_dvorak-2	7	]	-RRB-
# GUM_bio_dvorak-2	8	;	:
# GUM_bio_dvorak-2	1	8	NNP
# GUM_bio_dvorak-2	2	September	NNP
# GUM_bio_dvorak-2	1	1841	CD
# GUM_bio_dvorak-2	2	–	SYM
# GUM_bio_dvorak-2	3	1	CD
# GUM_bio_dvorak-2	4	May	SYM
# GUM_bio_dvorak-2	5	1904	CD
# GUM_bio_dvorak-2	6	)	-RRB-
# GUM_bio_dvorak-2	7	was	VBD
# GUM_bio_dvorak-2	8	a	DT
# GUM_bio_dvorak-2	9	Czech	JJ
# GUM_bio_dvorak-2	10	composer	NN
# GUM_bio_dvorak-2	11	.	.
# GUM_bio_dvorak-3	1	After	IN
# GUM_bio_dvorak-3	2	Bedřich	NNP
# GUM_bio_dvorak-3	3	Smetana	NNP
# GUM_bio_dvorak-3	4	,	,
# GUM_bio_dvorak-3	5	he	PRP
# GUM_bio_dvorak-3	6	was	VBD
# GUM_bio_dvorak-3	7	the	DT
# GUM_bio_dvorak-3	8	next	JJ
# GUM_bio_dvorak-3	9	Czech	JJ
# GUM_bio_dvorak-3	10	Romantic	JJ
# GUM_bio_dvorak-3	11	-	HYPH
# GUM_bio_dvorak-3	1	era	JJ
# GUM_bio_dvorak-3	2	composer	NN
# GUM_bio_dvorak-3	3	to	IN
# GUM_bio_dvorak-3	4	achieve	DT
# GUM_bio_dvorak-3	5	worldwide	JJ
# GUM_bio_dvorak-3	6	recognition	NN
# GUM_bio_dvorak-3	7	.	.
# GUM_bio_dvorak-4	1	Following	``
# GUM_bio_dvorak-4	2	Smetana	NNP
# GUM_bio_dvorak-4	3	's	POS
# GUM_bio_dvorak-4	4	nationalist	JJ
# GUM_bio_dvorak-4	5	example	NN
# GUM_bio_dvorak-4	6	,	,
# GUM_bio_dvorak-4	7	Dvořák	NNP
# GUM_bio_dvorak-4	8	frequently	-LRB-
# GUM_bio_dvorak-4	9	employed	CD
# GUM_bio_dvorak-4	10	aspects	-RRB-
# GUM_bio_dvorak-4	11	,	,
# GUM_bio_dvorak-4	1	specifically	CC
# GUM_bio_dvorak-4	2	rhythms	NNS
# GUM_bio_dvorak-4	3	,	,
# GUM_bio_dvorak-4	4	of	IN
# GUM_bio_dvorak-4	5	the	DT
# GUM_bio_dvorak-4	6	folk	NN
# GUM_bio_dvorak-4	7	music	NN
# GUM_bio_dvorak-4	8	of	IN
# GUM_bio_dvorak-4	1	Moravia	NNP
# GUM_bio_dvorak-4	2	and	CC
# GUM_bio_dvorak-4	1	his	PRP$
# GUM_bio_dvorak-4	2	native	NN
# GUM_bio_dvorak-4	3	Bohemia	NNP
# GUM_bio_dvorak-4	4	.	.
# GUM_bio_dvorak-5	1	Dvořák	NNP
# GUM_bio_dvorak-5	2	's	POS
# GUM_bio_dvorak-5	3	own	JJ
# GUM_bio_dvorak-5	4	style	NN
# GUM_bio_dvorak-5	5	has	VBZ
# GUM_bio_dvorak-5	6	been	VBN
# GUM_bio_dvorak-5	7	described	VBN
# GUM_bio_dvorak-5	8	as	IN
# GUM_bio_dvorak-5	9	"	``
# GUM_bio_dvorak-5	10	the	DT
# GUM_bio_dvorak-5	11	fullest	JJS
# GUM_bio_dvorak-5	1	recreation	NN
# GUM_bio_dvorak-5	2	of	IN
# GUM_bio_dvorak-5	3	a	DT
# GUM_bio_dvorak-5	4	national	JJ
# GUM_bio_dvorak-5	5	idiom	NN
# GUM_bio_dvorak-5	6	with	IN
# GUM_bio_dvorak-5	7	that	DT
# GUM_bio_dvorak-5	8	of	IN
# GUM_bio_dvorak-5	1	the	DT
# GUM_bio_dvorak-5	2	symphonic	JJ
# GUM_bio_dvorak-5	1	tradition	NN
# GUM_bio_dvorak-5	2	,	,
# GUM_bio_dvorak-5	3	absorbing	VBG
# GUM_bio_dvorak-5	4	folk	NN
# GUM_bio_dvorak-5	5	influences	NNS
# GUM_bio_dvorak-5	6	and	CC
# GUM_bio_dvorak-5	7	finding	DT
# GUM_bio_dvorak-5	8	effective	JJ
# GUM_bio_dvorak-5	9	ways	NNS
# GUM_bio_dvorak-5	10	of	IN
# GUM_bio_dvorak-5	11	using	DT
# GUM_bio_dvorak-5	12	them	NN
# GUM_bio_dvorak-5	13	"	''
# GUM_bio_dvorak-5	14	.	.
# GUM_bio_dvorak-5	15	[	-LRB-
# GUM_bio_dvorak-5	16	1	CD
# GUM_bio_dvorak-5	17	]	-RRB-
# GUM_bio_dvorak-6	1	Antonín	NNP
# GUM_bio_dvorak-6	2	Dvořák	NNP
# GUM_bio_dvorak-7	1	Dvořák	NNP
# GUM_bio_dvorak-7	2	displayed	IN
# GUM_bio_dvorak-7	3	his	PRP$
# GUM_bio_dvorak-7	4	musical	JJ
# GUM_bio_dvorak-7	5	gifts	NNS
# GUM_bio_dvorak-7	6	at	IN
# GUM_bio_dvorak-7	7	an	DT
# GUM_bio_dvorak-7	8	early	JJ
# GUM_bio_dvorak-7	9	age	NN
# GUM_bio_dvorak-7	10	,	,
# GUM_bio_dvorak-7	11	being	VBG
# GUM_bio_dvorak-7	1	an	DT
# GUM_bio_dvorak-7	2	apt	JJ
# GUM_bio_dvorak-7	3	violin	NN
# GUM_bio_dvorak-7	4	student	NN
# GUM_bio_dvorak-7	5	from	IN
# GUM_bio_dvorak-7	6	age	NN
# GUM_bio_dvorak-7	7	six	NN
# GUM_bio_dvorak-7	8	.	.
# GUM_bio_dvorak-8	1	The	DT
# GUM_bio_dvorak-8	2	first	JJ
# GUM_bio_dvorak-8	3	public	JJ
# GUM_bio_dvorak-8	4	performances	NNS
# GUM_bio_dvorak-8	5	of	IN
# GUM_bio_dvorak-8	6	his	PRP$
# GUM_bio_dvorak-8	7	works	NNS
# GUM_bio_dvorak-8	8	were	VBD
# GUM_bio_dvorak-8	9	in	IN
# GUM_bio_dvorak-8	10	Prague	NNP
# GUM_bio_dvorak-8	11	in	IN
# GUM_bio_dvorak-8	1	1872	NNP
# GUM_bio_dvorak-8	2	and	CC
# GUM_bio_dvorak-8	3	,	,
# GUM_bio_dvorak-8	4	with	IN
# GUM_bio_dvorak-8	5	special	JJ
# GUM_bio_dvorak-8	6	success	NN
# GUM_bio_dvorak-8	7	,	,
# GUM_bio_dvorak-8	8	in	IN
# GUM_bio_dvorak-8	1	1873	CD
# GUM_bio_dvorak-8	2	,	,
# GUM_bio_dvorak-8	1	when	WRB
# GUM_bio_dvorak-8	2	he	PRP
# GUM_bio_dvorak-8	3	was	VBD
# GUM_bio_dvorak-8	4	aged	IN
# GUM_bio_dvorak-8	5	31	CD
# GUM_bio_dvorak-8	6	.	.
# GUM_bio_dvorak-9	1	Seeking	VBG
# GUM_bio_dvorak-9	2	recognition	NN
# GUM_bio_dvorak-9	3	beyond	IN
# GUM_bio_dvorak-9	4	the	DT
# GUM_bio_dvorak-9	5	Prague	NNP
# GUM_bio_dvorak-9	6	area	NNP
# GUM_bio_dvorak-9	7	,	,
# GUM_bio_dvorak-9	8	he	PRP
# GUM_bio_dvorak-9	9	submitted	VBD
# GUM_bio_dvorak-9	10	a	DT
# GUM_bio_dvorak-9	11	score	NN
# GUM_bio_dvorak-9	1	of	IN
# GUM_bio_dvorak-9	2	his	PRP$
# GUM_bio_dvorak-9	3	First	NNP
# GUM_bio_dvorak-9	4	Symphony	NNP
# GUM_bio_dvorak-9	5	to	IN
# GUM_bio_dvorak-9	6	a	DT
# GUM_bio_dvorak-9	7	prize	JJ
# GUM_bio_dvorak-9	8	competition	NN
# GUM_bio_dvorak-9	1	in	IN
# GUM_bio_dvorak-9	2	Germany	NNP
# GUM_bio_dvorak-9	1	,	,
# GUM_bio_dvorak-9	2	but	CC
# GUM_bio_dvorak-9	3	did	VBD
# GUM_bio_dvorak-9	4	not	RB
# GUM_bio_dvorak-9	5	win	RB
# GUM_bio_dvorak-9	6	,	,
# GUM_bio_dvorak-9	7	and	CC
# GUM_bio_dvorak-9	8	the	DT
# GUM_bio_dvorak-9	9	unreturned	JJ
# GUM_bio_dvorak-9	10	manuscript	NN
# GUM_bio_dvorak-9	11	was	VBD
# GUM_bio_dvorak-9	12	lost	VBN
# GUM_bio_dvorak-9	13	until	IN
# GUM_bio_dvorak-9	14	rediscovered	VBN
# GUM_bio_dvorak-9	15	many	IN
# GUM_bio_dvorak-9	16	decades	DT
# GUM_bio_dvorak-9	17	later	NN
# GUM_bio_dvorak-9	18	.	.
# GUM_bio_dvorak-10	1	In	IN
# GUM_bio_dvorak-10	2	1874	CD
# GUM_bio_dvorak-10	3	he	PRP
# GUM_bio_dvorak-10	4	made	VBD
# GUM_bio_dvorak-10	5	a	DT
# GUM_bio_dvorak-10	6	submission	NN
# GUM_bio_dvorak-10	7	to	IN
# GUM_bio_dvorak-10	8	the	DT
# GUM_bio_dvorak-10	9	Austrian	NNP
# GUM_bio_dvorak-10	10	State	NNP
# GUM_bio_dvorak-10	11	Prize	NNP
# GUM_bio_dvorak-10	1	for	IN
# GUM_bio_dvorak-10	2	Composition	NNP
# GUM_bio_dvorak-10	3	,	,
# GUM_bio_dvorak-10	4	including	VBG
# GUM_bio_dvorak-10	5	scores	NNS
# GUM_bio_dvorak-10	6	of	IN
# GUM_bio_dvorak-10	7	two	CD
# GUM_bio_dvorak-10	8	further	JJ
# GUM_bio_dvorak-10	1	symphonies	NNS
# GUM_bio_dvorak-10	2	and	CC
# GUM_bio_dvorak-10	1	other	JJ
# GUM_bio_dvorak-10	2	works	NNS
# GUM_bio_dvorak-10	3	.	.

# %% [markdown]
# ## Generating a TSV File according to the format specified in the Problem Statement

# %%
output_file = "viterbi_predictions_train.tsv"
with open(output_file, "w", newline="") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    writer.writerow(["Sent_ID", "Data", "Sentence", "Result"])
    for i in range(len(trainingResults)):
        for j in range(len(trainingResults[i])):
            writer.writerow([sentIdList[i], trainingData[j][1], trainingSentences[i][j], trainingResults[i][j]])

# %%
output_file = "viterbi_predictions_test.tsv"
with open(output_file, "w", newline="") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    writer.writerow(["Sent_ID", "Data", "Sentence", "Result"])
    for i in range(len(testResults)):
        for j in range(len(testResults[i])):
            writer.writerow([listOfTestSentIds[i], testData[j][1], testSentences[i][j], testResults[i][j]])
