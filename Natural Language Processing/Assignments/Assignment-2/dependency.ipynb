# %% [markdown]
# <h1 style="text-align: center;"> Assignment-2 (Task-2) </h1>
# <h4 style="text-align: center;">  Name: Shatansh Patnaik </h4>
# <h4 style="text-align: center;"> Roll No: 20MA20067 </h4>

# %% [markdown]
# ### Importing all the packages to be used in the project

# %%
import numpy as np
from collections import defaultdict
import copy
from collections import Counter 
import csv

# %% [markdown]
# ### Defining a function to store in the parsed data that is to be used for parsing in training and test data

# %%
def parseData(filePath):
    data = []
    listOfSentIds = []
    
    with open(filePath, 'r') as file:
        sentId = ""
        
        for line in file:
            line = line.strip()
            if line.startswith("# sent_id"):
                newLine = line.split("=")
                newSentence = newLine[-1].strip()
                sentId = newSentence
                listOfSentIds.append(sentId)
                
            elif line and not line.startswith("#"):
                divisions = line.split()
                if len(divisions) >= 5:
                    data.append([sentId, divisions[0], divisions[1], divisions[2], divisions[3], divisions[4], divisions[5]]) 
                    
    return data, listOfSentIds

# %% [markdown]
# ### Function for grouping in the parsed data in the training and test data set

# %%
def groupData(data):
    dicts = {}

    for sublist in data:
        key = sublist[0]
        if key not in dicts:
            dicts[key] = [[] for _ in range(len(sublist)-1)]
        for i in range(1, len(sublist)):
            if sublist[i].isdigit():
                dicts[key][i-1].append(int(sublist[i]))
            elif all(char.isdigit() for char in sublist[i]):
                dicts[key][i-1].append(float(sublist[i]))
            else:
                dicts[key][i-1].append(sublist[i])

    result = []
    for key, values in dicts.items():
        result.append([key] + values)

    return result, dicts

# %% [markdown]
# ### The defined functions have the following functionalities:
# - The function getLineNumberMappings returns in an array of dictionary which is mapping of indices in a sentence to their respective tokens
# - getInitialConfig returns us a 2D array of tuple of Stack, Arcs and Buffer for all sentences in the dataset
# - getDependencyTree returns us the Dependency Tree for each sentence in a 2D array

# %%
# For each sentence in the array it is a dictionary of mappings from numbers to words
def getLineNumberMappings(groupedData):
    result = []
    for group in groupedData:
        groupDict = {}
        keys = group[1]
        values = group[3]
        for i in range(len(keys)):
            groupDict[keys[i]] = str(values[i])
        result.append(groupDict)
    return result

# Lets make the initial configuration
def getInitialConfig(data):
    configLists = []
    for i in range(len(data)):
        newArr = data[i][3]
        updatedArr = []
        for element in newArr:
            updatedArr.append(str(element))
        configLists.append(([], updatedArr, []))
    return configLists

# Dependency tree extra is a 2D array of (head, dep, depTag)
# Dep Tree is a 2D array of (head, dep)
def getDependencyTree(groupedData, getWordsAtIndices):
    resE = []
    res = []
    
    for i in range(len(groupedData)):
        depIndices = groupedData[i][1]
        headIndices = groupedData[i][5]
        modIndices = groupedData[i][6]
        dicts = getWordsAtIndices[i]
        newArr = []
        newArrE = []
        
        for j in range(min(len(depIndices), len(headIndices), len(modIndices))):
            getDepWord = dicts[depIndices[j]]
            getHeadWord = "*"
            
            if headIndices[j] != 0:
                getHeadWord = dicts[headIndices[j]]
            
#             if getHeadWord != "*":
            newArrE.append((getHeadWord, getDepWord, modIndices[j]))
            newArr.append((getHeadWord,getDepWord))
        
        res.append(newArr)
        resE.append(newArrE)
        
    return res, resE

# %% [markdown]
# ### The defined functions have the following functionalities:
# - The function getPOS returns in an array of dictionary which is mapping of tokens in a sentence to their respective POS Tags
# - The function getDepT returns in an array of dictionary which is mapping of tokens in a sentence to their respective dependency relationship modifiers
# - The function getFrequencyDictionaries returns the most commonly occuring 1000 words in the dataset along with their respective POS Tags and Dependency Relationships with their respective head words

# %%
def getPOS(groupedData):
    result = []
    for group in groupedData:
        groupDict = {}
        keys = group[3]
        values = group[4]
        for i in range(len(keys)):
            val = str(keys[i])
            groupDict[val] = values[i]
        result.append(groupDict)
    return result

def getDepT(groupedData):
    result = []
    for group in groupedData:
        groupDict = {}
        keys = group[3]
        values = group[6]
        for i in range(len(keys)):
            val = str(keys[i])
            groupDict[val] = values[i]
        result.append(groupDict)
    return result

def getFrequencyDictionaries(trainingData):
    allWords = []
    allPos = []
    allDeps = []
    words = defaultdict(int)
    posTags = {}
    depTags = {}

    for i in range(len(trainingData)):
        value1 = str(trainingData[i][3])
        value2 = str(trainingData[i][4])
        value3 = str(trainingData[i][6])
        
        allWords.append(value1)

        if value2 not in allPos:
            allPos.append(value2)

        if value3 not in allDeps:
            allDeps.append(value3)

    wordFreqs = Counter(allWords)
    mostCommonWords = wordFreqs.most_common(1005)
    uniqueWords = [word for word, freq in mostCommonWords if freq < 1000]

    for i in range(len(uniqueWords)):
        words[uniqueWords[i]] = i
        
    for i in range(len(allPos)):
        posTags[allPos[i]] = i
        
    for i in range(len(allDeps)):
        depTags[allDeps[i]] = i

    return words, posTags, depTags

# %% [markdown]
# ### The defined functions have the following functionalities:
# - The function performAction performs the respective action (LEFT-ARC, RIGHT-ARC, SHIFT or REDUCE) on the given configuration and returns the modified configuration
# - The function Oracle returns the appropriate action to be performed on the configuration by looking at the Dependency Tree

# %%
def performAction(configuration, action):
    stack, buffer, arcs = configuration   
    topS = stack[-1] if stack else None
    firstB = buffer[0] if buffer else None
    
    if action == "LEFT-ARC":
        arcs.append((firstB, topS))
        stack.pop()
    elif action == "RIGHT-ARC":
        arcs.append((topS, firstB))
        stack.append(firstB)
        buffer.pop(0)
    elif action == "REDUCE":
        stack.pop()
    elif action == "SHIFT":
        buffer.pop(0)
        stack.append(firstB)
        
    return (stack, buffer, arcs)

def oracle(configuration, DT):
    stack, buffer, arcs = configuration
    
    topS = stack[-1] if stack else None
    firstB = buffer[0] if buffer else None

    if firstB and topS and (firstB, topS) in DT and topS not in [D for H, D in arcs]:
        return "LEFT-ARC"
    elif topS and firstB and (topS, firstB) in DT:
        return "RIGHT-ARC"
    elif topS and firstB and topS in [D for H, D in arcs]:
        for word in reversed(stack[:-1]):
            if (word, firstB) in DT or (firstB, word) in DT:
                return "REDUCE"
    return "SHIFT"

# %% [markdown]
# ### This function returns the Bag of Words vector for a given configuration

# %%
def getBOW (word, getIndex):
    if word is None:
        return [0] * len(getIndex)
    elif word not in getIndex:
        return [0] * len(getIndex)
    else:
        index = getIndex[word]
        listOfStuff = [0]*len(getIndex)
        if index >=0 and index < len(getIndex):
            listOfStuff[index] = 1
        return listOfStuff

# %% [markdown]
# ### This function returns the feature model vector for a given configuration

# %%
def getFeatureModel(configuration, index, pos, depT):
    stack, buffer, arcs = configuration
    
    topS = None
    firstB = None
    posTagTopS = None
    posTagFirstB = None
    posTagSecondB = None
    
    if stack:
        topS = stack[-1]
        posTagTopS = pos[index][topS]
    if buffer:
        firstB = buffer[0]
        posTagFirstB = pos[index][firstB]
        if len(buffer) >= 2:
            posTagSecondB = pos[index][buffer[1]]
    
    topDep = None
    topLDep = None
    topRDep = None
    firstLDep = None
    
    for head, depTag in arcs:
        if topS and head == topS:
            topDep = depTag
            if not topLDep:
                topLDep = depTag
            topRDep = depTag
        
        if firstB and head == firstB:
            if not firstLDep:
                firstLDep = depTag
                
    topDep = depT[index][topDep] if topDep and depT[index][topDep] else None
    topLDep = depT[index][topLDep] if topLDep and depT[index][topLDep] else None
    topRDep = depT[index][topRDep] if topRDep and depT[index][topRDep] else None
    firstLDep = depT[index][firstLDep] if firstLDep and depT[index][firstLDep] else None
    
    tops = getBOW(topS, words)
    first = getBOW(firstB, words)
    posTop = getBOW(posTagTopS, posTags)
    posFirst = getBOW(posTagFirstB, posTags)
    posSecond = getBOW(posTagSecondB, posTags)
    topDeps = getBOW(topDep, depTags)
    topLDeps = getBOW(topLDep, depTags)
    topRDeps = getBOW(topRDep, depTags)
    firstLDeps = getBOW(firstLDep, depTags)
    
    fM =  tops + first + posTop + posFirst + posSecond + topDeps + topLDeps + topRDeps + firstLDeps
    
    return fM

# %%
getAction = ["LEFT-ARC", "RIGHT-ARC", "REDUCE", "SHIFT"]
transitionAction = {
    "LEFT-ARC": 0, "RIGHT-ARC": 1, "REDUCE": 2, "SHIFT": 3
}

# %%
def performComputation(fM, action):
    v = len(fM)
    result = np.zeros(4 * v)
    result[transitionAction[action]*v : (transitionAction[action] + 1)*v] +=fM

    return result

# %% [markdown]
# ### This is basically the training of the model

# %%
Results = []
uncleanedTrainingData, _ = parseData("./NLP2/train.txt")
trainingData = [sublist for sublist in uncleanedTrainingData if sublist[1].isdigit()]

groupedTrainingData, dictionaryOfTrainingData = groupData(trainingData)

listOfConfigs = getInitialConfig(groupedTrainingData)
getWordsAtIndices = getLineNumberMappings(groupedTrainingData)
DT, DTE = getDependencyTree(groupedTrainingData, getWordsAtIndices)

pos = getPOS(groupedTrainingData)
depT = getDepT(groupedTrainingData)
words, posTags, depTags = getFrequencyDictionaries(trainingData)

def learnTheWeights(listOfConfigurations, maxIters, DT, pos, depT):
    v = (2*len(words) + 3*len(posTags) + 4*len(depTags))
#     w = np.random.normal(10, 4, 4*v)
    w = [22.2]*(4*v)
    w = np.array(w)
    for i in range(maxIters):
#         print(i)
        for j in range(len(listOfConfigurations)):
#             print(j)
            c = [copy.deepcopy(tup) for tup in listOfConfigurations[j]]
            stack, buffer, arc = c
            maxValue = -9999
            trainingAction = "LEFT-ARC"
            bestFeature = np.array([])
            
            while buffer:
                fM = getFeatureModel((stack, buffer, arc), j, pos, depT)
                fM = np.array(fM)
                for action in getAction:
                    newFeatureVector = performComputation(fM, action)
                    value = np.dot(newFeatureVector, w)

                    if value > maxValue:
                        maxValue = value
                        trainingAction = action
                        bestFeature = newFeatureVector
                
                oracleAction = oracle(c, DT[j])
                
                if trainingAction != oracleAction:
                    w = w + performComputation(fM, oracleAction) - bestFeature
                stack, buffer, arc = performAction(c, oracleAction)
            Results.append(arc)
        
    return w

# %%
# 100 Iterations take about 13 minutes
weights = learnTheWeights(listOfConfigs, 10, DT, pos, depT)
np.save('dependency_model_on.npy', weights)

# %%
print(weights)
print(Results[0])
# Out:
# [ 5.2 -7.8 11.2 ...  9.2 -0.8 31.2]
# [('appreciation', 'aesthetic'), ('art', 'Spanish'), ('art', 'and'), ('appreciation', 'art'), ('appreciation', ':')]

# %%
# This should return a valid action
def checkIfMoveIsLegal(c, testAction):
    stack, buffer, arcs = c
    if testAction == "SHIFT":
        return "SHIFT"
    elif testAction == "RIGHT-ARC":
        if stack:
            return "RIGHT-ARC"
        return "SHIFT"
    elif testAction == "LEFT-ARC":
        if len(stack) == 0:
            return "SHIFT"
        elif stack[-1] in [D for H, D in arcs]:
            return "REDUCE"
        else:
            return "LEFT-ARC"
    else:
        if len(stack) == 0:
            return "SHIFT"
        elif stack[-1] not in [D for H, D in arcs]:
            return "LEFT-ARC"
        else:
            return "REDUCE"

# %%
def getIndexOfTokens(groupedData):
    result = []
    for group in groupedData:
        groupDict = defaultdict(str)
        keys = group[3]
        values = group[1]
        for i in range(len(keys)):
            groupDict[keys[i]] = (values[i])
        result.append(groupDict)
    return result

# %% [markdown]
# ### This is the testing of the model

# %%
def testDataFunction(listOfConfigurations, DT, weights, posTest, depTest):
    testResults = []
    for j in range(len(listOfConfigurations)):
        c = [copy.deepcopy(tup) for tup in listOfConfigurations[j]]
        stack, buffer, arc = c
        testAction = "LEFT-ARC"
        bestFeature = np.array([])

        while buffer:
            fM = getFeatureModel((stack, buffer, arc), j, posTest, depTest)
            fM = np.array(fM)
            
            maxValue = float('-inf')
            bestFeature = np.array([])
            
            for action in getAction:
                newFeatureVector = performComputation(fM, action)
                value = np.dot(newFeatureVector, weights)

                if value > maxValue:
                    maxValue = value
                    testAction = action
                    bestFeature = newFeatureVector
            
            # Illegal check
            updatedAction = checkIfMoveIsLegal(c, testAction)
            stack, buffer, arc = performAction(c, updatedAction)
            
        testResults.append(arc)
        
    return testResults

# %%
uncleanedTestData, listOfSentIds = parseData("./NLP2/test.txt")
testData = [sublist for sublist in uncleanedTestData if sublist[1].isdigit()]

groupedTestData, dictionaryOfTestData = groupData(testData)
listOfTestConfigs = getInitialConfig(groupedTestData)
getTestWordsAtIndices = getLineNumberMappings(groupedTestData)
getIndicesOfWords = getIndexOfTokens(groupedTestData)
DTTest, _ = getDependencyTree(groupedTestData, getTestWordsAtIndices)

posTest = getPOS(groupedTestData)
depTest = getDepT(groupedTestData)

testResults = testDataFunction(listOfTestConfigs, DTTest, weights, posTest, depTest)

# %%
UAS_Length = 0
UAS_Num = 0
for i in range(len(testResults)):
    for j in range(len(testResults[i])):
        head, dep = testResults[i][j]
        if (head, dep) in DTTest[i]:
            UAS_Num += 1
    UAS_Length += len(DTTest[i])

print(f"The UAS Score for the test data is : {UAS_Num/UAS_Length * 100} %")
# Out:
# The UAS Score for the test data is : 25.252525252525253 %

# %%
for i in range(len(testResults)):
    for j in range(len(testResults[i])):
        head, dep = testResults[i][j]
        head = str(head)
        dep = str(dep)
#         if getIndicesOfWords[i][head] and getIndicesOfWords[i][dep]: 
        print(f"{listOfSentIds[i]} {getIndicesOfWords[i][dep]} {dep} {getIndicesOfWords[i][head]}")
# Out:
# GUM_academic_discrimination-1 1 the 2
# GUM_academic_discrimination-1 3 of 4
# GUM_academic_discrimination-1 2 prevalence 4
# GUM_academic_discrimination-1 4 discrimination 5
# GUM_academic_discrimination-1 6 racial 7
# GUM_academic_discrimination-1 5 across 7
# GUM_academic_discrimination-1 8 in 9
# GUM_academic_discrimination-1 7 group 9
# GUM_academic_discrimination-1 10 America 9
# GUM_academic_discrimination-1 11 : 10
# GUM_academic_discrimination-2 5 representative 6
# GUM_academic_discrimination-2 4 nationally 6
# GUM_academic_discrimination-2 3 a 6
# GUM_academic_discrimination-2 7 of 8
# GUM_academic_discrimination-2 8 adult 6
# GUM_academic_discrimination-3 2 . 1
# GUM_academic_discrimination-4 2 experience 1
# GUM_academic_discrimination-4 11 of 4
# GUM_academic_discrimination-4 4 discrimination 1
# GUM_academic_discrimination-4 5 and 1
# GUM_academic_discrimination-4 6 bias 1
# GUM_academic_discrimination-4 7 have 8
# GUM_academic_discrimination-4 9 the 8
# GUM_academic_discrimination-4 8 be 10
# GUM_academic_discrimination-4 10 focus 1
# GUM_academic_discrimination-4 12 much 1
# GUM_academic_discrimination-4 1 personal 13
# GUM_academic_discrimination-4 14 science 15
# GUM_academic_discrimination-4 13 social 15
# GUM_academic_discrimination-4 15 research 16
# GUM_academic_discrimination-4 16 . 17
# GUM_academic_discrimination-4 17 [
# GUM_academic_discrimination-4 19 -
# GUM_academic_discrimination-4  1
# GUM_academic_discrimination-4 21 ]
# GUM_academic_discrimination-5 2 have 3
# GUM_academic_discrimination-5 3 explore 1
# GUM_academic_discrimination-5 4 the 3
# GUM_academic_discrimination-5 6 consequence 5
# GUM_academic_discrimination-5 7 of 8
# GUM_academic_discrimination-5 8 discrimination 5
# GUM_academic_discrimination-5 9 [ 5
# GUM_academic_discrimination-5  3 5
# GUM_academic_discrimination-5 11 -
# GUM_academic_discrimination-5  5
# GUM_academic_discrimination-5 13 ]
# GUM_academic_discrimination-5 14 ;
# GUM_academic_discrimination-6 2 have 3
# GUM_academic_discrimination-6 4 the 3
# GUM_academic_discrimination-6 7 that 8
# GUM_academic_discrimination-6 12 bias 11
# GUM_academic_discrimination-6 13 [ 12
# GUM_academic_discrimination-6  6 12
# GUM_academic_discrimination-6 15 ]
# GUM_academic_discrimination-7 2 have 3
# GUM_academic_discrimination-7 4 the 3
# GUM_academic_discrimination-7 6 underpinning 5
# GUM_academic_discrimination-7 7 of 8
# GUM_academic_discrimination-7 8 discrimination 5
# GUM_academic_discrimination-7 9 [ 5
# GUM_academic_discrimination-7  7 5
# GUM_academic_discrimination-7 11 -
# GUM_academic_discrimination-7  9
# GUM_academic_discrimination-7 13 ]
# GUM_academic_discrimination-7 14 ;
# GUM_academic_discrimination-8 3 theorist 2
# GUM_academic_discrimination-8 4 have 5
# GUM_academic_discrimination-8 5 explore 3
# GUM_academic_discrimination-8 20 the 5
# GUM_academic_discrimination-8 8 way 7
# GUM_academic_discrimination-8 10 in 15
# GUM_academic_discrimination-8 15 - 16
# GUM_academic_discrimination-8 13 / 16
# GUM_academic_discrimination-8 14 out 15
# GUM_academic_discrimination-8 15 - 13
# GUM_academic_discrimination-8 16 group 13
# GUM_academic_discrimination-8 17 bias 16
# GUM_academic_discrimination-8 9 that 18
# GUM_academic_discrimination-8 18 emerge 7
# GUM_academic_discrimination-8 19 across 18
# GUM_academic_discrimination-8 21 history 7
# GUM_academic_discrimination-8 23 our 24
# GUM_academic_discrimination-8 22 of 24
# GUM_academic_discrimination-8 24 species 25
# GUM_academic_discrimination-8 7 various 25
# GUM_academic_discrimination-8 25 . 5
# GUM_academic_discrimination-8 26 [
# GUM_academic_discrimination-8 28 ]
# GUM_academic_discrimination-9 6 already 7
# GUM_academic_discrimination-9 8 a 9
# GUM_academic_discrimination-9 7 possess 9
# GUM_academic_discrimination-9 5 researcher 9
# GUM_academic_discrimination-9 4 , 9
# GUM_academic_discrimination-9 3 respect 9
# GUM_academic_discrimination-9 17 of 11
# GUM_academic_discrimination-9 12 concern 11
# GUM_academic_discrimination-9 11 knowledge 13
# GUM_academic_discrimination-9 9 wealth 13
# GUM_academic_discrimination-9 13 the 2
# GUM_academic_discrimination-9 19 and 16
# GUM_academic_discrimination-9 14 origin 16
# GUM_academic_discrimination-9 2 many 16
# GUM_academic_discrimination-9 1 in 16
# GUM_academic_discrimination-9 16 consequence 18
# GUM_academic_discrimination-9 18 discrimination 19
# GUM_academic_discrimination-9 20 bias 21
# GUM_academic_discrimination-9 21 . 22
# GUM_academic_discrimination-9 22 [
# GUM_academic_discrimination-9 24 ]
# GUM_academic_discrimination-10 11 be 6
# GUM_academic_discrimination-10 4 not 6
# GUM_academic_discrimination-10 3 should 6
# GUM_academic_discrimination-10 2 also 6
# GUM_academic_discrimination-10 1 what 6
# GUM_academic_discrimination-10 7 in 8
# GUM_academic_discrimination-10 8 discussion 24
# GUM_academic_discrimination-10 13 grow 14
# GUM_academic_discrimination-10 22 the 14
# GUM_academic_discrimination-10 10 discrimination 14
# GUM_academic_discrimination-10 15 to 16
# GUM_academic_discrimination-10 14 push 16
# GUM_academic_discrimination-10 16 implement 17
# GUM_academic_discrimination-10 19 aim 18
# GUM_academic_discrimination-10 20 at 21
# GUM_academic_discrimination-10 18 policy 21
# GUM_academic_discrimination-10 17 social 21
# GUM_academic_discrimination-10 21 reduce 22
# GUM_academic_discrimination-10 26 practice 25
# GUM_academic_discrimination-10 27 . 25
# GUM_academic_discrimination-11 3 training 2
# GUM_academic_discrimination-11 16 in 5
# GUM_academic_discrimination-11 5 professional 6
# GUM_academic_discrimination-11 6 setting 3
# GUM_academic_discrimination-11 8 for 9
# GUM_academic_discrimination-11 10 , 9
# GUM_academic_discrimination-11 9 example 10
# GUM_academic_discrimination-11 10 , 3
# GUM_academic_discrimination-11 11 be 12
# GUM_academic_discrimination-11 12 intend 2
# GUM_academic_discrimination-11 13 to 14
# GUM_academic_discrimination-11 14 reduce 15
# GUM_academic_discrimination-11 15 bias 26
# GUM_academic_discrimination-11 26 the 18
# GUM_academic_discrimination-11 20 increase 22
# GUM_academic_discrimination-11 19 by 22
# GUM_academic_discrimination-11 25 regard 26
# GUM_academic_discrimination-11 28 face 29
# GUM_academic_discrimination-11 29 minority 30
# GUM_academic_discrimination-11 31 member 30
# GUM_academic_discrimination-11 32 . 30
# GUM_academic_discrimination-11 33 [ 30
# GUM_academic_discrimination-11  12 30
# GUM_academic_discrimination-11 35 ]
# GUM_academic_discrimination-12 11 the 4
# GUM_academic_discrimination-12 25 , 4
# GUM_academic_discrimination-12 1 indeed 4
# GUM_academic_discrimination-12 7 policy 6
# GUM_academic_discrimination-12 17 be 9
# GUM_academic_discrimination-12 9 root 6
# GUM_academic_discrimination-12 27 in 9
# GUM_academic_discrimination-12 6 certain 12
# GUM_academic_discrimination-12 5 of 12
# GUM_academic_discrimination-12 13 that 14
# GUM_academic_discrimination-12 12 assumption 14
# GUM_academic_discrimination-12 14 discrimination 4
# GUM_academic_discrimination-12 15 and 16
# GUM_academic_discrimination-12 16 bias 4
# GUM_academic_discrimination-12 4 implementation 17
# GUM_academic_discrimination-12 19 at 20
# GUM_academic_discrimination-12 20 least 21
# GUM_academic_discrimination-12 23 appreciable 24
# GUM_academic_discrimination-12 22 some 24
# GUM_academic_discrimination-12 24 amount 26
# GUM_academic_discrimination-12 28 modern 29
# GUM_academic_discrimination-12 29 society 30
# GUM_academic_discrimination-13 1 even 2
# GUM_academic_discrimination-13 6 the 7
# GUM_academic_discrimination-13 8 of 7
# GUM_academic_discrimination-13 4 estimate 7
# GUM_academic_discrimination-13 3 , 7
# GUM_academic_discrimination-13 7 prevalence 2
# GUM_academic_discrimination-13 9 perceive 10
# GUM_academic_discrimination-13 11 remain 12
# GUM_academic_discrimination-13 10 discrimination 12
# GUM_academic_discrimination-13 2 so 12
# GUM_academic_discrimination-13 13 ( 12
# GUM_academic_discrimination-13 15 [ 14
# GUM_academic_discrimination-13  13 17
# GUM_academic_discrimination-13 17 - 14
# GUM_academic_discrimination-13  14 17
# GUM_academic_discrimination-13 19 ]
# GUM_academic_discrimination-13 14 see 20
# GUM_academic_discrimination-13 12 rare 20
# GUM_academic_discrimination-13 20 ) 21
# GUM_academic_discrimination-14 1 at 2
# GUM_academic_discrimination-14 2 least 3
# GUM_academic_discrimination-14 3 one 4
# GUM_academic_discrimination-14 4 prior 5
# GUM_academic_discrimination-14 8 and 9
# GUM_academic_discrimination-14 7 Kessler 9
# GUM_academic_discrimination-14 6 by 9
# GUM_academic_discrimination-14 5 study 9
# GUM_academic_discrimination-14 46 [ 9
# GUM_academic_discrimination-14 9 colleague
# GUM_academic_discrimination-14 48 ]
# GUM_academic_discrimination-14  15 42
# GUM_academic_discrimination-14 42 , 14
# GUM_academic_discrimination-14 42 , 14
# GUM_academic_discrimination-14 16 use 17
# GUM_academic_discrimination-14 17 measure 14
# GUM_academic_discrimination-14 19 perceive 38
# GUM_academic_discrimination-14 37 of 38
# GUM_academic_discrimination-14 38 discrimination 14
# GUM_academic_discrimination-14 22 a 23
# GUM_academic_discrimination-14 21 in 23
# GUM_academic_discrimination-14 23 large 14
# GUM_academic_discrimination-14 25 sample 42
# GUM_academic_discrimination-14 28 that 29
# GUM_academic_discrimination-14 34 report 29
# GUM_academic_discrimination-14 29 approximately
# GUM_academic_discrimination-14  33 31
# GUM_academic_discrimination-14 33 respondent 34
# GUM_academic_discrimination-14 31 % 34
# GUM_academic_discrimination-14 24 American 34
# GUM_academic_discrimination-14 14 however 34
# GUM_academic_discrimination-14 35 some 34
# GUM_academic_discrimination-14 36 form 38
# GUM_academic_discrimination-14 39 ( 38
# GUM_academic_discrimination-14 43 Gibbons 41
# GUM_academic_discrimination-14 44 et 45
# GUM_academic_discrimination-14 45 al. 41
# GUM_academic_discrimination-14 46 [ 41
# GUM_academic_discrimination-14 41 also
# GUM_academic_discrimination-14 40 see
# GUM_academic_discrimination-14 48 ]
# GUM_academic_discrimination-14  4 49
# GUM_academic_discrimination-14 49 ) 50
# GUM_academic_discrimination-15 3 study 4
# GUM_academic_discrimination-15 5 to 6
# GUM_academic_discrimination-15 6 build 4
# GUM_academic_discrimination-15 7 on 6
# GUM_academic_discrimination-15 8 this 9
# GUM_academic_discrimination-15 9 research 4
# GUM_academic_discrimination-15 27 the 13
# GUM_academic_discrimination-15 11 estimate 13
# GUM_academic_discrimination-15 10 by 13
# GUM_academic_discrimination-15 4 seek 13
# GUM_academic_discrimination-15 16 experience 15
# GUM_academic_discrimination-15 18 a 19
# GUM_academic_discrimination-15 22 representative 23
# GUM_academic_discrimination-15 21 nationally 23
# GUM_academic_discrimination-15 23 sample 24
# GUM_academic_discrimination-15 28 Unite 29
# GUM_academic_discrimination-15 29 State 30
# GUM_academic_discrimination-15 26 from 30
# GUM_academic_discrimination-15 25 adult 30
# GUM_academic_discrimination-15 24 of 30
# GUM_academic_discrimination-15 20 , 30
# GUM_academic_discrimination-15 19 large 30
# GUM_academic_discrimination-15 17 among 30
# GUM_academic_discrimination-15 30 . 16
# GUM_academic_discrimination-16 6 the 4
# GUM_academic_discrimination-16 7 perceive 8
# GUM_academic_discrimination-16 9 for 10
# GUM_academic_discrimination-16 8 reason 10
# GUM_academic_discrimination-16 11 discrimination 10
# GUM_academic_discrimination-16 12 experience 11
# GUM_academic_discrimination-16 13 . 12
# GUM_academic_discrimination-17 2 for 3
# GUM_academic_discrimination-17 1 reason 3
# GUM_academic_discrimination-17 3 discrimination 4
# GUM_academic_discrimination-18 1 all 2
# GUM_academic_discrimination-18 13 who 4
# GUM_academic_discrimination-18 5 they 4
# GUM_academic_discrimination-18 27 be 7
# GUM_academic_discrimination-18 4 indicate 7
# GUM_academic_discrimination-18 2 respondent 7
# GUM_academic_discrimination-18 8 against 26
# GUM_academic_discrimination-18 11 , 12
# GUM_academic_discrimination-18 10 specifically 12
# GUM_academic_discrimination-18 26 — 12
# GUM_academic_discrimination-18 12 that 14
# GUM_academic_discrimination-18 17 or 18
# GUM_academic_discrimination-18 16 sometimes 18
# GUM_academic_discrimination-18 15 with 18
# GUM_academic_discrimination-18 14 respond 18
# GUM_academic_discrimination-18 7 discriminate 18
# GUM_academic_discrimination-18 21 perceive 22
# GUM_academic_discrimination-18 24 describe 25
# GUM_academic_discrimination-18 25 above 26
# GUM_academic_discrimination-18 23 measure 28
# GUM_academic_discrimination-18 22 discrimination 28
# GUM_academic_discrimination-18 29 the 28
# GUM_academic_discrimination-18 19 to 28
# GUM_academic_discrimination-18 28 ask 18
# GUM_academic_discrimination-18 30 follow 31
# GUM_academic_discrimination-18 18 often 31
# GUM_academic_discrimination-18 32 : 31
# GUM_academic_discrimination-19 4 you 5
# GUM_academic_discrimination-19 8 main 9
# GUM_academic_discrimination-19 12 experience 11
# GUM_academic_discrimination-19 13 ? 12
# GUM_academic_discrimination-19 14 '' 13
# GUM_academic_discrimination-20 2 be 3
# GUM_academic_discrimination-20 1 respondent 3
# GUM_academic_discrimination-20 4 to 5
# GUM_academic_discrimination-20 3 allow 5
# GUM_academic_discrimination-20 5 choose 6
# GUM_academic_discrimination-20 6 one 7
# GUM_academic_discrimination-20 10 category
# GUM_academic_discrimination-20  11 11
# GUM_academic_discrimination-20 8 from 11
# GUM_academic_discrimination-20 11 . 7
# GUM_academic_discrimination-21 8 be 9
# GUM_academic_discrimination-21 7 response 9
# GUM_academic_discrimination-21 6 this 9
# GUM_academic_discrimination-21 5 , 9
# GUM_academic_discrimination-21 4 analysis 9
# GUM_academic_discrimination-21 3 present 9
# GUM_academic_discrimination-21 16 the 9
# GUM_academic_discrimination-21 1 for 9
# GUM_academic_discrimination-21 10 into 11
# GUM_academic_discrimination-21 9 recode 11
# GUM_academic_discrimination-21 11 nine 12
# GUM_academic_discrimination-21 17 follow 18
# GUM_academic_discrimination-21 15 capture 18
# GUM_academic_discrimination-21 14 category 18
# GUM_academic_discrimination-21 18 option 13
# GUM_academic_discrimination-21 19 : 18
# GUM_academic_discrimination-22 4 / 3
# GUM_academic_discrimination-22 3 ancestry 4
# GUM_academic_discrimination-22 5 skin 6
# GUM_academic_discrimination-22 6 color 1
# GUM_academic_discrimination-26 2 or 3
# GUM_academic_discrimination-26 1 height 3
# GUM_academic_discrimination-26 3 weight 4
# GUM_academic_discrimination-27 2 orientation 1
# GUM_academic_discrimination-28 1 education 2
# GUM_academic_discrimination-28 2 or 3
# GUM_academic_discrimination-28 3 income 4
# GUM_academic_discrimination-29 1 physical 2
# GUM_academic_discrimination-30 1 and 2
# GUM_academic_discrimination-30 2 other 3
# GUM_academic_discrimination-31 2 follow 12
# GUM_academic_discrimination-31 14 the 12
# GUM_academic_discrimination-31 8 be 9
# GUM_academic_discrimination-31 7 questionnaire 9
# GUM_academic_discrimination-31 6 original 9
# GUM_academic_discrimination-31 4 from 9
# GUM_academic_discrimination-31 12 category 9
# GUM_academic_discrimination-31 11 one 12
# GUM_academic_discrimination-31 10 into 12
# GUM_academic_discrimination-31 13 for 15
# GUM_academic_discrimination-31 16 : 15
# GUM_academic_discrimination-31 17 race 15
# GUM_academic_discrimination-31 20 or 21
# GUM_academic_discrimination-31 19 ancestry 21
# GUM_academic_discrimination-31 23 ; 21
# GUM_academic_discrimination-31 21 national 15
# GUM_academic_discrimination-31 22 origin 21
# GUM_academic_discrimination-31 24 and 25
# GUM_academic_discrimination-31 15 analysis 25
# GUM_academic_discrimination-31 27 skin 28
# GUM_academic_discrimination-31 26 of 28
# GUM_academic_discrimination-31 28 color 29
# GUM_academic_discrimination-31 25 shade 29
# GUM_academic_discrimination-31 9 collapse 29
# GUM_academic_discrimination-32 4 this 5
# GUM_academic_discrimination-32 3 because 5
# GUM_academic_discrimination-32 16 , 5
# GUM_academic_discrimination-32 1 additionally 5
# GUM_academic_discrimination-32 7 only 8
# GUM_academic_discrimination-32 6 be 8
# GUM_academic_discrimination-32 8 ask 5
# GUM_academic_discrimination-32 28 of 10
# GUM_academic_discrimination-32 10 respondent 11
# GUM_academic_discrimination-32 12 report 13
# GUM_academic_discrimination-32 13 prior 14
# GUM_academic_discrimination-32 16 , 15
# GUM_academic_discrimination-32 17 the 18
# GUM_academic_discrimination-32 18 build 15
# GUM_academic_discrimination-32 15 experience 19
# GUM_academic_discrimination-32 14 discrimination 19
# GUM_academic_discrimination-32 11 who 19
# GUM_academic_discrimination-32 5 question 19
# GUM_academic_discrimination-32 19 - 24
# GUM_academic_discrimination-32 24 in 35
# GUM_academic_discrimination-32 35 skip 22
# GUM_academic_discrimination-32 23 result 22
# GUM_academic_discrimination-32 29 case 30
# GUM_academic_discrimination-32 27 number 30
# GUM_academic_discrimination-32 26 large 30
# GUM_academic_discrimination-32 25 a 30
# GUM_academic_discrimination-32 22 pattern 30
# GUM_academic_discrimination-32 31 as 32
# GUM_academic_discrimination-32 30 score 32
# GUM_academic_discrimination-32 32 missing 33
# GUM_academic_discrimination-32 34 legitimate 36
# GUM_academic_discrimination-32 33 ( 36
# GUM_academic_discrimination-32 36 ) 37
# GUM_academic_discrimination-33 1 respondent 2
# GUM_academic_discrimination-33 2 race 3
# GUM_academic_discrimination-34 5 be 6
# GUM_academic_discrimination-34 4 variable 6
# GUM_academic_discrimination-34 3 race 6
# GUM_academic_discrimination-34 6 not 7
# GUM_academic_discrimination-34 2 a 7
# GUM_academic_discrimination-34 1 because 7
# GUM_academic_discrimination-34 24 the 25
# GUM_academic_discrimination-34 8 from 25
# GUM_academic_discrimination-34 25 Wave 7
# GUM_academic_discrimination-34  4 7
# GUM_academic_discrimination-34 7 available 27
# GUM_academic_discrimination-34 14 we 15
# GUM_academic_discrimination-34 18 category 19
# GUM_academic_discrimination-34 17 racial 19
# GUM_academic_discrimination-34 15 use 19
# GUM_academic_discrimination-34 13 , 19
# GUM_academic_discrimination-34 27 interview 19
# GUM_academic_discrimination-34 20 by 22
# GUM_academic_discrimination-34 19 report 22
# GUM_academic_discrimination-34 23 during 25
# GUM_academic_discrimination-34 22 respondent 25
# GUM_academic_discrimination-34  1 27
# GUM_academic_discrimination-35 10 Wave
# GUM_academic_discrimination-35  1 12
# GUM_academic_discrimination-35 12 race 13
# GUM_academic_discrimination-35 13 — 5
# GUM_academic_discrimination-35 6 than 5
# GUM_academic_discrimination-35 9 , 8
# GUM_academic_discrimination-35 8 say 9
# GUM_academic_discrimination-35 12 race
# GUM_academic_discrimination-35  3 13
# GUM_academic_discrimination-35 5 rather 13
# GUM_academic_discrimination-35 14 be 15
# GUM_academic_discrimination-35 16 to 17
# GUM_academic_discrimination-35 17 preserve 18
# GUM_academic_discrimination-35 19 count 18
# GUM_academic_discrimination-35 20 . 18
# GUM_academic_discrimination-36 2 logic 24
# GUM_academic_discrimination-36 14 the 24
# GUM_academic_discrimination-36 24 be 4
# GUM_academic_discrimination-36 7 ) 21
# GUM_academic_discrimination-36 21 all 6
# GUM_academic_discrimination-36 27 Wave 21
# GUM_academic_discrimination-36  4 11
# GUM_academic_discrimination-36 13 in 27
# GUM_academic_discrimination-36 12 appear 27
# GUM_academic_discrimination-36 11 respondent 27
# GUM_academic_discrimination-36  1 27
# GUM_academic_discrimination-36 17 sample 18
# GUM_academic_discrimination-36 23 have 24
# GUM_academic_discrimination-36 22 would 24
# GUM_academic_discrimination-36 26 at 27
# GUM_academic_discrimination-36 25 interview 27
# GUM_academic_discrimination-36  3 29
# GUM_academic_discrimination-36 32 pattern 31
# GUM_academic_discrimination-36 34 temporary 35
# GUM_academic_discrimination-36 33 of 35
# GUM_academic_discrimination-36 35 attrition 36
# GUM_academic_discrimination-36 31 differential 36
# GUM_academic_discrimination-36 30 to 36
# GUM_academic_discrimination-36 29 due 36
# GUM_academic_discrimination-36 20 not 36
# GUM_academic_discrimination-36 36 . 19
# GUM_academic_discrimination-37 2 be 3
# GUM_academic_discrimination-37 1 respondent 3
# GUM_academic_discrimination-37 4 to 5
# GUM_academic_discrimination-37 5 indicate 3
# GUM_academic_discrimination-37 3 ask 6
# GUM_academic_discrimination-37 6 their 7
# GUM_academic_discrimination-37 11 follow 12
# GUM_academic_discrimination-37 10 the 12
# GUM_academic_discrimination-37 9 among 12
# GUM_academic_discrimination-37 8 from 12
# GUM_academic_discrimination-37 13 : 12
# GUM_academic_discrimination-37 14 White 12
# GUM_academic_discrimination-37 31 or 18
# GUM_academic_discrimination-37 18 African 16
# GUM_academic_discrimination-37 16 Black 27
# GUM_academic_discrimination-37 28 ; 21
# GUM_academic_discrimination-37 21 Hispanic 27
# GUM_academic_discrimination-37 27 American 24
# GUM_academic_discrimination-37 24 Indian 31
# GUM_academic_discrimination-37 26 Native 31
# GUM_academic_discrimination-37 29 and 30
# GUM_academic_discrimination-37 30 Asian 21
# GUM_academic_discrimination-37 32 Pacific 33
# GUM_academic_discrimination-37 33 Islander 34
# GUM_academic_discrimination-37 12 category 34
# GUM_academic_discrimination-38 17 be 3
# GUM_academic_discrimination-38 1 respondent 3
# GUM_academic_discrimination-38 4 the 5
# GUM_academic_discrimination-38 6 to 7
# GUM_academic_discrimination-38 7 select 8
# GUM_academic_discrimination-38 8 more 9
# GUM_academic_discrimination-38 10 one 11
# GUM_academic_discrimination-38 13 and 14
# GUM_academic_discrimination-38 12 , 14
# GUM_academic_discrimination-38 11 race 14
# GUM_academic_discrimination-38 9 than 14
# GUM_academic_discrimination-38 5 opportunity 14
# GUM_academic_discrimination-38 14 that 15
# GUM_academic_discrimination-38 15 who 16
# GUM_academic_discrimination-38 16 do 18
# GUM_academic_discrimination-38 3 provide 18
# GUM_academic_discrimination-38 18 ask 19
# GUM_academic_discrimination-38 19 a 20
# GUM_academic_discrimination-38 20 follow 21
# GUM_academic_discrimination-38 21 - 22
# GUM_academic_discrimination-38 22 up 23
# GUM_academic_discrimination-38 23 question 24
# GUM_academic_discrimination-38 24 regard 25
# GUM_academic_discrimination-38 25 which 26
# GUM_academic_discrimination-38 27 well 28
# GUM_academic_discrimination-38 28 describe 29
# GUM_academic_discrimination-38 30 racial 31
# GUM_academic_discrimination-38 29 their 31
# GUM_academic_discrimination-38 32 . 31
# GUM_academic_discrimination-39 5 , 6
# GUM_academic_discrimination-39 4 study 6
# GUM_academic_discrimination-39 3 current 6
# GUM_academic_discrimination-39 8 who 9
# GUM_academic_discrimination-39 10 more 9
# GUM_academic_discrimination-39 12 one 19
# GUM_academic_discrimination-39 14 be 15
# GUM_academic_discrimination-39 19 race 15
# GUM_academic_discrimination-39 11 than 15
# GUM_academic_discrimination-39 9 indicate 15
# GUM_academic_discrimination-39 7 respondent 15
# GUM_academic_discrimination-39 6 that 15
# GUM_academic_discrimination-39 2 the 15
# GUM_academic_discrimination-39 1 in 15
# GUM_academic_discrimination-39 16 as 20
# GUM_academic_discrimination-39 20 '' 18
# GUM_academic_discrimination-39 18 mix 15
# GUM_academic_discrimination-39 20 '' 19
# GUM_academic_discrimination-39 21 . 19
# GUM_academic_discrimination-40 2 variable 1
# GUM_academic_discrimination-40 3 . 1
# GUM_academic_discrimination-41 1 to 2
# GUM_academic_discrimination-41 2 provide 3
# GUM_academic_discrimination-41 6 analytical 7
# GUM_academic_discrimination-41 9 a 10
# GUM_academic_discrimination-41 8 as 10
# GUM_academic_discrimination-41 7 sample 10
# GUM_academic_discrimination-41 10 whole 11
# GUM_academic_discrimination-41 5 the 11
# GUM_academic_discrimination-41 4 on 11
# GUM_academic_discrimination-41 11 , 3
# GUM_academic_discrimination-41 12 two 3
# GUM_academic_discrimination-41 15 variable 14
# GUM_academic_discrimination-41 16 be 17
# GUM_academic_discrimination-41 17 include 14
# GUM_academic_discrimination-42 7 measure 8
# GUM_academic_discrimination-42 6 continuous 8
# GUM_academic_discrimination-42 5 a 8
# GUM_academic_discrimination-42 4 be 8
# GUM_academic_discrimination-42 3 age 8
# GUM_academic_discrimination-42 2 , 8
# GUM_academic_discrimination-42 1 first 8
# GUM_academic_discrimination-42 10 subtract 28
# GUM_academic_discrimination-42 15 respondent 28
# GUM_academic_discrimination-42 16 's 15
# GUM_academic_discrimination-42 28 the 17
# GUM_academic_discrimination-42 27 of 17
# GUM_academic_discrimination-42 26 year 17
# GUM_academic_discrimination-42 17 birth 18
# GUM_academic_discrimination-42 18 ( 28
# GUM_academic_discrimination-42 9 by 19
# GUM_academic_discrimination-42 19 obtain 8
# GUM_academic_discrimination-42 24 from 19
# GUM_academic_discrimination-42 8 create 31
# GUM_academic_discrimination-42 31 Wave
# GUM_academic_discrimination-42  1 23
# GUM_academic_discrimination-42 23 ) 26
# GUM_academic_discrimination-42 30 at 31
# GUM_academic_discrimination-42 29 interview 31
# GUM_academic_discrimination-42  4 33
# GUM_academic_discrimination-43 2 , 13
# GUM_academic_discrimination-43 5 dichotomously 6
# GUM_academic_discrimination-43 4 be 6
# GUM_academic_discrimination-43 13 sex 6
# GUM_academic_discrimination-43 7 base 8
# GUM_academic_discrimination-43 15 the 10
# GUM_academic_discrimination-43 10 self 11
# GUM_academic_discrimination-43 11 - 12
# GUM_academic_discrimination-43 12 report 13
# GUM_academic_discrimination-43 14 of 16
# GUM_academic_discrimination-43 17 at 18
# GUM_academic_discrimination-43 16 respondent 18
# GUM_academic_discrimination-43 18 Wave
# GUM_academic_discrimination-43 8 on
# GUM_academic_discrimination-43 6 code
# GUM_academic_discrimination-43 1 second
# GUM_academic_discrimination-43  4 20
# GUM_academic_discrimination-43  0 26
# GUM_academic_discrimination-43 23 female 24
# GUM_academic_discrimination-43 26 = 24
# GUM_academic_discrimination-43 20 ( 24
# GUM_academic_discrimination-43  1 24
# GUM_academic_discrimination-43 27 male 28
# GUM_academic_discrimination-43 24 and 28
# GUM_academic_discrimination-43 28 ) 29
# GUM_academic_discrimination-44 1 analytical 2
# GUM_academic_discrimination-44 2 plan 3
# GUM_academic_discrimination-45 3 study 4
# GUM_academic_discrimination-45 5 three 6
# GUM_academic_discrimination-45 7 step 6
# GUM_academic_discrimination-45 8 . 6
# GUM_academic_discrimination-46 3 summary 4
# GUM_academic_discrimination-46 2 , 4
# GUM_academic_discrimination-46 7 study 8
# GUM_academic_discrimination-46 12 be 13
# GUM_academic_discrimination-46 11 category 13
# GUM_academic_discrimination-46 10 racial 13
# GUM_academic_discrimination-46 9 and 13
# GUM_academic_discrimination-46 8 variable 13
# GUM_academic_discrimination-46 6 the 13
# GUM_academic_discrimination-46 5 of 13
# GUM_academic_discrimination-46 4 statistic 13
# GUM_academic_discrimination-46 1 first 13
# GUM_academic_discrimination-46 14 . 13
# GUM_academic_discrimination-47 3 we 4
# GUM_academic_discrimination-47 7 proportion 6
# GUM_academic_discrimination-47 8 of 9
# GUM_academic_discrimination-47 9 the 6
# GUM_academic_discrimination-47 6 relative 10
# GUM_academic_discrimination-47 10 two 4
# GUM_academic_discrimination-47 11 discrimination 4
# GUM_academic_discrimination-47 13 measure 12
# GUM_academic_discrimination-47 14 across 15
# GUM_academic_discrimination-47 15 each 16
# GUM_academic_discrimination-47 16 racial 17
# GUM_academic_discrimination-47 17 category 12
# GUM_academic_discrimination-47 18 . 12
# GUM_academic_discrimination-48 1 finally 2
# GUM_academic_discrimination-48 3 we 4
# GUM_academic_discrimination-48 13 the 4
# GUM_academic_discrimination-48 4 assess 6
# GUM_academic_discrimination-48 2 , 6
# GUM_academic_discrimination-48 7 of 8
# GUM_academic_discrimination-48 8 report 6
# GUM_academic_discrimination-48 6 distribution 9
# GUM_academic_discrimination-48 10 for 9
# GUM_academic_discrimination-48 9 reason 11
# GUM_academic_discrimination-48 15 category 14
# GUM_academic_discrimination-48 16 . 14
# GUM_academic_discrimination-49 33 in 2
# GUM_academic_discrimination-49 3 to 4
# GUM_academic_discrimination-49 2 order 4
# GUM_academic_discrimination-49 4 examine 5
# GUM_academic_discrimination-49 7 association 6
# GUM_academic_discrimination-49 10 adjust 17
# GUM_academic_discrimination-49 17 F 12
# GUM_academic_discrimination-49 34 the 12
# GUM_academic_discrimination-49 8 , 12
# GUM_academic_discrimination-49 12 statistic 6
# GUM_academic_discrimination-49 13 ( 12
# GUM_academic_discrimination-49 28 design 15
# GUM_academic_discrimination-49 16 base 17
# GUM_academic_discrimination-49 15 - 18
# GUM_academic_discrimination-49 6 bivariate 18
# GUM_academic_discrimination-49 19 be 20
# GUM_academic_discrimination-49 18 ) 20
# GUM_academic_discrimination-49 5 potential 20
# GUM_academic_discrimination-49 22 it 23
# GUM_academic_discrimination-49 30 as 23
# GUM_academic_discrimination-49 24 for 23
# GUM_academic_discrimination-49 27 sample 28
# GUM_academic_discrimination-49 30 as 29
# GUM_academic_discrimination-49 29 such 31
# GUM_academic_discrimination-49 31 that 32
# GUM_academic_discrimination-49 26 complex 32
# GUM_academic_discrimination-49 25 a 32
# GUM_academic_discrimination-49 32 use 23
# GUM_academic_discrimination-49 35 Add 36
# GUM_academic_discrimination-49 36 Health 23
# GUM_academic_discrimination-49 37 . 23
# GUM_academic_discrimination-49 38 [ 23
# GUM_academic_discrimination-49  21 23
# GUM_academic_discrimination-49 40 ] 23
# GUM_academic_discrimination-50 1 more 2
# GUM_academic_discrimination-50 5 analyze 6
# GUM_academic_discrimination-50 7 sample 6
# GUM_academic_discrimination-50 8 datum 7
# GUM_academic_discrimination-50 9 employ 17
# GUM_academic_discrimination-50 11 svy 12
# GUM_academic_discrimination-50 35 of 14
# GUM_academic_discrimination-50 14 command 15
# GUM_academic_discrimination-50 12 suite 15
# GUM_academic_discrimination-50 15 in 17
# GUM_academic_discrimination-50 16 Stata 15
# GUM_academic_discrimination-50 19 Pearson 18
# GUM_academic_discrimination-50 31 statistic 22
# GUM_academic_discrimination-50 20 χ2 22
# GUM_academic_discrimination-50 18 conventional 22
# GUM_academic_discrimination-50 17 the 22
# GUM_academic_discrimination-50 22 test 24
# GUM_academic_discrimination-50 25 be 26
# GUM_academic_discrimination-50 26 convert 24
# GUM_academic_discrimination-50 30 F 31
# GUM_academic_discrimination-50 39 a 31
# GUM_academic_discrimination-50 58 '' 31
# GUM_academic_discrimination-50 27 into 31
# GUM_academic_discrimination-50 33 noninteger 34
# GUM_academic_discrimination-50 32 with 34
# GUM_academic_discrimination-50 34 degree 36
# GUM_academic_discrimination-50 24 independence 36
# GUM_academic_discrimination-50 6 weight 36
# GUM_academic_discrimination-50 4 when 36
# GUM_academic_discrimination-50 51 , 36
# GUM_academic_discrimination-50 2 specifically 36
# GUM_academic_discrimination-50 41 - 40
# GUM_academic_discrimination-50 42 order 40
# GUM_academic_discrimination-50 44 and 45
# GUM_academic_discrimination-50 43 Rao 45
# GUM_academic_discrimination-50 40 second 45
# GUM_academic_discrimination-50 38 use 45
# GUM_academic_discrimination-50 37 by 45
# GUM_academic_discrimination-50 45 Scott 36
# GUM_academic_discrimination-50 46 ( 36
# GUM_academic_discrimination-50  1981 36
# GUM_academic_discrimination-50 60 [
# GUM_academic_discrimination-50  22
# GUM_academic_discrimination-50 62 ]
# GUM_academic_discrimination-50 51 ,
# GUM_academic_discrimination-50  1984
# GUM_academic_discrimination-50 60 [
# GUM_academic_discrimination-50  23
# GUM_academic_discrimination-50 62 ]
# GUM_academic_discrimination-50 58 '' 57
# GUM_academic_discrimination-50 59 . 57
# GUM_academic_discrimination-50 60 [ 57
# GUM_academic_discrimination-50  24 57
# GUM_academic_discrimination-50 62 ]
# GUM_academic_discrimination-51 37 the 2
# GUM_academic_discrimination-51 2 p 9
# GUM_academic_discrimination-51 9 - 4
# GUM_academic_discrimination-51 19 associate 4
# GUM_academic_discrimination-51 8 design 9
# GUM_academic_discrimination-51 10 base 11
# GUM_academic_discrimination-51 12 be 13
# GUM_academic_discrimination-51 11 F 13
# GUM_academic_discrimination-51 20 with 13
# GUM_academic_discrimination-51 4 value 13
# GUM_academic_discrimination-51 14 more 15
# GUM_academic_discrimination-51 15 accurate 13
# GUM_academic_discrimination-51 16 ( 15
# GUM_academic_discrimination-51 22 χ2 23
# GUM_academic_discrimination-51 23 statistic 24
# GUM_academic_discrimination-51 25 give 27
# GUM_academic_discrimination-51 28 and 27
# GUM_academic_discrimination-51 29 calculation 27
# GUM_academic_discrimination-51 30 take 27
# GUM_academic_discrimination-51 31 into 32
# GUM_academic_discrimination-51 27 adjustment 32
# GUM_academic_discrimination-51 34 weight 35
# GUM_academic_discrimination-51 32 account 35
# GUM_academic_discrimination-51 24 ) 35
# GUM_academic_discrimination-51 36 of 38
# GUM_academic_discrimination-51 35 nature 38
# GUM_academic_discrimination-51 38 datum 39
# GUM_academic_discrimination-51 17 than 39
# GUM_academic_discrimination-51 39 . 15
# GUM_academic_discrimination-52 2 final 3
# GUM_academic_discrimination-52 6 a 7
# GUM_academic_discrimination-52 5 include 7
# GUM_academic_discrimination-52 4 also 7
# GUM_academic_discrimination-52 3 step 7
# GUM_academic_discrimination-52 1 this 7
# GUM_academic_discrimination-52 10 relative 11
# GUM_academic_discrimination-52 16 the 11
# GUM_academic_discrimination-52 12 of 11
# GUM_academic_discrimination-52 14 category 13
# GUM_academic_discrimination-52 15 across 17
# GUM_academic_discrimination-52 17 various 18
# GUM_academic_discrimination-52 18 report 19
# GUM_academic_discrimination-52 19 reason 13
# GUM_academic_discrimination-52 20 for 21
# GUM_academic_discrimination-52 21 discrimination 13
# GUM_academic_discrimination-52 22 . 13
# GUM_academic_discrimination-53 1 as 2
# GUM_academic_discrimination-53 2 note 3
# GUM_academic_discrimination-53 24 be 13
# GUM_academic_discrimination-53 6 analysis 13
# GUM_academic_discrimination-53 5 all 13
# GUM_academic_discrimination-53 4 , 13
# GUM_academic_discrimination-53 3 early 13
# GUM_academic_discrimination-53 9 accord 13
# GUM_academic_discrimination-53 12 survey 13
# GUM_academic_discrimination-53 33 the 13
# GUM_academic_discrimination-53 10 to 13
# GUM_academic_discrimination-53 14 provide 13
# GUM_academic_discrimination-53 19 research 20
# GUM_academic_discrimination-53 18 Health 20
# GUM_academic_discrimination-53 17 Add 20
# GUM_academic_discrimination-53 23 error 25
# GUM_academic_discrimination-53 22 standard 25
# GUM_academic_discrimination-53 29 and 25
# GUM_academic_discrimination-53 20 staff 25
# GUM_academic_discrimination-53 15 by 25
# GUM_academic_discrimination-53 13 weight 25
# GUM_academic_discrimination-53 26 for 25
# GUM_academic_discrimination-53 25 correct 28
# GUM_academic_discrimination-53 28 clustering 29
# GUM_academic_discrimination-53 30 stratification 31
# GUM_academic_discrimination-53 31 that 32
# GUM_academic_discrimination-53 34 sampling 35
# GUM_academic_discrimination-53 32 define 35
# GUM_academic_discrimination-53 35 strategy 36
# GUM_academic_discrimination-54 4 estimate 5
# GUM_academic_discrimination-54 3 all 5
# GUM_academic_discrimination-54 2 , 5
# GUM_academic_discrimination-54 1 thus 5
# GUM_academic_discrimination-54 6 here 5
# GUM_academic_discrimination-54 7 can 8
# GUM_academic_discrimination-54 9 consider 8
# GUM_academic_discrimination-54 10 nationally 11
# GUM_academic_discrimination-54 11 representative 8
# GUM_academic_discrimination-54 14 Unite 15
# GUM_academic_discrimination-54 15 State 16
# GUM_academic_discrimination-54 16 . 13
# GUM_academic_eegimaa-1 2 Gujjolaay 3
# GUM_academic_eegimaa-1 6 speaker 7
# GUM_academic_eegimaa-1 7 and 8
# GUM_academic_eegimaa-1 8 their 9
# GUM_academic_eegimaa-1 5 its 9
# GUM_academic_eegimaa-1 4 , 9
# GUM_academic_eegimaa-1 9 neighbour 3
# GUM_academic_eegimaa-2 1 this 2
# GUM_academic_eegimaa-2 3 briefly 4
# GUM_academic_eegimaa-2 6 Gújjolaay 9
# GUM_academic_eegimaa-2 5 the 9
# GUM_academic_eegimaa-2 9 Eegimaa 4
# GUM_academic_eegimaa-2 10 for 11
# GUM_academic_eegimaa-2 8 ( 11
# GUM_academic_eegimaa-2 11 short 12
# GUM_academic_eegimaa-2 13 Ethnologue 14
# GUM_academic_eegimaa-2 18 : 14
# GUM_academic_eegimaa-2 16 ISO 14
# GUM_academic_eegimaa-2 17 639-3 14
# GUM_academic_eegimaa-2 18 : 17
# GUM_academic_eegimaa-2 23 speaker 24
# GUM_academic_eegimaa-2 25 its 26
# GUM_academic_eegimaa-2 26 variety 24
# GUM_academic_eegimaa-2 27 . 26
# GUM_academic_eegimaa-3 3 discuss 4
# GUM_academic_eegimaa-3 2 also 4
# GUM_academic_eegimaa-3 1 we 4
# GUM_academic_eegimaa-3 7 contact 8
# GUM_academic_eegimaa-3 10 the 8
# GUM_academic_eegimaa-3 9 of 8
# GUM_academic_eegimaa-3 4 aspect 8
# GUM_academic_eegimaa-3 11 Eegimaa 12
# GUM_academic_eegimaa-3 12 language 8
# GUM_academic_eegimaa-3 8 situation 13
# GUM_academic_eegimaa-4 27 be 3
# GUM_academic_eegimaa-4 1 this 3
# GUM_academic_eegimaa-4 7 we 8
# GUM_academic_eegimaa-4 6 as 8
# GUM_academic_eegimaa-4 8 will 9
# GUM_academic_eegimaa-4 5 because 9
# GUM_academic_eegimaa-4 14 , 9
# GUM_academic_eegimaa-4 10 in 9
# GUM_academic_eegimaa-4 9 show 11
# GUM_academic_eegimaa-4  6 11
# GUM_academic_eegimaa-4 26 name 22
# GUM_academic_eegimaa-4 20 prevention 22
# GUM_academic_eegimaa-4 22 and 23
# GUM_academic_eegimaa-4 19 death 23
# GUM_academic_eegimaa-4 30 Eegimaa 23
# GUM_academic_eegimaa-4 17 the 23
# GUM_academic_eegimaa-4 16 of 23
# GUM_academic_eegimaa-4 15 some 23
# GUM_academic_eegimaa-4 13 below 23
# GUM_academic_eegimaa-4 11 § 23
# GUM_academic_eegimaa-4 23 child 24
# GUM_academic_eegimaa-4 24 - 25
# GUM_academic_eegimaa-4 26 name 25
# GUM_academic_eegimaa-4 28 give 26
# GUM_academic_eegimaa-4 34 community 33
# GUM_academic_eegimaa-4 35 . 34
# GUM_academic_eegimaa-5 5 language 6
# GUM_academic_eegimaa-5 4 Jóola 6
# GUM_academic_eegimaa-5 16 a 6
# GUM_academic_eegimaa-5 20 be 6
# GUM_academic_eegimaa-5 1 Eegimaa 6
# GUM_academic_eegimaa-5 10 Casamance 11
# GUM_academic_eegimaa-5 9 Basse 11
# GUM_academic_eegimaa-5 8 the 11
# GUM_academic_eegimaa-5 7 in 11
# GUM_academic_eegimaa-5 6 speak 11
# GUM_academic_eegimaa-5 13 Southern 14
# GUM_academic_eegimaa-5 17 population 18
# GUM_academic_eegimaa-5 19 to 20
# GUM_academic_eegimaa-5 18 estimate 20
# GUM_academic_eegimaa-5 21 between
# GUM_academic_eegimaa-5 15 by
# GUM_academic_eegimaa-5 14 Senegal
# GUM_academic_eegimaa-5 12 of
# GUM_academic_eegimaa-5 11 area
# GUM_academic_eegimaa-5  7000 31
# GUM_academic_eegimaa-5 24 Bassène 38
# GUM_academic_eegimaa-5 31 ( 38
# GUM_academic_eegimaa-5 38 ,
# GUM_academic_eegimaa-5  2007 40
# GUM_academic_eegimaa-5 40 ) 28
# GUM_academic_eegimaa-5  11200 28
# GUM_academic_eegimaa-5 30 speaker 28
# GUM_academic_eegimaa-5 31 ( 30
# GUM_academic_eegimaa-5 32 Lewis 34
# GUM_academic_eegimaa-5 34 Simons 36
# GUM_academic_eegimaa-5 28 and 36
# GUM_academic_eegimaa-5 36 & 37
# GUM_academic_eegimaa-5 37 Fennig 38
# GUM_academic_eegimaa-5  2014 40
# GUM_academic_eegimaa-6 3 be 4
# GUM_academic_eegimaa-6 22 language 4
# GUM_academic_eegimaa-6 1 Jóola 4
# GUM_academic_eegimaa-6 5 as 6
# GUM_academic_eegimaa-6 9 's 8
# GUM_academic_eegimaa-6 8 Sapir 10
# GUM_academic_eegimaa-6 18 of 10
# GUM_academic_eegimaa-6 6 member 10
# GUM_academic_eegimaa-6  1971 12
# GUM_academic_eegimaa-6 10 ( 12
# GUM_academic_eegimaa-6 12 ) 13
# GUM_academic_eegimaa-6 13 Bak 14
# GUM_academic_eegimaa-6 21 Congo 23
# GUM_academic_eegimaa-6 20 Niger 23
# GUM_academic_eegimaa-6 19 the 23
# GUM_academic_eegimaa-6 16 Atlantic 23
# GUM_academic_eegimaa-6 14 group 23
# GUM_academic_eegimaa-6 4 classify 23
# GUM_academic_eegimaa-6 23 phylum 24
# GUM_academic_eegimaa-7 4 language 5
# GUM_academic_eegimaa-7 3 this 5
# GUM_academic_eegimaa-7 16 of 5
# GUM_academic_eegimaa-7 1 speaker 5
# GUM_academic_eegimaa-7 5 be 6
# GUM_academic_eegimaa-7 12 the 9
# GUM_academic_eegimaa-7 20 in 9
# GUM_academic_eegimaa-7 14 Casamance 15
# GUM_academic_eegimaa-7 13 former 15
# GUM_academic_eegimaa-7 10 , 15
# GUM_academic_eegimaa-7 9 Gambia 15
# GUM_academic_eegimaa-7 17 Southern 18
# GUM_academic_eegimaa-7 19 and 21
# GUM_academic_eegimaa-7 18 Senegal 21
# GUM_academic_eegimaa-7 15 region 21
# GUM_academic_eegimaa-7 21 Guinea 6
# GUM_academic_eegimaa-7 22 Bissau 6
# GUM_academic_eegimaa-7 23 . 6
# GUM_academic_eegimaa-8 12 the 2
# GUM_academic_eegimaa-8 3 in 4
# GUM_academic_eegimaa-8 2 map 4
# GUM_academic_eegimaa-8  1 4
# GUM_academic_eegimaa-8 4 Figure 10
# GUM_academic_eegimaa-8 10 , 7
# GUM_academic_eegimaa-8 8 from 9
# GUM_academic_eegimaa-8 7 take 9
# GUM_academic_eegimaa-8 9 Ethnologue 10
# GUM_academic_eegimaa-8 14 of 15
# GUM_academic_eegimaa-8 13 language 15
# GUM_academic_eegimaa-8 11 present 15
# GUM_academic_eegimaa-8 15 Senegal 16
# GUM_academic_eegimaa-9 15 the 2
# GUM_academic_eegimaa-9 3 on 5
# GUM_academic_eegimaa-9 5 map 6
# GUM_academic_eegimaa-9 2 arrow 6
# GUM_academic_eegimaa-9 10 speak 11
# GUM_academic_eegimaa-9 21 Eegimaa 11
# GUM_academic_eegimaa-9 7 to 11
# GUM_academic_eegimaa-9 6 point 11
# GUM_academic_eegimaa-9 12 ( 11
# GUM_academic_eegimaa-9 16 name 17
# GUM_academic_eegimaa-9 14 be 17
# GUM_academic_eegimaa-9 13 Bandial 17
# GUM_academic_eegimaa-9 11 area 17
# GUM_academic_eegimaa-9 18 by 19
# GUM_academic_eegimaa-9 20 for 21
# GUM_academic_eegimaa-9 21 Eegimaa 19
# GUM_academic_eegimaa-9 19 Ethnologue 22
# GUM_academic_eegimaa-9 17 use 22
# GUM_academic_eegimaa-9 22 ) 23
# GUM_academic_eegimaa-10 3 mainly 4
# GUM_academic_eegimaa-10 2 be 4
# GUM_academic_eegimaa-10 1 Eegimaa 4
# GUM_academic_eegimaa-10 31 in 6
# GUM_academic_eegimaa-10 6 Mof-Ávvi 20
# GUM_academic_eegimaa-10 26 former 10
# GUM_academic_eegimaa-10 8 a 10
# GUM_academic_eegimaa-10 34 of
# GUM_academic_eegimaa-10  10 10
# GUM_academic_eegimaa-10 13 village 14
# GUM_academic_eegimaa-10 10 kingdom 14
# GUM_academic_eegimaa-10 20 , 14
# GUM_academic_eegimaa-10 4 speak 14
# GUM_academic_eegimaa-10 32 the 17
# GUM_academic_eegimaa-10 15 to 17
# GUM_academic_eegimaa-10 14 locate 17
# GUM_academic_eegimaa-10 17 west 19
# GUM_academic_eegimaa-10 22 capital 23
# GUM_academic_eegimaa-10 27 administrative 28
# GUM_academic_eegimaa-10 28 region 30
# GUM_academic_eegimaa-10 30 Casamance 26
# GUM_academic_eegimaa-10 35 Senegal 33
# GUM_academic_eegimaa-10 36 . 33
# GUM_academic_eegimaa-11 3 a 4
# GUM_academic_eegimaa-11 4 peninsula 5
# GUM_academic_eegimaa-11 2 be 5
# GUM_academic_eegimaa-11 1 Mof-Ávvi 5
# GUM_academic_eegimaa-11 8 Casamance 9
# GUM_academic_eegimaa-11 38 the 9
# GUM_academic_eegimaa-11 27 to 12
# GUM_academic_eegimaa-11 9 River 12
# GUM_academic_eegimaa-11 30 by 12
# GUM_academic_eegimaa-11 5 border 12
# GUM_academic_eegimaa-11 12 north 36
# GUM_academic_eegimaa-11 14 which 15
# GUM_academic_eegimaa-11 22 Jóola 20
# GUM_academic_eegimaa-11 17 from 20
# GUM_academic_eegimaa-11 16 it 20
# GUM_academic_eegimaa-11 20 Búluf 15
# GUM_academic_eegimaa-11 42 and 15
# GUM_academic_eegimaa-11 22 Jóola 15
# GUM_academic_eegimaa-11 23 Fogny 24
# GUM_academic_eegimaa-11 33 Brin 32
# GUM_academic_eegimaa-11 37 where 39
# GUM_academic_eegimaa-11 40 of 41
# GUM_academic_eegimaa-11 41 Kujireray 39
# GUM_academic_eegimaa-11 42 and 39
# GUM_academic_eegimaa-11 43 Baïnounk 39
# GUM_academic_eegimaa-11 44 Gubëeher 45
# GUM_academic_eegimaa-11 45 live 46
# GUM_academic_eegimaa-11 46 . 39
# GUM_academic_eegimaa-12 1 in 30
# GUM_academic_eegimaa-12 30 the 3
# GUM_academic_eegimaa-12 6 river 7
# GUM_academic_eegimaa-12 18 , 7
# GUM_academic_eegimaa-12 8 as 7
# GUM_academic_eegimaa-12 9 Kamobeul 7
# GUM_academic_eegimaa-12 11 separate 24
# GUM_academic_eegimaa-12 10 Bolon 24
# GUM_academic_eegimaa-12 7 know 24
# GUM_academic_eegimaa-12 3 south 24
# GUM_academic_eegimaa-12 16 speak 17
# GUM_academic_eegimaa-12 29 of 24
# GUM_academic_eegimaa-12 24 Mof-Ávvi 25
# GUM_academic_eegimaa-12 22 side 25
# GUM_academic_eegimaa-12 21 west 25
# GUM_academic_eegimaa-12 19 while 25
# GUM_academic_eegimaa-12 17 area 25
# GUM_academic_eegimaa-12 15 Bayot 25
# GUM_academic_eegimaa-12 13 from 25
# GUM_academic_eegimaa-12 26 with 28
# GUM_academic_eegimaa-12 25 coincide 28
# GUM_academic_eegimaa-12 36 Kaasa 33
# GUM_academic_eegimaa-12 34 and 35
# GUM_academic_eegimaa-12 35 Jóola 33
# GUM_academic_eegimaa-12 33 Húluf 37
# GUM_academic_eegimaa-12 28 homeland 37
# GUM_academic_eegimaa-12 37 Ésuulaaluʔ 38
# GUM_academic_eegimaa-13 1 the 2
# GUM_academic_eegimaa-13 24 in 4
# GUM_academic_eegimaa-13 2 map 4
# GUM_academic_eegimaa-13  2 4
# GUM_academic_eegimaa-13 4 Figure 6
# GUM_academic_eegimaa-13 16 , 8
# GUM_academic_eegimaa-13 8 adapt 6
# GUM_academic_eegimaa-13 9 from 10
# GUM_academic_eegimaa-13 6 below 10
# GUM_academic_eegimaa-13 10 Palmeri 11
# GUM_academic_eegimaa-13 12 Gazio 13
# GUM_academic_eegimaa-13 11 and 13
# GUM_academic_eegimaa-13 13 (
# GUM_academic_eegimaa-13  1995 15
# GUM_academic_eegimaa-13 20 approximate 21
# GUM_academic_eegimaa-13 19 very 21
# GUM_academic_eegimaa-13 18 a 21
# GUM_academic_eegimaa-13 22 of 23
# GUM_academic_eegimaa-13 21 location 23
# GUM_academic_eegimaa-13 17 show 23
# GUM_academic_eegimaa-13 23 Mof-Ávvi 25
# GUM_academic_eegimaa-13 15 ) 25
# GUM_academic_eegimaa-13 28 neighbour 29
# GUM_academic_eegimaa-13 29 speech 30
# GUM_academic_eegimaa-13 30 community 27
# GUM_academic_eegimaa-13 31 . 30
# GUM_academic_eegimaa-14 4 community 3
# GUM_academic_eegimaa-14 6 be 7
# GUM_academic_eegimaa-14 5 will 7
# GUM_academic_eegimaa-14 3 this 7
# GUM_academic_eegimaa-14 12 of 7
# GUM_academic_eegimaa-14 1 some 7
# GUM_academic_eegimaa-14 16 in 10
# GUM_academic_eegimaa-14 10 our 11
# GUM_academic_eegimaa-14 17 §
# GUM_academic_eegimaa-14  6 15
# GUM_academic_eegimaa-14 15 name 19
# GUM_academic_eegimaa-14 14 prevention 19
# GUM_academic_eegimaa-14 13 death 19
# GUM_academic_eegimaa-14 11 discussion 19
# GUM_academic_eegimaa-14 8 to 19
# GUM_academic_eegimaa-14 19 . 7
# GUM_academic_eegimaa-15 2 Eegimaa 3
# GUM_academic_eegimaa-15 1 the 3
# GUM_academic_eegimaa-15 4 in 5
# GUM_academic_eegimaa-15 3 speak 5
# GUM_academic_eegimaa-15 5 Mof-Ávvi 6
# GUM_academic_eegimaa-15 6 be 7
# GUM_academic_eegimaa-15 11 give 10
# GUM_academic_eegimaa-15 12 by 13
# GUM_academic_eegimaa-15 10 name 13
# GUM_academic_eegimaa-15 13 speaker 9
# GUM_academic_eegimaa-15 15 neighbour 16
# GUM_academic_eegimaa-15 16 language 17
# GUM_academic_eegimaa-15 14 of 17
# GUM_academic_eegimaa-15 9 several 17
# GUM_academic_eegimaa-15 17 . 7
# GUM_academic_eegimaa-16 1 for 2
# GUM_academic_eegimaa-16 2 example 37
# GUM_academic_eegimaa-16 6 Kusiilay 17
# GUM_academic_eegimaa-16  1 17
# GUM_academic_eegimaa-16 39 the 26
# GUM_academic_eegimaa-16 13 ' 26
# GUM_academic_eegimaa-16 31 of 29
# GUM_academic_eegimaa-16 26 language 29
# GUM_academic_eegimaa-16 29 Essil 37
# GUM_academic_eegimaa-16 19 by 20
# GUM_academic_eegimaa-16 18 give 20
# GUM_academic_eegimaa-16 20 speaker 22
# GUM_academic_eegimaa-16 22 Kujireray 23
# GUM_academic_eegimaa-16 25 Eegimaa 37
# GUM_academic_eegimaa-16 23 to 37
# GUM_academic_eegimaa-16 17 name 37
# GUM_academic_eegimaa-16 38 be 37
# GUM_academic_eegimaa-16 37 , 37
# GUM_academic_eegimaa-16 28 because 29
# GUM_academic_eegimaa-16 41 which 33
# GUM_academic_eegimaa-16 43 a 36
# GUM_academic_eegimaa-16 36 district 37
# GUM_academic_eegimaa-16 37 , 33
# GUM_academic_eegimaa-16 47 village 33
# GUM_academic_eegimaa-16 42 have 44
# GUM_academic_eegimaa-16 44 border 33
# GUM_academic_eegimaa-16 46 their 47
# GUM_academic_eegimaa-16 45 with 47
# GUM_academic_eegimaa-16 47 village 33
# GUM_academic_eegimaa-16 48 . 33
# GUM_academic_eegimaa-17 5 give 4
# GUM_academic_eegimaa-17 7 Bayot 8
# GUM_academic_eegimaa-17 13 be 14
# GUM_academic_eegimaa-17 14 not 15
# GUM_academic_eegimaa-17 12 meaning 15
# GUM_academic_eegimaa-17 11 its 15
# GUM_academic_eegimaa-17 10 but 15
# GUM_academic_eegimaa-17 9 , 15
# GUM_academic_eegimaa-17 8 speaker 15
# GUM_academic_eegimaa-17 6 by 15
# GUM_academic_eegimaa-17 4 name 15
# GUM_academic_eegimaa-17 3 the 15
# GUM_academic_eegimaa-17 1 Endungo 15
# GUM_academic_eegimaa-18 27 the 5
# GUM_academic_eegimaa-18 33 ' 5
# GUM_academic_eegimaa-18 38 of 37
# GUM_academic_eegimaa-18 5 language 37
# GUM_academic_eegimaa-18 13 , 37
# GUM_academic_eegimaa-18 1 Kúlaakiay 37
# GUM_academic_eegimaa-18 31 / 32
# GUM_academic_eegimaa-18 30 Seleki 32
# GUM_academic_eegimaa-18 37 village 32
# GUM_academic_eegimaa-18 17 give 16
# GUM_academic_eegimaa-18 22 who 23
# GUM_academic_eegimaa-18 24 more 25
# GUM_academic_eegimaa-18 26 with 37
# GUM_academic_eegimaa-18 37 village 25
# GUM_academic_eegimaa-18 39 Mof-Ávvi 37
# GUM_academic_eegimaa-18 36 other 40
# GUM_academic_eegimaa-18 35 all 40
# GUM_academic_eegimaa-18 34 than 40
# GUM_academic_eegimaa-18 32 Sállagi 40
# GUM_academic_eegimaa-18 25 familiar 40
# GUM_academic_eegimaa-18 40 . 23
# GUM_academic_eegimaa-19 1 finally 42
# GUM_academic_eegimaa-19 4 / 5
# GUM_academic_eegimaa-19 49 Banjal 5
# GUM_academic_eegimaa-19 42 , 5
# GUM_academic_eegimaa-19 51 the 41
# GUM_academic_eegimaa-19 14 ' 41
# GUM_academic_eegimaa-19 5 Bandial 41
# GUM_academic_eegimaa-19 48 of 47
# GUM_academic_eegimaa-19 41 language 47
# GUM_academic_eegimaa-19 47 village 48
# GUM_academic_eegimaa-19 17 most 18
# GUM_academic_eegimaa-19 48 of 18
# GUM_academic_eegimaa-19 21 that 26
# GUM_academic_eegimaa-19 54 be 51
# GUM_academic_eegimaa-19 27 give 26
# GUM_academic_eegimaa-19 33 Jóola 51
# GUM_academic_eegimaa-19 31 Búluf 51
# GUM_academic_eegimaa-19 39 and 33
# GUM_academic_eegimaa-19 33 Jóola 31
# GUM_academic_eegimaa-19 34 Fogny 31
# GUM_academic_eegimaa-19 35 speaker 51
# GUM_academic_eegimaa-19 53 to 37
# GUM_academic_eegimaa-19 37 Eegimaa 35
# GUM_academic_eegimaa-19 44 person 35
# GUM_academic_eegimaa-19 55 in 56
# GUM_academic_eegimaa-19 57 with 58
# GUM_academic_eegimaa-19 58 they 56
# GUM_academic_eegimaa-19 56 contact 59
# GUM_academic_eegimaa-19 59 . 52
# GUM_academic_eegimaa-20  1 1
# GUM_academic_eegimaa-20 1 Figure 3
# GUM_academic_eegimaa-21 6 of 3
# GUM_academic_eegimaa-21 3 Senegal 8
# GUM_academic_eegimaa-21 4 ( 8
# GUM_academic_eegimaa-21 7 Google 8
# GUM_academic_eegimaa-21 8 map 5
# GUM_academic_eegimaa-21 5 courtesy 9
# GUM_academic_eegimaa-22  2 1
# GUM_academic_eegimaa-22 1 Figure 3
# GUM_academic_eegimaa-23 5 speak 6
# GUM_academic_eegimaa-23 4 Eegimaa 6
# GUM_academic_eegimaa-23 3 the 6
# GUM_academic_eegimaa-23 2 of 6
# GUM_academic_eegimaa-23 1 map 6
# GUM_academic_eegimaa-24 3 be 4
# GUM_academic_eegimaa-24 4 write 2
# GUM_academic_eegimaa-24 5 use 6
# GUM_academic_eegimaa-24 7 usual 8
# GUM_academic_eegimaa-24 8 spelling 9
# GUM_academic_eegimaa-24 6 their 9
# GUM_academic_eegimaa-24 9 . 4
# GUM_academic_eegimaa-25 8 language 4
# GUM_academic_eegimaa-25 5 be 6
# GUM_academic_eegimaa-25 4 code 6
# GUM_academic_eegimaa-25 2 Ethnologue 6
# GUM_academic_eegimaa-25 1 the 6
# GUM_academic_eegimaa-25 7 for 9
# GUM_academic_eegimaa-25 6 provide 9
# GUM_academic_eegimaa-25 9 variety 10
# GUM_academic_eegimaa-25 11 have 12
# GUM_academic_eegimaa-25 10 that 12
# GUM_academic_eegimaa-25 12 they 13
# GUM_academic_eegimaa-26 13 language 2
# GUM_academic_eegimaa-26 3 be 4
# GUM_academic_eegimaa-26 4 write 2
# GUM_academic_eegimaa-26 5 follow 9
# GUM_academic_eegimaa-26 9 the 7
# GUM_academic_eegimaa-26 8 for 10
# GUM_academic_eegimaa-26 7 recommendation 10
# GUM_academic_eegimaa-26 14 of 15
# GUM_academic_eegimaa-26 15 Senegal 16
# GUM_academic_eegimaa-26 12 national 16
# GUM_academic_eegimaa-26 10 transcription 16
# GUM_academic_eegimaa-26 16 , 4
# GUM_academic_eegimaa-26 17 Decree 4
# GUM_academic_eegimaa-26 18 2005-981 4
# GUM_academic_eegimaa-27 15 the 18
# GUM_academic_eegimaa-27 17 of 18
# GUM_academic_eegimaa-27 19 name 18
# GUM_academic_eegimaa-27 6 Mof-Ávvi 18
# GUM_academic_eegimaa-27 7 be 8
# GUM_academic_eegimaa-27 8 write 18
# GUM_academic_eegimaa-27 9 use 15
# GUM_academic_eegimaa-27 11 Eegimaa 12
# GUM_academic_eegimaa-27 13 and 14
# GUM_academic_eegimaa-27 12 orthography 14
# GUM_academic_eegimaa-27 14 follow 15
# GUM_academic_eegimaa-27 15 the 15
# GUM_academic_eegimaa-27 22 speaker 21
# GUM_academic_eegimaa-27 23 . 21
# GUM_academic_eegimaa-28 2 language 3
# GUM_academic_eegimaa-28 3 variety 1
# GUM_academic_eegimaa-28 6 closely 7
# GUM_academic_eegimaa-28 5 be 7
# GUM_academic_eegimaa-28 4 which 7
# GUM_academic_eegimaa-28 7 related 1
# GUM_academic_eegimaa-28 8 to 9
# GUM_academic_eegimaa-28 9 Eegimaa 7
# GUM_academic_eegimaa-28 12 / 13
# GUM_academic_eegimaa-28 11 Kujireray 13
# GUM_academic_eegimaa-28 10 include 13
# GUM_academic_eegimaa-28 13 Kuluunaay 1
# GUM_academic_eegimaa-28 39 ( 1
# GUM_academic_eegimaa-28 30 the 31
# GUM_academic_eegimaa-28 29 from 31
# GUM_academic_eegimaa-28 32 of 19
# GUM_academic_eegimaa-28 19 Brin 31
# GUM_academic_eegimaa-28 34 with
# GUM_academic_eegimaa-28  76 31
# GUM_academic_eegimaa-28 36 % 37
# GUM_academic_eegimaa-28 38 similarity 49
# GUM_academic_eegimaa-28 37 lexical 49
# GUM_academic_eegimaa-28 31 village 49
# GUM_academic_eegimaa-28 1 Jóola 49
# GUM_academic_eegimaa-28 26 and 27
# GUM_academic_eegimaa-28 49 ) 27
# GUM_academic_eegimaa-28 27 Gufiñamay 39
# GUM_academic_eegimaa-28 33 Afiniam
# GUM_academic_eegimaa-28  74 36
# GUM_academic_eegimaa-28 44 al. 45
# GUM_academic_eegimaa-28 43 et 45
# GUM_academic_eegimaa-28 42 Lewis 45
# GUM_academic_eegimaa-28 45 ,
# GUM_academic_eegimaa-28 47 eds.
# GUM_academic_eegimaa-28 49 )
# GUM_academic_eegimaa-28  2014 49
# GUM_academic_eegimaa-28 41 on 49
# GUM_academic_eegimaa-28 40 base 49
# GUM_academic_eegimaa-29 1 Gútaamay 19
# GUM_academic_eegimaa-29 26 the 27
# GUM_academic_eegimaa-29 25 from 27
# GUM_academic_eegimaa-29 9 , 10
# GUM_academic_eegimaa-29 24 ) 10
# GUM_academic_eegimaa-29 10 Gulapaoray 7
# GUM_academic_eegimaa-29 19 ( 10
# GUM_academic_eegimaa-29 15 Djilapaor 24
# GUM_academic_eegimaa-29 27 village 24
# GUM_academic_eegimaa-29 17 and 18
# GUM_academic_eegimaa-29 18 Gusiilay 10
# GUM_academic_eegimaa-29 19 ( 10
# GUM_academic_eegimaa-29 20 ISO 21
# GUM_academic_eegimaa-29 21 639-3 19
# GUM_academic_eegimaa-29 22 : 21
# GUM_academic_eegimaa-29 23 bsl 24
# GUM_academic_eegimaa-29 7 Butam 24
# GUM_academic_eegimaa-29 28 of 24
# GUM_academic_eegimaa-29 34 language 35
# GUM_academic_eegimaa-29 33 other 35
# GUM_academic_eegimaa-29 32 also 35
# GUM_academic_eegimaa-29 31 be 35
# GUM_academic_eegimaa-29 30 Essil 35
# GUM_academic_eegimaa-29 29 Thionk 35
# GUM_academic_eegimaa-29 36 to 37
# GUM_academic_eegimaa-29 37 Eegimaa 35
# GUM_academic_eegimaa-29 35 related 38
# GUM_academic_eegimaa-30 2 be 3
# GUM_academic_eegimaa-30 1 they 3
# GUM_academic_eegimaa-30 7 Casamance 8
# GUM_academic_eegimaa-30 10 the 8
# GUM_academic_eegimaa-30 5 of 8
# GUM_academic_eegimaa-30 4 north 8
# GUM_academic_eegimaa-30 12 Búluf 13
# GUM_academic_eegimaa-30 11 Jóola 13
# GUM_academic_eegimaa-30 9 in 13
# GUM_academic_eegimaa-30 8 River 13
# GUM_academic_eegimaa-30 13 area 14
# GUM_academic_eegimaa-30 14 . 3
# GUM_academic_eegimaa-31 1 there 2
# GUM_academic_eegimaa-31 3 also 4
# GUM_academic_eegimaa-31 5 migrant 4
# GUM_academic_eegimaa-31 7 community 6
# GUM_academic_eegimaa-31 18 in 9
# GUM_academic_eegimaa-31 9 village 6
# GUM_academic_eegimaa-31 10 like 11
# GUM_academic_eegimaa-31 11 Djifanghor 6
# GUM_academic_eegimaa-31 20 ( 6
# GUM_academic_eegimaa-31 23 Ziguinchor 24
# GUM_academic_eegimaa-31 24 ) 17
# GUM_academic_eegimaa-31 31 of 17
# GUM_academic_eegimaa-31 13 east 17
# GUM_academic_eegimaa-31 17 and 6
# GUM_academic_eegimaa-31 19 Bourofaye 17
# GUM_academic_eegimaa-31 20 ( 17
# GUM_academic_eegimaa-31 29 with 30
# GUM_academic_eegimaa-31 28 cohabit 30
# GUM_academic_eegimaa-31 27 they 30
# GUM_academic_eegimaa-31 26 where 30
# GUM_academic_eegimaa-31 25 , 30
# GUM_academic_eegimaa-31 30 speaker 31
# GUM_academic_eegimaa-31 32 Baïnounk 33
# GUM_academic_eegimaa-31 33 language 34
# GUM_academic_eegimaa-31 21 south 34
# GUM_academic_eegimaa-31 34 . 6
# GUM_academic_eegimaa-32 2 most 1
# GUM_academic_eegimaa-32 3 Eegimaa 2
# GUM_academic_eegimaa-32 4 speaker 2
# GUM_academic_eegimaa-32 5 from 6
# GUM_academic_eegimaa-32 6 Mof-Ávvi 7
# GUM_academic_eegimaa-32 1 nowadays 7
# GUM_academic_eegimaa-32 9 their 10
# GUM_academic_eegimaa-32 15 area 14
# GUM_academic_eegimaa-32 18 and 19
# GUM_academic_eegimaa-32 17 Ziguinchor 19
# GUM_academic_eegimaa-32 16 like 19
# GUM_academic_eegimaa-32 19 Dakar 15
# GUM_academic_eegimaa-32 20 . 15
# GUM_academic_eegimaa-33 33 of 25
# GUM_academic_eegimaa-33 25 Eegimaa 4
# GUM_academic_eegimaa-33 4 use 5
# GUM_academic_eegimaa-33 1 speaker 5
# GUM_academic_eegimaa-33 6 term 7
# GUM_academic_eegimaa-33 5 the 7
# GUM_academic_eegimaa-33 7 Gújjolaay 8
# GUM_academic_eegimaa-33 9 mean 35
# GUM_academic_eegimaa-33 35 Jóola 11
# GUM_academic_eegimaa-33 8 ( 11
# GUM_academic_eegimaa-33 26 to 13
# GUM_academic_eegimaa-33 11 ) 13
# GUM_academic_eegimaa-33 26 to 13
# GUM_academic_eegimaa-33 13 refer 28
# GUM_academic_eegimaa-33 16 language 17
# GUM_academic_eegimaa-33 18 they 19
# GUM_academic_eegimaa-33 21 each 19
# GUM_academic_eegimaa-33 24 but 25
# GUM_academic_eegimaa-33 23 , 25
# GUM_academic_eegimaa-33 31 from 32
# GUM_academic_eegimaa-33 30 variety 32
# GUM_academic_eegimaa-33 32 that 33
# GUM_academic_eegimaa-33 36 people 34
# GUM_academic_eegimaa-33 37 . 34
# GUM_academic_eegimaa-34 1 Eegimaa 12
# GUM_academic_eegimaa-34 4 endangered 5
# GUM_academic_eegimaa-34 6 whose 7
# GUM_academic_eegimaa-34 5 language 7
# GUM_academic_eegimaa-34 3 a 7
# GUM_academic_eegimaa-34 8 to 9
# GUM_academic_eegimaa-34 9 new 10
# GUM_academic_eegimaa-34 13 decline 12
# GUM_academic_eegimaa-34 14 significantly 12
# GUM_academic_eegimaa-34 18 decade 17
# GUM_academic_eegimaa-34 17 last 19
# GUM_academic_eegimaa-34 16 the 19
# GUM_academic_eegimaa-34 15 in 19
# GUM_academic_eegimaa-34 19 . 12
# GUM_academic_eegimaa-35 2 be 3
# GUM_academic_eegimaa-35 1 it 3
# GUM_academic_eegimaa-35 4 to 5
# GUM_academic_eegimaa-35 3 important 5
# GUM_academic_eegimaa-35 5 understand 15
# GUM_academic_eegimaa-35 7 contact 8
# GUM_academic_eegimaa-35 15 the 8
# GUM_academic_eegimaa-35 14 of 10
# GUM_academic_eegimaa-35 10 Eegimaa 11
# GUM_academic_eegimaa-35 8 situation 11
# GUM_academic_eegimaa-35 17 name 18
# GUM_academic_eegimaa-35 16 ritual 18
# GUM_academic_eegimaa-35 13 some 18
# GUM_academic_eegimaa-35 12 because 18
# GUM_academic_eegimaa-35 11 , 18
# GUM_academic_eegimaa-35 21 paper 22
# GUM_academic_eegimaa-35 25 language 26
# GUM_academic_eegimaa-35 29 community 28
# GUM_academic_eegimaa-35 30 . 29
# GUM_academic_eegimaa-36 3 be 4
# GUM_academic_eegimaa-36 4 give 2
# GUM_academic_eegimaa-36 9 in 7
# GUM_academic_eegimaa-36 5 either 7
# GUM_academic_eegimaa-36 8 or 7
# GUM_academic_eegimaa-36 11 different 12
# GUM_academic_eegimaa-36 10 a 12
# GUM_academic_eegimaa-36 7 Eegimaa 12
# GUM_academic_eegimaa-36 12 language 13
# GUM_bio_dvorak-1 2 Dvořák 1
# GUM_bio_dvorak-2 2 Leopold 3
# GUM_bio_dvorak-2 1 Antonín 3
# GUM_bio_dvorak-2 9 / 6
# GUM_bio_dvorak-2 8 -ʒæk 10
# GUM_bio_dvorak-2 7 , 10
# GUM_bio_dvorak-2 10 d(ə)-VOR-zha(h)k 6
# GUM_bio_dvorak-2 19 ; 30
# GUM_bio_dvorak-2 30 Czech 10
# GUM_bio_dvorak-2 13 : 30
# GUM_bio_dvorak-2 14 [ 30
# GUM_bio_dvorak-2 15 ˈantoɲiːn 30
# GUM_bio_dvorak-2 18 ] 17
# GUM_bio_dvorak-2  8 17
# GUM_bio_dvorak-2 21 September
# GUM_bio_dvorak-2  1841
# GUM_bio_dvorak-2 23 -
# GUM_bio_dvorak-2  1 25
# GUM_bio_dvorak-2 17 ˈdvor̝aːk 25
# GUM_bio_dvorak-2 16 ˈlɛopolt 25
# GUM_bio_dvorak-2 25 May 30
# GUM_bio_dvorak-2  1904 30
# GUM_bio_dvorak-2 29 a 31
# GUM_bio_dvorak-2 28 be 31
# GUM_bio_dvorak-2 27 ) 31
# GUM_bio_dvorak-2 32 . 31
# GUM_bio_dvorak-3 2 Bedřich 3
# GUM_bio_dvorak-3 1 after 3
# GUM_bio_dvorak-3 5 he 6
# GUM_bio_dvorak-3 10 Romantic 11
# GUM_bio_dvorak-3 9 Czech 11
# GUM_bio_dvorak-3 11 - 8
# GUM_bio_dvorak-3 12 era 8
# GUM_bio_dvorak-3 13 composer 8
# GUM_bio_dvorak-3 14 to 15
# GUM_bio_dvorak-3 15 achieve 16
# GUM_bio_dvorak-3 16 worldwide 17
# GUM_bio_dvorak-3 17 recognition 8
# GUM_bio_dvorak-3 18 . 8
# GUM_bio_dvorak-4 2 Smetana 1
# GUM_bio_dvorak-4 3 's 1
# GUM_bio_dvorak-4 1 follow 4
# GUM_bio_dvorak-4 4 nationalist 5
# GUM_bio_dvorak-4 9 employ 10
# GUM_bio_dvorak-4 8 frequently 10
# GUM_bio_dvorak-4 10 aspect 14
# GUM_bio_dvorak-4 14 , 12
# GUM_bio_dvorak-4 12 specifically 13
# GUM_bio_dvorak-4 13 rhythm 14
# GUM_bio_dvorak-4 17 folk 18
# GUM_bio_dvorak-4 16 the 18
# GUM_bio_dvorak-4 19 of 18
# GUM_bio_dvorak-4 18 music 20
# GUM_bio_dvorak-4 7 Dvořák 20
# GUM_bio_dvorak-4 5 example 20
# GUM_bio_dvorak-4 24 Bohemia 23
# GUM_bio_dvorak-4 25 . 23
# GUM_bio_dvorak-5 1 Dvořák 2
# GUM_bio_dvorak-5 5 have 6
# GUM_bio_dvorak-5 6 be 7
# GUM_bio_dvorak-5 4 style 7
# GUM_bio_dvorak-5 3 own 7
# GUM_bio_dvorak-5 2 's 7
# GUM_bio_dvorak-5 8 as 34
# GUM_bio_dvorak-5 34 '' 7
# GUM_bio_dvorak-5 20 the 7
# GUM_bio_dvorak-5 11 full 7
# GUM_bio_dvorak-5 7 describe 12
# GUM_bio_dvorak-5 15 national 16
# GUM_bio_dvorak-5 14 a 16
# GUM_bio_dvorak-5 31 of 16
# GUM_bio_dvorak-5 17 with 18
# GUM_bio_dvorak-5 16 idiom 18
# GUM_bio_dvorak-5 12 recreation 18
# GUM_bio_dvorak-5 21 symphonic 22
# GUM_bio_dvorak-5 24 absorb 25
# GUM_bio_dvorak-5 25 folk 26
# GUM_bio_dvorak-5 26 influence 27
# GUM_bio_dvorak-5 27 and 28
# GUM_bio_dvorak-5 23 , 28
# GUM_bio_dvorak-5 22 tradition 28
# GUM_bio_dvorak-5 18 that 28
# GUM_bio_dvorak-5 28 find 29
# GUM_bio_dvorak-5 30 way 29
# GUM_bio_dvorak-5 32 use 29
# GUM_bio_dvorak-5 29 effective 33
# GUM_bio_dvorak-5 33 they 34
# GUM_bio_dvorak-5 35 . 36
# GUM_bio_dvorak-5 36 [
# GUM_bio_dvorak-5 38 ]
# GUM_bio_dvorak-6 2 Dvořák 1
# GUM_bio_dvorak-7 5 gift 4
# GUM_bio_dvorak-7 10 , 11
# GUM_bio_dvorak-7 11 be 12
# GUM_bio_dvorak-7 13 apt 12
# GUM_bio_dvorak-7 14 violin 15
# GUM_bio_dvorak-7 15 student 13
# GUM_bio_dvorak-7 17 age 18
# GUM_bio_dvorak-7 16 from 18
# GUM_bio_dvorak-7 18 six 15
# GUM_bio_dvorak-7 19 . 15
# GUM_bio_dvorak-8 4 performance 3
# GUM_bio_dvorak-8 7 work 24
# GUM_bio_dvorak-8 6 his 24
# GUM_bio_dvorak-8 5 of 24
# GUM_bio_dvorak-8 24 be 3
# GUM_bio_dvorak-8 19 in 10
# GUM_bio_dvorak-8 10 Prague 3
# GUM_bio_dvorak-8 19 in 3
# GUM_bio_dvorak-8  1872 3
# GUM_bio_dvorak-8 3 public 13
# GUM_bio_dvorak-8 16 special 17
# GUM_bio_dvorak-8 15 with 17
# GUM_bio_dvorak-8 17 success 21
# GUM_bio_dvorak-8 21 , 21
# GUM_bio_dvorak-8 13 and 21
# GUM_bio_dvorak-8 2 first 21
# GUM_bio_dvorak-8 1 the 21
# GUM_bio_dvorak-8  1873 21
# GUM_bio_dvorak-8 23 he 24
# GUM_bio_dvorak-8 22 when 24
# GUM_bio_dvorak-8 25 aged
# GUM_bio_dvorak-8 27 .
# GUM_bio_dvorak-9 1 seek 2
# GUM_bio_dvorak-9 5 Prague 6
# GUM_bio_dvorak-9 29 the 6
# GUM_bio_dvorak-9 3 beyond 6
# GUM_bio_dvorak-9 8 he 9
# GUM_bio_dvorak-9 17 a 11
# GUM_bio_dvorak-9 11 score 9
# GUM_bio_dvorak-9 14 First 15
# GUM_bio_dvorak-9 18 prize 19
# GUM_bio_dvorak-9 16 to 19
# GUM_bio_dvorak-9 15 Symphony 19
# GUM_bio_dvorak-9 13 his 19
# GUM_bio_dvorak-9 12 of 19
# GUM_bio_dvorak-9 20 in 21
# GUM_bio_dvorak-9 21 Germany 27
# GUM_bio_dvorak-9 19 competition 27
# GUM_bio_dvorak-9 27 , 9
# GUM_bio_dvorak-9 23 but 24
# GUM_bio_dvorak-9 24 do 25
# GUM_bio_dvorak-9 26 win 27
# GUM_bio_dvorak-9 27 , 25
# GUM_bio_dvorak-9 28 and 25
# GUM_bio_dvorak-9 32 be 33
# GUM_bio_dvorak-9 31 manuscript 33
# GUM_bio_dvorak-9 30 unreturned 33
# GUM_bio_dvorak-9 25 not 33
# GUM_bio_dvorak-9 9 submit 33
# GUM_bio_dvorak-9 6 area 33
# GUM_bio_dvorak-9 33 lose 2
# GUM_bio_dvorak-9 34 until 35
# GUM_bio_dvorak-9 35 rediscover 36
# GUM_bio_dvorak-9 37 decade 36
# GUM_bio_dvorak-9 38 late 39
# GUM_bio_dvorak-9 39 . 37
# GUM_bio_dvorak-10 1 in
# GUM_bio_dvorak-10  1874 3
# GUM_bio_dvorak-10 5 a 6
# GUM_bio_dvorak-10 4 make 6
# GUM_bio_dvorak-10 10 State 11
# GUM_bio_dvorak-10 9 Austrian 11
# GUM_bio_dvorak-10 8 the 11
# GUM_bio_dvorak-10 7 to 11
# GUM_bio_dvorak-10 12 for 13
# GUM_bio_dvorak-10 11 Prize 13
# GUM_bio_dvorak-10 13 Composition 14
# GUM_bio_dvorak-10 6 submission 14
# GUM_bio_dvorak-10 3 he 14
# GUM_bio_dvorak-10 15 include 16
# GUM_bio_dvorak-10 17 of 18
# GUM_bio_dvorak-10 18 two 16
# GUM_bio_dvorak-10 19 further 16
# GUM_bio_dvorak-10 20 symphony 21
# GUM_bio_dvorak-10 16 score 21
# GUM_bio_dvorak-10 14 , 21
# GUM_bio_dvorak-10 23 work 24
# GUM_bio_dvorak-10 22 other 24
# GUM_bio_dvorak-10 21 and 24

# %%
output_file = "dependency_predictions_on.tsv"
with open(output_file, "w", newline="") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    writer.writerow(["Sent_ID", "Dep_Index", "Dep_Word", "Head_Index"])
    for i in range(len(testResults)):
        for j in range(len(testResults[i])):
            head, dep = testResults[i][j]
            head = str(head)
            dep = str(dep)
            if getIndicesOfWords[i][head] and getIndicesOfWords[i][dep]:
                writer.writerow([listOfSentIds[i], getIndicesOfWords[i][dep], dep, getIndicesOfWords[i][head]])
